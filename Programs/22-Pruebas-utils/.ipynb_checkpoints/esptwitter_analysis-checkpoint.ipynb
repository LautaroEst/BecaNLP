# %%
import sys, os
sys.path.append(os.path.join(sys.path[0].split('Documents')[0],'Documents/BecaNLP/Utils'))

import NLPUtils as nlp

# %load_ext autoreload
# %autoreload 2

# %%
import pandas as pd

ds_total = pd.read_csv('../../Utils/Datasets/Spanish-Tweets/Total.csv',usecols=['TEXTO'],skiprows=1)['TEXTO']
ds_public = df = pd.read_csv('../../Utils/Datasets/Spanish-Tweets/tweets_public.csv',usecols=['text'])['text']
ds_teams = pd.read_csv('../../Utils/Datasets/Spanish-Tweets/betsentiment-ES-tweets-sentiment-teams.csv',encoding='latin-1')['tweet_text']
ds_worldcup = pd.read_csv('../../Utils/Datasets/Spanish-Tweets/betsentiment-ES-tweets-sentiment-worldcup.csv',encoding='latin-1')['tweet_text']
# Out:
# 0    #tablondeanuncios Funda nordica ikea #madrid h...
# 1    #tr Me ofrezco para montar muebles de Ikea - H...
# 2    #VozPópuli Vozpópuli @voz_populi - #LoMásLeido...
# 3    #ZonaTecno Destacado: Todo lo que hay que sabe...
# 4    $Carrefour retira pez #Panga. OCU y grupos x #...
# Name: TEXTO, dtype: object

# %%
df = pd.read_csv('../../Utils/Datasets/Spanish-Tweets/tweets_public.csv',usecols=['text'])
df
# Out:
#                                                    text
# 0     Trabajar en #Ryanair como #TMA: https://t.co/r...
# 1     @Iberia @FIONAFERRER Cuando gusten en Cancún s...
# 2     Sabiais que @Iberia te trata muy bien en santi...
# 3     NUNCA NUNCA NUNCA pidáis el café de Ryanair.\n...
# 4     @cris_tortu @dakar @Iberia @Mitsubishi_ES @BFG...
# ...                                                 ...
# 7862  @Iberia @iberiaexpress especialistas en dejart...
# 7863  Con @Iberia, mi destino a un solo click. ¡Dese...
# 7864                   @Iberia Muy bien. Muchas gracias
# 7865  Es que volar con Ryanair es peor que irte a ch...
# 7866  Iberia inaugura un nuevo espacio Premium para ...
#
# [7867 rows x 1 columns]

# %%
df = pd.read_csv('../../Utils/Datasets/Spanish-Tweets/betsentiment-ES-tweets-sentiment-teams.csv',encoding='latin-1')
df
# Out:
#                 tweet_date_created             tweet_id  \
# 0       2018-08-08T13:09:15.489000  1027179935184703489
# 1       2018-08-08T18:27:37.320000  1027260056092344320
# 2       2018-08-12T14:59:31.520000  1028657238116843520
# 3       2018-08-04T13:23:30.257000  1025733971320160257
# 4       2018-07-28T11:21:06.480000  1023166450981396480
# ...                            ...                  ...
# 132702  2018-08-10T21:57:11.345000  1028037572671545345
# 132703  2018-08-18T04:57:47.448000  1030680133189992448
# 132704  2018-09-16T16:54:09.904000  1041369661399547904
# 132705  2018-07-26T01:58:04.409000  1022299986762129409
# 132706  2018-08-04T18:11:00.800000  1025806323844300800
#
#                                                tweet_text language sentiment  \
# 0       Alisson puede estar más tranquilo, no cargará ...       es  POSITIVE
# 1       @iPincheViky @ChelseaFC Es que el director eje...       es   NEUTRAL
# ...

# %%
df = pd.read_csv('../../Utils/Datasets/Spanish-Tweets/betsentiment-ES-tweets-sentiment-worldcup.csv',encoding='latin-1')
df
# Out:
#                  tweet_date_created             tweet_id  \
# 0               2018-06-17T09:47:48  1008285070573035521
# 1        2018-06-28T06:00:16.360000  1012214075651215360
# 2               2018-06-07T22:07:43  1004847397074333696
# 3               2018-05-31T21:02:10  1002294186782199810
# 4               2018-06-26T11:02:06  1011565260183097344
# ...                             ...                  ...
# 1072456         2018-06-17T14:12:56  1008351795389689857
# 1072457  2018-06-17T14:12:56.857000  1008351795389689857
# 1072458         2018-05-14T01:54:14   995844705849143296
# 1072459         2018-06-23T15:22:55  1010543732742074368
# 1072460         2018-06-15T03:17:48  1007462149810159617
#
#                                                 tweet_text language sentiment  \
# 0        @JoseAMeadeK @miseleccionmx A pero si estás en...       es   NEUTRAL
# 1        #MarioPereyraDT\n"Tenemos que jugarle a Franci...       es   NEUTRAL
# ...

# %%
help(pd.read_csv)
# Out:
# Help on function read_csv in module pandas.io.parsers:
#
# read_csv(filepath_or_buffer: Union[str, pathlib.Path, IO[~AnyStr]], sep=',', delimiter=None, header='infer', names=None, index_col=None, usecols=None, squeeze=False, prefix=None, mangle_dupe_cols=True, dtype=None, engine=None, converters=None, true_values=None, false_values=None, skipinitialspace=False, skiprows=None, skipfooter=0, nrows=None, na_values=None, keep_default_na=True, na_filter=True, verbose=False, skip_blank_lines=True, parse_dates=False, infer_datetime_format=False, keep_date_col=False, date_parser=None, dayfirst=False, cache_dates=True, iterator=False, chunksize=None, compression='infer', thousands=None, decimal: str = '.', lineterminator=None, quotechar='"', quoting=0, doublequote=True, escapechar=None, comment=None, encoding=None, dialect=None, error_bad_lines=True, warn_bad_lines=True, delim_whitespace=False, low_memory=True, memory_map=False, float_precision=None)
# ...
