# %%
import sys, os
sys.path.append(os.path.join(sys.path[0].split('BecaNLP')[0],'BecaNLP/Utils'))

import NLPUtils as nlp
import numpy as np
import pandas as pd

# %load_ext autoreload
# %autoreload 2

# %%
help(root)
# Out:
# Help on Element object:
#
# class Element(builtins.object)
#  |  Methods defined here:
#  |
#  |  __copy__(self, /)
#  |
#  |  __deepcopy__(self, memo, /)
#  |
#  |  __delitem__(self, key, /)
#  |      Delete self[key].
#  |
#  |  __getattribute__(self, name, /)
#  |      Return getattr(self, name).
#  |
#  |  __getitem__(self, key, /)
#  |      Return self[key].
#  |
#  |  __getstate__(self, /)
#  |
#  |  __init__(self, /, *args, **kwargs)
#  |      Initialize self.  See help(type(self)) for accurate signature.
#  |
#  |  __len__(self, /)
#  |      Return len(self).
#  |
#  |  __repr__(self, /)
#  |      Return repr(self).
#  |
#  |  __setitem__(self, key, value, /)
#  |      Set self[key] to value.
#  |
#  |  __setstate__(self, state, /)
#  |
#  |  __sizeof__(self, /)
#  |      Size of object in memory, in bytes.
#  |
#  |  append(self, subelement, /)
#  |
#  |  clear(self, /)
#  |
#  |  extend(self, elements, /)
#  |
#  |  find(self, /, path, namespaces=None)
#  |
# ...

# %%
from NLPUtils.datasets import tass
from itertools import chain

uy_train = [(text, label) for (text,label) in tass.uy_train_reader()]
print(len(uy_train))
tass.cr_train_reader(),tass.pe_train_reader(),tass.mx_train_reader(),tass.es_train_reader()
# Out:
# Yo espero tranquila. Si gana de nvo alg partido tradicional, después sé q podré pasarla mal, pero tamb me voy a reír bastante. NEU
#
# Los fracasos de Michelle, Cristina y Dilma muestra que no sólo las izquierdas no son mejores, sino que las mujeres tp gobiernan tan bien N
#
# Debemos orar por los hnos venezolanos gente q es rehén hoy de la crisis en su país.Yo tengo amigos venezolanos q me preocupan en serio... N
#
# Me dijo que no le había gustado no se cuantas cosas pero me estuvo hablando todo el tiempo de eso JAJAJAJJA no entiendo loco NEU
#
# @susanagkp jajaja yo fui el viernes ! precavido pero el finde pasado no fui a la feria y quería ir pero ya veo que toca esperar... N
#
# iba a ir a la feria pero me encuentro que llovió y esta bastante feo así que procedo a meterme en la cama otro rato N
#
# @VirginiaBfo en ese baile conocí a mi ex y esa fue mi ruina ! y trabajé en un baile muy bueno desde los 21 a los 28 N
#
# ...
