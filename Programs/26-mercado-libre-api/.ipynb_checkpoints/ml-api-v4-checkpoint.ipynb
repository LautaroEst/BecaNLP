# %%
import sys
sys.path.append('python-sdk/lib/')
from meli import Meli
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import os
import re

# %load_ext autoreload
# %autoreload 2

# %% [markdown]
# # Inspección del dataset
#
# Los datos están en `data_all2.csv`

# %%
df_all = pd.read_csv('data_all2.csv')
df_all
# Out:
#               prod_id     cat_id  review_id country  \
# 0        MLA621740496    MLA1642   31217685     MLA
# 1        MLA621740496    MLA1642    6964851     MLA
# 2        MLA621740496    MLA1642    6589060     MLA
# 3        MLA621740496    MLA1642    7434436     MLA
# 4        MLA621740496    MLA1642   66786049     MLA
# ...               ...        ...        ...     ...
# 2581577  MLA753374110  MLA412786   51134018     MLA
# 2581578  MLA753374110  MLA412786   54084733     MLA
# 2581579  MLA753374110  MLA412786   56645855     MLA
# 2581580  MLA753374110  MLA412786   59257571     MLA
# 2581581  MLA753374110  MLA412786   58695656     MLA
#
#                                                 prod_title  reviewer_id  \
# 0        Almohadones Colores Lisos 40x40 Con Cierre - S...    239242243
# 1        Almohadones Colores Lisos 40x40 Con Cierre - S...     79368646
# 2        Almohadones Colores Lisos 40x40 Con Cierre - S...     12440335
# 3        Almohadones Colores Lisos 40x40 Con Cierre - S...     93444262
# 4        Almohadones Colores Lisos 40x40 Con Cierre - S...      6611442
# ...                                                    ...          ...
# 2581577         Sidra 1888 500ml, Oferta!!! Floresta, Caba    168034268
# 2581578         Sidra 1888 500ml, Oferta!!! Floresta, Caba     58313943
# 2581579         Sidra 1888 500ml, Oferta!!! Floresta, Caba     22165603
# 2581580         Sidra 1888 500ml, Oferta!!! Floresta, Caba     95220008
# 2581581         Sidra 1888 500ml, Oferta!!! Floresta, Caba     62331002
#
#                            review_date review_status  \
# 0        2018-07-24T13:38:53.000-04:00     published
# 1        2017-05-09T19:45:53.000-04:00     published
# 2        2017-05-01T18:53:38.000-04:00     published
# 3        2017-05-19T08:47:59.000-04:00     published
# 4        2020-06-20T22:52:16.000-04:00     published
# ...                                ...           ...
# 2581577  2019-12-09T11:39:25.000-04:00     published
# 2581578  2020-01-20T16:28:23.000-04:00     published
# 2581579  2020-02-25T19:00:03.000-04:00     published
# 2581580  2020-04-07T19:40:29.000-04:00     published
# 2581581  2020-03-28T11:26:00.000-04:00     published
#
#                       review_title  \
# 0                        Excelente
# 1                        Muy bueno
# 2                        Excelente
# 3                        Muy bueno
# 4                        Excelente
# ...                            ...
# 2581577          Muy buen producto
# 2581578                  Excelente
# 2581579                 Increíble
# 2581580                  Excelente
# 2581581  sin ningun inconveniente.
#
#                                             review_content  review_rate  \
# 0        Muy buenos almohadones, los colores son mejore...            5
# 1                  Muy prolija confección y terminaciones.            4
# 2        Estan muy buenos y quedan muy lindos en el sil...            5
# 3                     Muy buen producto y el mejor precio.            4
# 4                      Muy lindos,  buena tela. \nGracias.            5
# ...                                                    ...          ...
# 2581577         Ok buen producto okokokokokoooooooooooooo.            3
# 2581578            Excelente precio y calidad de producto.            5
# 2581579           Impecable, gran producto, lo recomiendo.            5
# 2581580  Muy bueno y práctico para toda ocasión. Recome...            5
# 2581581    Todo ok. Excelente producto y excelente precio.            5
#
#          review_likes  review_dislikes
# 0                   1                0
# 1                   1                0
# 2                   1                0
# 3                   1                0
# 4                   0                0
# ...               ...              ...
# 2581577             0                0
# 2581578             0                0
# 2581579             0                0
# 2581580             0                0
# 2581581             0                0
#
# [2581582 rows x 13 columns]

# %%
# Nos quedamos con las filas que no contienen caracteres basura
char_vocab = df_all['review_content'].str.split('').explode().value_counts()
chars_to_keep = set('abcçdefghijklmnñopqrstuvwxyzABCÇDEFGHIJKLMNÑOPQRSTUVWXYZ' + \
                    'áàâãäÁÀÂÃÄéèêëÉÈÊẼËíìîĩïÍÌÎĨÏóòôõöÓÒÔÕÖúùûũüÚÙÛŨÜ' + \
                    '.,;:%&$-!¡()?¿/\\"\'' + \
                    '0123456789' + \
                    ' \n\t')# VER los caracteres de IMDb para elegir con cual quedarme
chars_to_remove = sorted(list(set(char_vocab.index) - chars_to_keep - {''}))
df_all = df_all[-df_all['review_content'].str.contains('|'.join([re.escape(c) for c in chars_to_remove]),regex=True,na=True)]

# Convertimos todos los espacios en espacios simples
#df_all['review_content'] = df_all['review_content'].str.replace(r'[\s]+',' ',regex=True)

# %% [markdown]
# Fijamos una cantidad de máxima de comentarios por producto y sampleamos los reviews de los productos que tienen más de esa cantidad como un promedio ponderado del rate, cantidad de likes y de dislikes

# %%
max_comments = 20

indices = (-1 * df_all['review_rate'] + \
.1 * df_all['review_likes'] + \
.01 * df_all['review_dislikes']).sort_values(ascending=False).index
df_sampled = df_all.loc[indices,:].groupby('prod_id').head(max_comments)
len(df_sampled)
# Out:
# 1450846

# %% [markdown]
# Cantidad de comentarios en cada categoría y por idioma

# %%
mask = df_sampled['country'] == 'MLB'
print('Comentarios en portugués:')
rates_port = df_sampled[mask]['review_rate'].value_counts().sort_index()
print(rates_port)
print('Comentarios en español:')
rates_esp = df_sampled[np.logical_not(mask)]['review_rate'].value_counts().sort_index()
print(rates_esp)
print('Comentarios totales:')
print(rates_port + rates_esp)
print('Total:',sum(rates_port + rates_esp))
# Out:
# Comentarios en portugués:
# 1     38490
# 2     25030
# 3     56912
# 4    122652
# 5    306853
# Name: review_rate, dtype: int64
# Comentarios en español:
# 1     43005
# 2     29605
# 3     83887
# 4    225467
# 5    518945
# Name: review_rate, dtype: int64
# Comentarios totales:
# 1     81495
# 2     54635
# 3    140799
# 4    348119
# 5    825798
# Name: review_rate, dtype: int64
# Total: 1450846

# %%
df_por = df_sampled[df_sampled['country'] == 'MLB']
df_esp = df_sampled[df_sampled['country'] != 'MLB']

random_state = np.random.RandomState(1234)
n = 25000

df_esp = df_esp.iloc[np.hstack([random_state.choice(arr, n, replace=False) 
                       for arr in df_esp.groupby('review_rate').indices.values()]),:]

df_por = df_por.iloc[np.hstack([random_state.choice(arr, n, replace=False) 
                       for arr in df_por.groupby('review_rate').indices.values()]),:]
# Out:
# 5    25000
# 4    25000
# 3    25000
# 2    25000
# 1    25000
# Name: review_rate, dtype: int64

# %%
df_esp = df_esp.reset_index(drop=True)
df_esp = df_esp.iloc[random_state.permutation(len(df_esp)),:]
# Out:
#              prod_id     cat_id  review_id country  \
# 0       MLA790282460    MLA1075   55342637     MLA
# 1       MCO448783779   MCO36570   28804428     MCO
# 2       MLM651407722  MLM194512   49937109     MLM
# 3       MLU471250247    MLU9080   48747756     MLU
# 4       MLM749562442  MLM194390   57920565     MLM
# ...              ...        ...        ...     ...
# 124995  MLV477720396    MLV1935   52212770     MLV
# 124996  MLA843662465  MLA409597   71233912     MLA
# 124997  MLM580317152  MLM193819   50978782     MLM
# 124998  MLA788653518    MLA4964   64509259     MLA
# 124999  MLM729440268  MLM172327   66672810     MLM
#
#                                                prod_title  reviewer_id  \
# 0       Collar Isabelino De Color Protección Con Felpa...     97410969
# 1       Antena Tdt Hd Clear Vision Tv Digital Televisi...    132276558
# 2       Pañales Desechables Tipo Calzón Para Adulto Gr...    385336413
# 3       Arreglo Reparac Cortina De Enrollar Persiana C...    452540979
# 4       Bateria Para Smartwatch Dz09,q18, A1, Gt08, V8...    531452809
# ...                                                   ...          ...
# 124995              Maillot Ciclismo Mtb Ruta Manga Larga    205982813
# 124996  Copa Copita Menstrual Cocoon® - Copitamenstrual ®     10072622
# 124997  Cojin Protector De Cuello Para Barra Olimpica Gym    480750023
# 124998  Corpiño Aretha Art.840 Modelante Con Broche De...     94424630
# 124999  Kit De Delineador De Ojos Magnético Con Pestañ...     88453799
#
#                           review_date review_status  \
# 0       2020-02-06T07:50:29.000-04:00     published
# 1       2018-06-01T12:53:15.000-04:00     published
# 2       2019-11-23T21:16:06.000-04:00     published
# 3       2019-11-07T20:50:31.000-04:00     published
# 4       2020-03-16T00:57:39.000-04:00     published
# ...                               ...           ...
# 124995  2019-12-24T09:15:42.000-04:00     published
# 124996  2020-07-22T18:39:29.000-04:00     published
# 124997  2019-12-06T18:43:30.000-04:00     published
# 124998  2020-06-03T19:57:50.000-04:00     published
# 124999  2020-06-19T21:49:26.000-04:00     published
#
#                         review_title  \
# 0                       No me sirvió
# 1                           Muy malo
# 2                     No lo compren
# 3       Mal trabajo poca experiencia
# 4                      Mal producto
# ...                              ...
# 124995    Muy buena calidad y estilo
# 124996                     Excelente
# 124997      Producto muy acolchonado
# 124998                 Lo recomiendo
# 124999                     Fabuloso
#
#                                            review_content  review_rate  \
# 0       La verdad no me sirvió. Esa parte en tela le q...            1
# 1       No mejoro para nada la señal, y menos capturo ...            1
# 2                         Es un producto de poca calidad.            1
# 3       Vino apurado y quedo mal. El tabajo lo llamo y...            1
# 4       Mal producto. Se suponía que durara 2 días la ...            1
# ...                                                   ...          ...
# 124995  Muy buena calidad y con todos los detalles sol...            5
# 124996  Mi primera copita. No puedo compararla con otr...            5
# 124997  Es un producto excelente, cumple con todas las...            5
# 124998  Muy bueno! se ajustó perfectamente a mi tamaño...            5
# 124999      Muy padre, solo que seque bien y es fabuloso.            5
#
#         review_likes  review_dislikes
# 0                  0                0
# 1                  0                0
# 2                  0                0
# 3                 21                1
# 4                  0                2
# ...              ...              ...
# 124995             0                1
# 124996             0                0
# 124997             0                0
# 124998             0                0
# 124999             0                0
#
# [125000 rows x 13 columns]

# %%
df_all['prod_id'].value_counts().hist(bins=100)
