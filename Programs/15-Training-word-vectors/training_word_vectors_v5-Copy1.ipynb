# %%
import torch
from NLPUtils import *

import numpy as np
# %matplotlib notebook
import matplotlib.pyplot as plt

# %load_ext autoreload
# %autoreload 2

# %%
with open('text8','r') as file:
    corpus = file.read()
    corpus = [corpus.split(' ')]

# %%
len(corpus[0])
# Out:
# 17005208

# %%
# Modelo de lenguaje:
method = 'SkipGram'
window_size = 2
embedding_dim = 100

# Parámetros de iteración:
batch_size = 128
epochs = 100
learning_rate = 9e-1
sample_loss_every = 100
use_gpu = 0

embedding_layer, vocab, loss_history = SGDTrainWordVectors(corpus,lm=method,window_size=window_size,batch_size=batch_size,embedding_dim=embedding_dim,use_gpu=use_gpu,epochs=epochs,learning_rate=learning_rate,sample_loss_every=sample_loss_every)
ax.plot(loss_history['iter'],loss_history['loss'])
# Out:
# Starting training...
# 	Model used: SkipGram
#     	Optimization method: Stochastic Gradient Descent
#     	Learning Rate: 0.9
#     	Number of epochs: 100
#     	Number of batches: 132854
#     	Number of samples per batch: 128
#
# Epoch: 1, Batch number: 0, Loss: 12.580182075500488
# Epoch: 1, Batch number: 100, Loss: 11.637015342712402
# Epoch: 1, Batch number: 200, Loss: 11.320563316345215
# Epoch: 1, Batch number: 300, Loss: 11.18282699584961
# Epoch: 1, Batch number: 400, Loss: 10.97012996673584
# Epoch: 1, Batch number: 500, Loss: 11.162750244140625
# Epoch: 1, Batch number: 600, Loss: 10.878678321838379
# Epoch: 1, Batch number: 700, Loss: 10.738945960998535
# Epoch: 1, Batch number: 800, Loss: 10.719120025634766
# Epoch: 1, Batch number: 900, Loss: 11.020880699157715
# Epoch: 1, Batch number: 1000, Loss: 10.459303855895996
# Epoch: 1, Batch number: 1100, Loss: 10.803762435913086
# Epoch: 1, Batch number: 1200, Loss: 10.220685958862305
# Epoch: 1, Batch number: 1300, Loss: 10.601238250732422
# Epoch: 1, Batch number: 1400, Loss: 10.613049507141113
# Epoch: 1, Batch number: 1500, Loss: 10.43242073059082
# Epoch: 1, Batch number: 1600, Loss: 10.634733200073242
# Epoch: 1, Batch number: 1700, Loss: 10.46478271484375
# Exiting training...
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-3-d99e318340c6> in <module>
#      12
#      13 embedding_layer, vocab, loss_history = SGDTrainWordVectors(corpus,lm=method,window_size=window_size,batch_size=batch_size,embedding_dim=embedding_dim,use_gpu=use_gpu,epochs=epochs,learning_rate=learning_rate,sample_loss_every=sample_loss_every)
# ---> 14 ax.plot(loss_history['iter'],loss_history['loss'])
#
# NameError: name 'ax' is not defined

# %%
words = ['anarchism', 'marxism', 'philosophy', 
         'critique', 'idea', 'god', 'human', 
         'man', 'love', 'king', 'queen']

distance = torch.nn.CosineSimilarity(dim=1, eps=1e-6)
weights = next(iter(embedding_layer.parameters())).data

for word in words:
    idx = vocab.token_to_index(word)
    print(weights.size())
# Out:
# torch.Size([253856, 100])
# torch.Size([253856, 100])
# torch.Size([253856, 100])
# torch.Size([253856, 100])
# torch.Size([253856, 100])
# torch.Size([253856, 100])
# torch.Size([253856, 100])
# torch.Size([253856, 100])
# torch.Size([253856, 100])
# torch.Size([253856, 100])
# torch.Size([253856, 100])

# %%
# Out:
# {'': 0,
#  'anarchism': 1,
#  'originated': 2,
#  'as': 3,
#  'a': 4,
#  'term': 5,
#  'of': 6,
#  'abuse': 7,
#  'first': 8,
#  'used': 9,
#  'against': 10,
#  'early': 11,
#  'working': 12,
#  'class': 13,
#  'radicals': 14,
#  'including': 15,
#  'the': 16,
#  'diggers': 17,
#  'english': 18,
#  'revolution': 19,
#  'and': 20,
#  'sans': 21,
#  'culottes': 22,
#  'french': 23,
#  'whilst': 24,
#  'is': 25,
#  'still': 26,
#  'in': 27,
#  'pejorative': 28,
#  'way': 29,
#  'to': 30,
#  'describe': 31,
#  'any': 32,
#  'act': 33,
#  'that': 34,
#  'violent': 35,
#  'means': 36,
#  'destroy': 37,
#  'organization': 38,
#  'society': 39,
#  'it': 40,
#  'has': 41,
#  'also': 42,
#  'been': 43,
#  'taken': 44,
#  'up': 45,
#  'positive': 46,
#  'label': 47,
#  'by': 48,
#  'self': 49,
#  'defined': 50,
#  'anarchists': 51,
#  'word': 52,
#  'derived': 53,
#  'from': 54,
#  'greek': 55,
#  'without': 56,
#  'archons': 57,
#  'ruler': 58,
#  'chief': 59,
#  'king': 60,
#  'political': 61,
#  'philosophy': 62,
#  'belief': 63,
#  'rulers': 64,
#  'are': 65,
#  'unnecessary': 66,
#  'should': 67,
#  'be': 68,
#  'abolished': 69,
#  'although': 70,
#  'there': 71,
#  'differing': 72,
#  'interpretations': 73,
#  'what': 74,
#  'this': 75,
#  'refers': 76,
#  'related': 77,
#  'social': 78,
#  'movements': 79,
#  'advocate': 80,
#  'elimination': 81,
#  'authoritarian': 82,
#  'institutions': 83,
#  'particularly': 84,
#  'state': 85,
#  'anarchy': 86,
#  'most': 87,
#  'use': 88,
#  'does': 89,
#  'not': 90,
#  'imply': 91,
#  'chaos': 92,
#  'nihilism': 93,
#  'or': 94,
#  'anomie': 95,
#  'but': 96,
#  'rather': 97,
#  'harmonious': 98,
#  'anti': 99,
#  'place': 100,
#  'regarded': 101,
#  'structures': 102,
#  'coercive': 103,
#  'economic': 104,
#  'relations': 105,
#  'based': 106,
#  'upon': 107,
#  'voluntary': 108,
#  'association': 109,
#  'autonomous': 110,
#  'individuals': 111,
#  'mutual': 112,
#  'aid': 113,
#  'governance': 114,
#  'while': 115,
#  'easily': 116,
#  'offer': 117,
#  'visions': 118,
#  'they': 119,
#  'believe': 120,
#  'truly': 121,
#  'free': 122,
#  'however': 123,
#  'ideas': 124,
#  'about': 125,
#  'how': 126,
#  'an': 127,
#  'anarchist': 128,
#  'might': 129,
#  'work': 130,
#  'vary': 131,
#  'considerably': 132,
#  'especially': 133,
#  'with': 134,
#  'respect': 135,
#  'economics': 136,
#  'disagreement': 137,
#  'brought': 138,
#  'origins': 139,
#  'predecessors': 140,
#  'kropotkin': 141,
#  'others': 142,
#  'argue': 143,
#  'before': 144,
#  'recorded': 145,
#  'history': 146,
#  'human': 147,
#  'was': 148,
#  'organized': 149,
#  'on': 150,
#  'principles': 151,
#  'anthropologists': 152,
#  'follow': 153,
#  'engels': 154,
#  'believing': 155,
#  'hunter': 156,
#  'gatherer': 157,
#  'bands': 158,
#  'were': 159,
#  'egalitarian': 160,
#  'lacked': 161,
#  'division': 162,
#  'labour': 163,
#  'accumulated': 164,
#  'wealth': 165,
#  'decreed': 166,
#  'law': 167,
#  'had': 168,
#  'equal': 169,
#  'access': 170,
#  'resources': 171,
#  'william': 172,
#  'godwin': 173,
#  'organisation': 174,
#  'rothbard': 175,
#  'find': 176,
#  'attitudes': 177,
#  'taoism': 178,
#  'ancient': 179,
#  'china': 180,
#  'found': 181,
#  'similar': 182,
#  'stoic': 183,
#  'zeno': 184,
#  'citium': 185,
#  'according': 186,
#  'repudiated': 187,
#  'omnipotence': 188,
#  'its': 189,
#  'intervention': 190,
#  'regimentation': 191,
#  'proclaimed': 192,
#  'sovereignty': 193,
#  'moral': 194,
#  'individual': 195,
#  'anabaptists': 196,
#  'one': 197,
#  'six': 198,
#  'th': 199,
#  'century': 200,
#  'europe': 201,
#  'sometimes': 202,
#  'considered': 203,
#  'religious': 204,
#  'forerunners': 205,
#  'modern': 206,
#  'bertrand': 207,
#  'russell': 208,
#  'his': 209,
#  'western': 210,
#  'writes': 211,
#  'all': 212,
#  'since': 213,
#  'held': 214,
#  'good': 215,
#  'man': 216,
#  'will': 217,
#  'guided': 218,
#  'at': 219,
#  'every': 220,
#  'moment': 221,
#  'holy': 222,
#  'spirit': 223,
#  'premise': 224,
#  'arrive': 225,
#  'communism': 226,
#  'true': 227,
#  'levellers': 228,
#  'communistic': 229,
#  'movement': 230,
#  'during': 231,
#  'time': 232,
#  'civil': 233,
#  'war': 234,
#  'some': 235,
#  'era': 236,
#  'mean': 237,
#  'something': 238,
#  'other': 239,
#  'than': 240,
#  'louis': 241,
#  'armand': 242,
#  'baron': 243,
#  'de': 244,
#  'lahontan': 245,
#  'nouveaux': 246,
#  'voyages': 247,
#  'dans': 248,
#  'l': 249,
#  'am': 250,
#  'rique': 251,
#  'septentrionale': 252,
#  'seven': 253,
#  'zero': 254,
#  'three': 255,
#  'where': 256,
#  'he': 257,
#  'described': 258,
#  'indigenous': 259,
#  'american': 260,
#  'which': 261,
#  'no': 262,
#  'laws': 263,
#  'prisons': 264,
#  'priests': 265,
#  'private': 266,
#  'property': 267,
#  'being': 268,
#  'libertarian': 269,
#  'leader': 270,
#  'indian': 271,
#  'repeatedly': 272,
#  'stated': 273,
#  'so': 274,
#  'ancestors': 275,
#  'nine': 276,
#  'thick': 277,
#  'published': 278,
#  'enquiry': 279,
#  'concerning': 280,
#  'justice': 281,
#  'did': 282,
#  'many': 283,
#  'later': 284,
#  'have': 285,
#  'book': 286,
#  'major': 287,
#  'text': 288,
#  'founder': 289,
#  'philosophical': 290,
#  'point': 291,
#  'yet': 292,
#  'existed': 293,
#  'anarchiste': 294,
#  'known': 295,
#  'mainly': 296,
#  'insult': 297,
#  'hurled': 298,
#  'bourgeois': 299,
#  'girondins': 300,
#  'more': 301,
#  'radical': 302,
#  'elements': 303,
#  'labelled': 304,
#  'pierre': 305,
#  'joseph': 306,
#  'proudhon': 307,
#  'commonly': 308,
#  'wasn': 309,
#  't': 310,
#  'until': 311,
#  'eight': 312,
#  'four': 313,
#  'adopted': 314,
#  'description': 315,
#  'for': 316,
#  'reason': 317,
#  'claim': 318,
#  'theory': 319,
#  'answers': 320,
#  'famous': 321,
#  'accusation': 322,
#  'theft': 323,
#  'opposed': 324,
#  'institution': 325,
#  'propri': 326,
#  'owners': 327,
#  'complete': 328,
#  'rights': 329,
#  'their': 330,
#  'wish': 331,
#  'such': 332,
#  'exploiting': 333,
#  'workers': 334,
#  'profit': 335,
#  'supported': 336,
#  'called': 337,
#  'possession': 338,
#  'can': 339,
#  'limited': 340,
#  'capital': 341,
#  'goods': 342,
#  'accordance': 343,
#  'equality': 344,
#  's': 345,
#  'vision': 346,
#  'mutualism': 347,
#  'mutuellisme': 348,
#  'involved': 349,
#  'exchange': 350,
#  'economy': 351,
#  'groups': 352,
#  'could': 353,
#  'trade': 354,
#  'products': 355,
#  'labor': 356,
#  'using': 357,
#  'notes': 358,
#  'represented': 359,
#  'amount': 360,
#  'production': 361,
#  'would': 362,
#  'ensure': 363,
#  'freely': 364,
#  'join': 365,
#  'together': 366,
#  'co': 367,
#  'operative': 368,
#  'workshops': 369,
#  'interest': 370,
#  'bank': 371,
#  'set': 372,
#  'provide': 373,
#  'everyone': 374,
#  'influential': 375,
#  'within': 376,
#  'followers': 377,
#  'active': 378,
#  'france': 379,
#  'complex': 380,
#  'developed': 381,
#  'number': 382,
#  'works': 383,
#  'over': 384,
#  'lifetime': 385,
#  'detailed': 386,
#  'discussion': 387,
#  'see': 388,
#  'here': 389,
#  'max': 390,
#  'stirner': 391,
#  'egoism': 392,
#  'ego': 393,
#  'own': 394,
#  'argued': 395,
#  'accepted': 396,
#  'notion': 397,
#  'right': 398,
#  'natural': 399,
#  'general': 400,
#  'very': 401,
#  'mere': 402,
#  'illusions': 403,
#  'ghosts': 404,
#  'mind': 405,
#  'saying': 406,
#  'reality': 407,
#  'advocated': 408,
#  'form': 409,
#  'amoralism': 410,
#  'unite': 411,
#  'associations': 412,
#  'egoists': 413,
#  'only': 414,
#  'when': 415,
#  'do': 416,
#  'him': 417,
#  'simply': 418,
#  'comes': 419,
#  'through': 420,
#  'whoever': 421,
#  'knows': 422,
#  'take': 423,
#  'defend': 424,
#  'thing': 425,
#  'belongs': 426,
#  'i': 427,
#  'my': 428,
#  'power': 429,
#  'long': 430,
#  'assert': 431,
#  'myself': 432,
#  'holder': 433,
#  'proprietor': 434,
#  'never': 435,
#  'himself': 436,
#  'egoist': 437,
#  'nevertheless': 438,
#  'individualistically': 439,
#  'inclined': 440,
#  'thought': 441,
#  'diverse': 442,
#  'individualist': 443,
#  'benjamin': 444,
#  'tucker': 445,
#  'two': 446,
#  'five': 447,
#  'josiah': 448,
#  'warren': 449,
#  'participated': 450,
#  'communitarian': 451,
#  'experiment': 452,
#  'headed': 453,
#  'robert': 454,
#  'owen': 455,
#  'new': 456,
#  'harmony': 457,
#  'failed': 458,
#  'few': 459,
#  'years': 460,
#  'amidst': 461,
#  'much': 462,
#  'internal': 463,
#  'conflict': 464,
#  'blamed': 465,
#  'community': 466,
#  'failure': 467,
#  'lack': 468,
#  'proceeded': 469,
#  'organise': 470,
#  'experimenal': 471,
#  'communities': 472,
#  'respected': 473,
#  'utopia': 474,
#  'times': 475,
#  'wrote': 476,
#  'peaceful': 477,
#  'revolutionist': 478,
#  'noted': 479,
#  'periodical': 480,
#  'ever': 481,
#  'says': 482,
#  'expound': 483,
#  'formulate': 484,
#  'doctrine': 485,
#  'now': 486,
#  'liberty': 487,
#  'xiv': 488,
#  'december': 489,
#  'became': 490,
#  'interested': 491,
#  'meeting': 492,
#  'b': 493,
#  'greene': 494,
#  'edited': 495,
#  'august': 496,
#  'april': 497,
#  'widely': 498,
#  'finest': 499,
#  'issued': 500,
#  'language': 501,
#  'conception': 502,
#  'incorporated': 503,
#  'variety': 504,
#  'theorists': 505,
#  'banking': 506,
#  'cost': 507,
#  'limit': 508,
#  'price': 509,
#  'heterodox': 510,
#  'value': 511,
#  'market': 512,
#  'herbert': 513,
#  'spencer': 514,
#  'freedom': 515,
#  'strongly': 516,
#  'product': 517,
#  'her': 518,
#  'believed': 519,
#  'trading': 520,
#  'system': 521,
#  'abundance': 522,
#  'competition': 523,
#  'eliminate': 524,
#  'profits': 525,
#  'received': 526,
#  'full': 527,
#  'individualists': 528,
#  'included': 529,
#  'lysander': 530,
#  'spooner': 531,
#  'stephen': 532,
#  'pearl': 533,
#  'andrews': 534,
#  'victor': 535,
#  'yarros': 536,
#  'international': 537,
#  'mikhail': 538,
#  'bakunin': 539,
#  'harsh': 540,
#  'reaction': 541,
#  'followed': 542,
#  'revolutions': 543,
#  'twenty': 544,
#  'workingmen': 545,
#  'united': 546,
#  'european': 547,
#  'revolutionary': 548,
#  'currents': 549,
#  'due': 550,
#  'genuine': 551,
#  'links': 552,
#  'signficiant': 553,
#  'start': 554,
#  'karl': 555,
#  'marx': 556,
#  'leading': 557,
#  'figure': 558,
#  'elected': 559,
#  'succeeding': 560,
#  'council': 561,
#  'objections': 562,
#  'came': 563,
#  'mutualists': 564,
#  'who': 565,
#  'statism': 566,
#  'shortly': 567,
#  'after': 568,
#  'joined': 569,
#  'polarised': 570,
#  'into': 571,
#  'camps': 572,
#  'respective': 573,
#  'figureheads': 574,
#  'clearest': 575,
#  'difference': 576,
#  'between': 577,
#  'strategy': 578,
#  'around': 579,
#  'favoured': 580,
#  'words': 581,
#  'direct': 582,
#  'economical': 583,
#  'struggle': 584,
#  'capitalism': 585,
#  'interfering': 586,
#  'parliamentary': 587,
#  'agitation': 588,
#  'focused': 589,
#  'activity': 590,
#  'characterised': 591,
#  'predicted': 592,
#  'if': 593,
#  'marxist': 594,
#  'party': 595,
#  'gained': 596,
#  'leaders': 597,
#  'end': 598,
#  'bad': 599,
#  'ruling': 600,
#  'fought': 601,
#  'climaxed': 602,
#  'final': 603,
#  'split': 604,
#  'hague': 605,
#  'congress': 606,
#  'often': 607,
#  'cited': 608,
#  'origin': 609,
#  'marxists': 610,
#  'democratic': 611,
#  'socialism': 612,
#  'distinct': 613,
#  'organisations': 614,
#  'rival': 615,
#  'internationals': 616,
#  'peter': 617,
#  'both': 618,
#  'associating': 619,
#  'moved': 620,
#  'away': 621,
#  'thinking': 622,
#  'collectivism': 623,
#  'embraced': 624,
#  'communist': 625,
#  'concepts': 626,
#  'communists': 627,
#  'owned': 628,
#  'collectively': 629,
#  'distributed': 630,
#  'need': 631,
#  'd': 632,
#  'jacque': 633,
#  'person': 634,
#  'unlike': 635,
#  'worker': 636,
#  'satisfaction': 637,
#  'needs': 638,
#  'whatever': 639,
#  'may': 640,
#  'nature': 641,
#  'announced': 642,
#  'us': 643,
#  'journal': 644,
#  'le': 645,
#  'libertaire': 646,
#  'seen': 647,
#  'important': 648,
#  'theorist': 649,
#  'outlined': 650,
#  'conquest': 651,
#  'bread': 652,
#  'fields': 653,
#  'factories': 654,
#  'felt': 655,
#  'operation': 656,
#  'beneficial': 657,
#  'illustrated': 658,
#  'factor': 659,
#  'evolution': 660,
#  'subsequent': 661,
#  'include': 662,
#  'emma': 663,
#  'goldman': 664,
#  'alexander': 665,
#  'berkman': 666,
#  'anarcho': 667,
#  'syndicalist': 668,
#  'below': 669,
#  'saw': 670,
#  'objective': 671,
#  'isaac': 672,
#  'puente': 673,
#  'comunismo': 674,
#  'libertario': 675,
#  'spanish': 676,
#  'cnt': 677,
#  'manifesto': 678,
#  'post': 679,
#  'disliked': 680,
#  'merging': 681,
#  'several': 682,
#  'maintained': 683,
#  'abolition': 684,
#  'consistent': 685,
#  'example': 686,
#  'professing': 687,
#  'publishing': 688,
#  'pseudo': 689,
#  'propaganda': 690,
#  'deed': 691,
#  'johann': 692,
#  'outspoken': 693,
#  'violence': 694,
#  'portrayed': 695,
#  'dangerous': 696,
#  'high': 697,
#  'profile': 698,
#  'acts': 699,
#  'riots': 700,
#  'assassinations': 701,
#  'insurrections': 702,
#  'terrorism': 703,
#  'revolutionaries': 704,
#  'late': 705,
#  'encouraged': 706,
#  'bombings': 707,
#  'heads': 708,
#  'further': 709,
#  'actions': 710,
#  'advocates': 711,
#  'said': 712,
#  'existing': 713,
#  'quickest': 714,
#  'radically': 715,
#  'overthrown': 716,
#  'annihilation': 717,
#  'exponents': 718,
#  'therefore': 719,
#  'massacres': 720,
#  'enemies': 721,
#  'people': 722,
#  'must': 723,
#  'motion': 724,
#  'preferred': 725,
#  'method': 726,
#  'dynamite': 727,
#  'earned': 728,
#  'moniker': 729,
#  'dynamost': 730,
#  'consensus': 731,
#  'legitimacy': 732,
#  'utility': 733,
#  'errico': 734,
#  'malatesta': 735,
#  'necessary': 736,
#  'desirable': 737,
#  'force': 738,
#  'settings': 739,
#  'same': 740,
#  'denounced': 741,
#  'refuted': 742,
#  'nechaev': 743,
#  'identified': 744,
#  'pacifist': 745,
#  'nonviolence': 746,
#  'leo': 747,
#  'tolstoy': 748,
#  'whose': 749,
#  'viewed': 750,
#  'christian': 751,
#  'notable': 752,
#  'exponent': 753,
#  'nonviolent': 754,
#  'resistance': 755,
#  'red': 756,
#  'black': 757,
#  'flag': 758,
#  'coming': 759,
#  'experience': 760,
#  'associated': 761,
#  'syndicalism': 762,
#  'seeking': 763,
#  'overthrow': 764,
#  'institute': 765,
#  'controlled': 766,
#  'pursued': 767,
#  'industrial': 768,
#  'strike': 769,
#  'primary': 770,
#  'syndicalists': 771,
#  'though': 772,
#  'repression': 773,
#  'reemerged': 774,
#  'influencing': 775,
#  'bourses': 776,
#  'travails': 777,
#  'unions': 778,
#  'conf': 779,
#  'ration': 780,
#  'g': 781,
#  'n': 782,
#  'rale': 783,
#  'du': 784,
#  'travail': 785,
#  'confederation': 786,
#  'cgt': 787,
#  'formed': 788,
#  'emile': 789,
#  'pataud': 790,
#  'pouget': 791,
#  'writing': 792,
#  'developing': 793,
#  'appeal': 794,
#  'bolshevism': 795,
#  'style': 796,
#  'significant': 797,
#  'prior': 798,
#  'remained': 799,
#  'spain': 800,
#  'mid': 801,
#  'world': 802,
#  'iww': 803,
#  'founded': 804,
#  'espoused': 805,
#  'unionism': 806,
#  'sought': 807,
#  'usher': 808,
#  'stateless': 809,
#  'members': 810,
#  'support': 811,
#  'explicitly': 812,
#  'rank': 813,
#  'file': 814,
#  'democracy': 815,
#  'embodying': 816,
#  'inspired': 817,
#  'anglophone': 818,
#  'reads': 819,
#  'don': 820,
#  'let': 821,
#  'politicians': 822,
#  'rule': 823,
#  'our': 824,
#  'lives': 825,
#  'you': 826,
#  'vote': 827,
#  'decide': 828,
#  'allow': 829,
#  'unity': 830,
#  'action': 831,
#  'management': 832,
#  'union': 833,
#  'federations': 834,
#  'successful': 835,
#  'confederaci': 836,
#  'nacional': 837,
#  'del': 838,
#  'trabajo': 839,
#  'national': 840,
#  'politics': 841,
#  'membership': 842,
#  'million': 843,
#  'played': 844,
#  'role': 845,
#  'like': 846,
#  'ricardo': 847,
#  'flores': 848,
#  'mag': 849,
#  'key': 850,
#  'figures': 851,
#  'mexican': 852,
#  'latin': 853,
#  'influenced': 854,
#  'extending': 855,
#  'zapatista': 856,
#  'rebellion': 857,
#  'factory': 858,
#  'occupation': 859,
#  'argentina': 860,
#  'berlin': 861,
#  'successor': 862,
#  'contemporary': 863,
#  'continues': 864,
#  'minor': 865,
#  'socities': 866,
#  'smaller': 867,
#  'largest': 868,
#  'organised': 869,
#  'today': 870,
#  'claims': 871,
#  'paid': 872,
#  'votes': 873,
#  'syndical': 874,
#  'elections': 875,
#  'solidarity': 876,
#  'alliance': 877,
#  'uk': 878,
#  'federation': 879,
#  'unionist': 880,
#  'exists': 881,
#  'claiming': 882,
#  'critics': 883,
#  'workerist': 884,
#  'fail': 885,
#  'deal': 886,
#  'life': 887,
#  'outside': 888,
#  'leftist': 889,
#  'bob': 890,
#  'oppressive': 891,
#  'workplace': 892,
#  'uphold': 893,
#  'russian': 894,
#  'seismic': 895,
#  'event': 896,
#  'development': 897,
#  'alongside': 898,
#  'bolsheviks': 899,
#  'february': 900,
#  'october': 901,
#  'initially': 902,
#  'supporting': 903,
#  'bolshevik': 904,
#  'coup': 905,
#  'soon': 906,
#  'turned': 907,
#  'left': 908,
#  'wing': 909,
#  'opposition': 910,
#  'culminated': 911,
#  'kronstadt': 912,
#  'central': 913,
#  'russia': 914,
#  'imprisoned': 915,
#  'driven': 916,
#  'underground': 917,
#  'victorious': 918,
#  'ukraine': 919,
#  'whites': 920,
#  'makhnovshchina': 921,
#  'peasant': 922,
#  'army': 923,
#  'led': 924,
#  'nestor': 925,
#  'makhno': 926,
#  'expelled': 927,
#  'leaving': 928,
#  'amongst': 929,
#  'those': 930,
#  'agitating': 931,
#  'response': 932,
#  'policy': 933,
#  'suppression': 934,
#  'uprising': 935,
#  'classic': 936,
#  'accounts': 937,
#  'experiences': 938,
#  'aiming': 939,
#  'expose': 940,
#  'control': 941,
#  'them': 942,
#  'predictions': 943,
#  'consequences': 944,
#  'proved': 945,
#  'too': 946,
#  'victory': 947,
#  'resulting': 948,
#  'serious': 949,
#  'damage': 950,
#  'internationally': 951,
#  'activists': 952,
#  'success': 953,
#  'setting': 954,
#  'parties': 955,
#  'grew': 956,
#  'expense': 957,
#  'socialist': 958,
#  'began': 959,
#  'realign': 960,
#  'themselves': 961,
#  'towards': 962,
#  'paris': 963,
#  'dielo': 964,
#  'truda': 965,
#  'group': 966,
#  'exiles': 967,
#  'concluded': 968,
#  'needed': 969,
#  'develop': 970,
#  'forms': 971,
#  'organisational': 972,
#  'platform': 973,
#  'inspire': 974,
#  'theoretical': 975,
#  'tactical': 976,
#  'collective': 977,
#  'responsibility': 978,
#  'federalism': 979,
#  'platformist': 980,
#  'ireland': 981,
#  'north': 982,
#  'eastern': 983,
#  'northeastern': 984,
#  'states': 985,
#  'bordering': 986,
#  'canada': 987,
#  'fight': 988,
#  'fascism': 989,
#  'construct': 990,
#  'armoured': 991,
#  'cars': 992,
#  'fascists': 993,
#  'collectivised': 994,
#  'familiar': 995,
#  'dynamics': 996,
#  'transformed': 997,
#  'rise': 998,
#  'cases': 999,
#  ...}
