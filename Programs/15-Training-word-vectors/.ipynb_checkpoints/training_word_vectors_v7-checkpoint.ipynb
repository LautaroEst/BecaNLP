# %%
import torch
from NLPUtils import *

import numpy as np
# %matplotlib notebook
import matplotlib.pyplot as plt

# %load_ext autoreload
# %autoreload 2

# %%
with open('text8','r') as file:
    corpus = file.read()
    corpus = [corpus.split(' ')]

# %%
corpus = [['hola', 'soy', 'lauti'],['hola', 'soy', 'guadi'], ['chau', 'soy', 'luna','me','quiero','ir']]

# %%
# Modelo de lenguaje:
method = 'SkipGram'
window_size = 2
embedding_dim = 100
cutoff_freq = 4
pretrained = None

# Parámetros de iteración:
batch_size = 128
use_gpu = 1

trainer = WordVectorsSGD(corpus,cutoff_freq=cutoff_freq,lm=method,window_size=window_size,batch_size=batch_size,embedding_dim=embedding_dim,use_gpu=use_gpu)
trainer.init_embeddings()
# Out:
# Word2vec trainer created:
# Model used: SkipGram
# Window size: 2
# Embedding dimension: 100
# Number of samples: 12
# Vocabulary Size: 2
# Discarted words with frequency less than 2
# Number of batches: 1
# Number of samples per batch: 128

# %%
epochs = 50
learning_rate = 1e-1
sample_loss_every = 1

trainer.train(epochs=epochs, learning_rate=learning_rate, sample_loss_every=sample_loss_every)
# Out:
# Starting training...
# Optimization method: Stochastic Gradient Descent
# Learning Rate: 0.1
# Number of epochs: 50
# Running on device (cuda:1)
#
# Epoch: 1, Batch number: 0, Loss: 0.6437820196151733
# Epoch: 2, Batch number: 0, Loss: 0.6259850859642029
# Epoch: 3, Batch number: 0, Loss: 0.42469194531440735
# Epoch: 4, Batch number: 0, Loss: 0.43643370270729065
# Epoch: 5, Batch number: 0, Loss: 0.42872732877731323
# Epoch: 6, Batch number: 0, Loss: 0.4547359347343445
# Epoch: 7, Batch number: 0, Loss: 0.43259915709495544
# Epoch: 8, Batch number: 0, Loss: 0.4657402038574219
# Epoch: 9, Batch number: 0, Loss: 0.43208789825439453
# Epoch: 10, Batch number: 0, Loss: 0.4669362008571625
# Epoch: 11, Batch number: 0, Loss: 0.43075963854789734
# Epoch: 12, Batch number: 0, Loss: 0.4658868610858917
# Epoch: 13, Batch number: 0, Loss: 0.42971476912498474
# Epoch: 14, Batch number: 0, Loss: 0.4649222195148468
# Epoch: 15, Batch number: 0, Loss: 0.4289340674877167
# Epoch: 16, Batch number: 0, Loss: 0.4641803503036499
# Epoch: 17, Batch number: 0, Loss: 0.4283332824707031
# Epoch: 18, Batch number: 0, Loss: 0.46360155940055847
# Epoch: 19, Batch number: 0, Loss: 0.42785680294036865
# Epoch: 20, Batch number: 0, Loss: 0.46313774585723877
# Epoch: 21, Batch number: 0, Loss: 0.42746976017951965
# Epoch: 22, Batch number: 0, Loss: 0.4627581536769867
# Epoch: 23, Batch number: 0, Loss: 0.42714908719062805
# Epoch: 24, Batch number: 0, Loss: 0.46244099736213684
# Epoch: 25, Batch number: 0, Loss: 0.42687883973121643
# Epoch: 26, Batch number: 0, Loss: 0.4621726870536804
# Epoch: 27, Batch number: 0, Loss: 0.4266480505466461
# Epoch: 28, Batch number: 0, Loss: 0.4619424045085907
# Epoch: 29, Batch number: 0, Loss: 0.4264487326145172
# Epoch: 30, Batch number: 0, Loss: 0.4617425203323364
# Epoch: 31, Batch number: 0, Loss: 0.42627468705177307
# Epoch: 32, Batch number: 0, Loss: 0.4615674316883087
# Epoch: 33, Batch number: 0, Loss: 0.4261212646961212
# Epoch: 34, Batch number: 0, Loss: 0.46141260862350464
# Epoch: 35, Batch number: 0, Loss: 0.42598533630371094
# Epoch: 36, Batch number: 0, Loss: 0.4612750709056854
# Epoch: 37, Batch number: 0, Loss: 0.4258638322353363
# Epoch: 38, Batch number: 0, Loss: 0.46115171909332275
# Epoch: 39, Batch number: 0, Loss: 0.4257546365261078
# Epoch: 40, Batch number: 0, Loss: 0.46104079484939575
# Epoch: 41, Batch number: 0, Loss: 0.42565596103668213
# Epoch: 42, Batch number: 0, Loss: 0.4609401524066925
# Epoch: 43, Batch number: 0, Loss: 0.42556631565093994
# Epoch: 44, Batch number: 0, Loss: 0.46084871888160706
# Epoch: 45, Batch number: 0, Loss: 0.42548465728759766
# Epoch: 46, Batch number: 0, Loss: 0.46076515316963196
# Epoch: 47, Batch number: 0, Loss: 0.4254096746444702
# Epoch: 48, Batch number: 0, Loss: 0.4606884717941284
# Epoch: 49, Batch number: 0, Loss: 0.42534083127975464
# Epoch: 50, Batch number: 0, Loss: 0.4606178402900696
# Training finished

# %%
fig, ax = plt.subplots()
ax.plot(trainer.loss_history['iter'],trainer.loss_history['loss'])
# Out:
# <img src="data:image/png;base64,..." width="640">
