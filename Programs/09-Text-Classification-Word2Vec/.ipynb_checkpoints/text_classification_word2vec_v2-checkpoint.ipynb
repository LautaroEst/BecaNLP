# %%
import torch
import pandas as pd
from TorchDataUtils import *
from NLPDataUtils import *

# %matplotlib notebook
import matplotlib.pyplot as plt

# %load_ext autoreload
# %autoreload 2

# %% [markdown]
# # Clasificación sin WordVectors

# %%
class AGNewsDataset(torch.utils.data.Dataset):
    
    def __init__(self, root='./AG_NEWS/', preprocess=lambda x: x, train=True):
        
        target = 'train.csv' if train else 'test.csv'
        df = pd.read_csv(root + target, header=None, names=['class_idx', 'title', 'description'])
        
        # Etiquetas:
        self.cls_indeces = torch.tensor(df['class_idx'].tolist(), dtype=torch.long) - 1
        
        # DataSeries con las muestras de entradas:
        data = df['title']
        self.data = preprocess(data)
    
    def __getitem__(self,idx):
        if type(idx) == torch.Tensor:
            idx = idx.item()
        return self.vectorizer.vectorize(self.data.iloc[idx]), self.cls_indeces[idx]
    
    def __len__(self):
        return len(self.cls_indeces)
    
    
def GetAGNewsDataset(root, preprocess, cutoff=25):
    
    # Datasets:
    train_dataset = AGNewsDataset(root, preprocess=preprocess, train=True)
    train_dataset.vectorizer = Vectorizer([train_dataset.data], cutoff=cutoff)
    test_dataset = AGNewsDataset(root, preprocess=preprocess, train=False)
    test_dataset.vectorizer = train_dataset.vectorizer
    
    # Dataloaders:
    train_dataloader, val_dataloader, test_dataloader = generate_data_batches(train_dataset, 
                                                                              test_dataset,    
                                                                              batch_size=64)
    return train_dataloader, val_dataloader, test_dataloader

def preprocess(data):
    df = data.str.replace(r'\(AP\)','')
    df = df.str.replace(r'\(Reuters\)','')
    df = df.str.replace(r'\(AFP\)','')
    df = df.str.replace(r'\(SPACE\.com\)','')
    df = df.str.replace(r'\ba\b','')
    df = df.str.replace(r'\bthe\b','')
    df = df.str.replace(r'\bis\b','')
    df = df.str.replace(r'\bof\b','')
    df = df.str.replace(r'\bto\b','')
    df = df.str.replace(r'[,:;\?\!\"]','')
    df = df.str.replace(r'\s+','<SEP>')
    df = df.str.replace(r"'s<SEP>","<SEP>'s<SEP>")
    df = df.str.split('<SEP>')
    return df

# %%
tc_train_dataloader, tc_val_dataloader, tc_test_dataloader = GetAGNewsDataset(root='./AG_NEWS/', 
                                                                     preprocess=preprocess, 
                                                                     cutoff=25)

import torch.nn as nn

class TextClassifier1(nn.Module):
    
    def __init__(self, vocab_size, n_embeddings, n_classes):
        super(TextClassifier1, self).__init__()
        self.emb = nn.Linear(vocab_size, n_embeddings)
        self.out = nn.Linear(n_embeddings, n_classes)
        
    def forward(self, x):
        return self.out(self.emb(x))
    
    def loss(self, scores, target):
        lf = nn.CrossEntropyLoss()
        return lf(scores, target)

# %%
# Parámetros de las muestras:
data = {
    'use_gpu': True, # Trasladar o no las muestras a la GPU
    'input_dtype': torch.float, # Tipo de dato de las muestras de entrada
    'target_dtype': torch.long, # Tipo de dato de las muestras de salida
    'train_dataloader': tc_train_dataloader, # Dataset de entrenamiento
    'val_dataloader': tc_val_dataloader # Dataset de validación
}

# Parámetros de optimización:
epochs = 20 # Cantidad de epochs
sample_loss_every = 500 # Cantidad de iteraciones para calcular la cantidad de aciertos
learning_rate = [1, 5e-1] # Tasa de aprendizaje
check_on_train = False # Queremos ver los resultados también en el train set

# Entrenamiento:
performance_history = []
classification_models = []

vocab_size = len(tc_train_dataloader.dataset.vectorizer.vocabulary)
n_classes = 4
n_embeddings = 100
ClassifierModel = TextClassifier1(vocab_size, n_embeddings, n_classes)

for lr in learning_rate:
    model = TextClassifier1(vocab_size, n_embeddings, n_classes)
    model.load_state_dict(ClassifierModel.state_dict())
    performance_history.append(SGDTrainModel(model, 
                                             data, 
                                             epochs, 
                                             lr, 
                                             sample_loss_every, 
                                             check_on_train, 
                                             verbose=True))
    classification_models.append(model)
    print('lr={:.2g} completed.'.format(lr))
# Out:
# Epoch: 0, Batch number: 0
# Accuracy on validation dataset: 645/2400 (26.88%)
#
# Epoch: 0, Batch number: 500
# Accuracy on validation dataset: 1585/2400 (66.04%)
#
# Epoch: 0, Batch number: 1000
# Accuracy on validation dataset: 1914/2400 (79.75%)
#
# Epoch: 0, Batch number: 1500
# Accuracy on validation dataset: 1911/2400 (79.62%)
#
# Epoch: 1, Batch number: 162
# Accuracy on validation dataset: 1917/2400 (79.88%)
#
# Epoch: 1, Batch number: 662
# Accuracy on validation dataset: 1922/2400 (80.08%)
#
# Epoch: 1, Batch number: 1162
# Accuracy on validation dataset: 1897/2400 (79.04%)
#
# Epoch: 1, Batch number: 1662
# Accuracy on validation dataset: 1942/2400 (80.92%)
#
# Epoch: 2, Batch number: 324
# Accuracy on validation dataset: 1926/2400 (80.25%)
#
# Epoch: 2, Batch number: 824
# Accuracy on validation dataset: 1844/2400 (76.83%)
#
# Epoch: 2, Batch number: 1324
# Accuracy on validation dataset: 1940/2400 (80.83%)
#
# Epoch: 2, Batch number: 1824
# Accuracy on validation dataset: 1921/2400 (80.04%)
#
# Epoch: 3, Batch number: 486
# Accuracy on validation dataset: 1926/2400 (80.25%)
#
# Epoch: 3, Batch number: 986
# Accuracy on validation dataset: 1939/2400 (80.79%)
#
# Epoch: 3, Batch number: 1486
# Accuracy on validation dataset: 1928/2400 (80.33%)
#
# Epoch: 4, Batch number: 148
# Accuracy on validation dataset: 1883/2400 (78.46%)
#
# Epoch: 4, Batch number: 648
# Accuracy on validation dataset: 1897/2400 (79.04%)
#
# Epoch: 4, Batch number: 1148
# Accuracy on validation dataset: 1909/2400 (79.54%)
#
# Epoch: 4, Batch number: 1648
# Accuracy on validation dataset: 1936/2400 (80.67%)
#
# Epoch: 5, Batch number: 310
# Accuracy on validation dataset: 1971/2400 (82.12%)
#
# Epoch: 5, Batch number: 810
# Accuracy on validation dataset: 1943/2400 (80.96%)
#
# Epoch: 5, Batch number: 1310
# Accuracy on validation dataset: 1934/2400 (80.58%)
#
# Epoch: 5, Batch number: 1810
# Accuracy on validation dataset: 1939/2400 (80.79%)
#
# Epoch: 6, Batch number: 472
# Accuracy on validation dataset: 1923/2400 (80.12%)
#
# Epoch: 6, Batch number: 972
# Accuracy on validation dataset: 1943/2400 (80.96%)
#
# Epoch: 6, Batch number: 1472
# Accuracy on validation dataset: 1955/2400 (81.46%)
#
# Epoch: 7, Batch number: 134
# Accuracy on validation dataset: 1917/2400 (79.88%)
#
# Epoch: 7, Batch number: 634
# Accuracy on validation dataset: 1946/2400 (81.08%)
#
# Epoch: 7, Batch number: 1134
# Accuracy on validation dataset: 1945/2400 (81.04%)
#
# Epoch: 7, Batch number: 1634
# Accuracy on validation dataset: 1953/2400 (81.38%)
#
# Epoch: 8, Batch number: 296
# Accuracy on validation dataset: 1934/2400 (80.58%)
#
# Epoch: 8, Batch number: 796
# Accuracy on validation dataset: 1948/2400 (81.17%)
#
# Epoch: 8, Batch number: 1296
# Accuracy on validation dataset: 1934/2400 (80.58%)
#
# Epoch: 8, Batch number: 1796
# Accuracy on validation dataset: 1960/2400 (81.67%)
#
# Epoch: 9, Batch number: 458
# Accuracy on validation dataset: 1948/2400 (81.17%)
#
# Epoch: 9, Batch number: 958
# Accuracy on validation dataset: 1935/2400 (80.62%)

# %% [markdown]
# # Entrenamiento de word vectors para clasificación

# %% [markdown]
# ## Pretraining

# %%
class WordEmbeddingAGNewsDataset(torch.utils.data.Dataset):
    
    def __init__(self, root='./AG_NEWS/', preprocess=lambda x: x, n_window=2, train=True):
        
        target = 'train.csv' if train else 'test.csv'
        df = pd.read_csv(root + target, header=None, names=['class_idx', 'title', 'description'])
        data = preprocess(df['title'])
        samples = data.apply(self._get_context, n_window=n_window)
        self.data = pd.DataFrame([[subsample[0], subsample[1]] for sample in samples for subsample in sample],
                                 columns=['word','context'])
    
    def __getitem__(self,idx):
        if type(idx) == torch.Tensor:
            idx = idx.item()
        
        context_vector = self.vectorizer.vectorize(self.data['context'].iloc[idx])
        word_index = self.vectorizer.vocabulary.token_to_index(self.data['word'].iloc[idx])
        return context_vector, word_index
    
    def _get_context(self,sentence,n_window):
        
        no_sentence = '<NS>'
        samples = []
        for i, word in enumerate(sentence):
            first_context_word_index = max(0,i-n_window)
            last_context_word_index = min(i+n_window+1, len(sentence))

            context = [no_sentence for j in range(i-n_window,first_context_word_index)] + \
                      sentence[first_context_word_index:i] + \
                      sentence[i+1:last_context_word_index] + \
                      [no_sentence for j in range(last_context_word_index,i+n_window+1)]
            
            samples.append((word,context))

        return samples
    
    
    def __len__(self):
        return len(self.data)
    
    
def GetAGNewsWordEmbeddingsDataset(root, preprocess, n_window=2, cutoff=25):
    
    # Datasets:
    train_dataset = WordEmbeddingAGNewsDataset(root, preprocess=preprocess, n_window=2, train=True)
    train_dataset.vectorizer = Vectorizer([train_dataset.data['word']], cutoff=cutoff)
    test_dataset = WordEmbeddingAGNewsDataset(root, preprocess=preprocess, n_window=2, train=False)
    test_dataset.vectorizer = train_dataset.vectorizer
    
    # Dataloaders:
    train_dataloader, val_dataloader, test_dataloader = generate_data_batches(train_dataset, 
                                                                              test_dataset,    
                                                                              batch_size=64)
    return train_dataloader, val_dataloader, test_dataloader


def preprocess(data):
    df = data.str.replace(r'\(AP\)','')
    df = df.str.replace(r'\(Reuters\)','')
    df = df.str.replace(r'\(AFP\)','')
    df = df.str.replace(r'\(SPACE\.com\)','')
    df = df.str.replace(r'\ba\b','')
    df = df.str.replace(r'\bthe\b','')
    df = df.str.replace(r'\bis\b','')
    df = df.str.replace(r'\bof\b','')
    df = df.str.replace(r'\bto\b','')
    df = df.str.replace(r'[,:;\?\!\"]','')
    df = df.str.replace(r'\s+','<SEP>')
    df = df.str.replace(r"'s<SEP>","<SEP>'s<SEP>")
    df = df.str.split('<SEP>')
    return df


we_train_dataloader, we_val_dataloader, we_test_dataloader = GetAGNewsWordEmbeddingsDataset(root='./AG_NEWS/', 
                                                                               preprocess=preprocess, 
                                                                               cutoff=25)

# %%
import torch.nn as nn

class Word2VecCBOW(nn.Module):
    
    def __init__(self, vocab_size, n_embeddings):
        super(Word2VecCBOW, self).__init__()
        self.emb = nn.Linear(vocab_size, n_embeddings)
        self.out = nn.Linear(n_embeddings, vocab_size)
        
    def forward(self, x):
        return self.out(self.emb(x))
    
    def loss(self, scores, target):
        lf = nn.CrossEntropyLoss()
        return lf(scores, target)
    

vocab_size = len(we_train_dataloader.dataset.vectorizer.vocabulary)
n_embeddings = 100
EmbeddingModel = Word2VecCBOW(vocab_size, n_embeddings)

# %%
# Parámetros de las muestras:
data = {
    'use_gpu': True, # Trasladar o no las muestras a la GPU
    'input_dtype': torch.float, # Tipo de dato de las muestras de entrada
    'target_dtype': torch.long, # Tipo de dato de las muestras de salida
    'train_dataloader': we_train_dataloader, # Dataset de entrenamiento
    'val_dataloader': we_val_dataloader # Dataset de validación
}

# Parámetros de optimización:
epochs = 20 # Cantidad de epochs
sample_loss_every = 5000 # Cantidad de iteraciones para calcular la cantidad de aciertos
learning_rate = [5e-1, 1e-1, 5e-2] # Tasa de aprendizaje
check_on_train = False # Queremos ver los resultados también en el train set

# Entrenamiento:
models = []
performance_history = []
n_classes = 4
for lr in learning_rate:
    model = Word2VecCBOW(vocab_size, n_embeddings)
    model.load_state_dict(EmbeddingModel.state_dict())
    performance_history.append(SGDTrainModel(model, 
                                             data, 
                                             epochs, 
                                             lr, 
                                             sample_loss_every, 
                                             check_on_train, 
                                             verbose=True))
    models.append(model)
    print('lr={:.2g} completed.'.format(lr))
# Out:
# Epoch: 0, Batch number: 0
# Accuracy on validation dataset: 4/15547 (0.03%)
#
# Epoch: 0, Batch number: 5000
# Accuracy on validation dataset: 364/15547 (2.34%)
#
# Epoch: 0, Batch number: 10000
# Accuracy on validation dataset: 667/15547 (4.29%)
#
# Epoch: 1, Batch number: 3097
# Accuracy on validation dataset: 782/15547 (5.03%)
#
# Epoch: 1, Batch number: 8097
# Accuracy on validation dataset: 898/15547 (5.78%)
#
# Epoch: 2, Batch number: 1194
# Accuracy on validation dataset: 927/15547 (5.96%)
#
# Epoch: 2, Batch number: 6194
# Accuracy on validation dataset: 965/15547 (6.21%)
#
# Epoch: 2, Batch number: 11194
# Accuracy on validation dataset: 1076/15547 (6.92%)
#
# Epoch: 3, Batch number: 4291
# Accuracy on validation dataset: 1137/15547 (7.31%)
#
# Epoch: 3, Batch number: 9291
# Accuracy on validation dataset: 1210/15547 (7.78%)
#
# Epoch: 4, Batch number: 2388
# Accuracy on validation dataset: 1216/15547 (7.82%)
#
# Epoch: 4, Batch number: 7388
# Accuracy on validation dataset: 1263/15547 (8.12%)
#
# Epoch: 5, Batch number: 485
# Accuracy on validation dataset: 1328/15547 (8.54%)
#
# Epoch: 5, Batch number: 5485
# Accuracy on validation dataset: 1377/15547 (8.86%)
#
# Epoch: 5, Batch number: 10485
# Accuracy on validation dataset: 1385/15547 (8.91%)
#
# Epoch: 6, Batch number: 3582
# Accuracy on validation dataset: 1386/15547 (8.91%)
#
# Epoch: 6, Batch number: 8582
# Accuracy on validation dataset: 1455/15547 (9.36%)
#
# Epoch: 7, Batch number: 1679
# Accuracy on validation dataset: 1489/15547 (9.58%)
#
# Epoch: 7, Batch number: 6679
# Accuracy on validation dataset: 1493/15547 (9.60%)
#
# Epoch: 7, Batch number: 11679
# Accuracy on validation dataset: 1560/15547 (10.03%)
#
# Epoch: 8, Batch number: 4776
# Accuracy on validation dataset: 1534/15547 (9.87%)
#
# Epoch: 8, Batch number: 9776
# Accuracy on validation dataset: 1576/15547 (10.14%)
#
# Epoch: 9, Batch number: 2873
# Accuracy on validation dataset: 1555/15547 (10.00%)
#
# Epoch: 9, Batch number: 7873
# Accuracy on validation dataset: 1570/15547 (10.10%)
#
# Epoch: 10, Batch number: 970
# Accuracy on validation dataset: 1607/15547 (10.34%)
#
# Epoch: 10, Batch number: 5970
# Accuracy on validation dataset: 1591/15547 (10.23%)
#
# Epoch: 10, Batch number: 10970
# Accuracy on validation dataset: 1651/15547 (10.62%)
#
# Epoch: 11, Batch number: 4067
# Accuracy on validation dataset: 1615/15547 (10.39%)
#
# Epoch: 11, Batch number: 9067
# Accuracy on validation dataset: 1618/15547 (10.41%)
#
# Epoch: 12, Batch number: 2164
# Accuracy on validation dataset: 1671/15547 (10.75%)
#
# Epoch: 12, Batch number: 7164
# Accuracy on validation dataset: 1627/15547 (10.47%)
#
# Epoch: 13, Batch number: 261
# Accuracy on validation dataset: 1659/15547 (10.67%)
#
# Epoch: 13, Batch number: 5261
# Accuracy on validation dataset: 1636/15547 (10.52%)
#
# Epoch: 13, Batch number: 10261
# Accuracy on validation dataset: 1689/15547 (10.86%)
#
# Epoch: 14, Batch number: 3358
# Accuracy on validation dataset: 1666/15547 (10.72%)
#
# Epoch: 14, Batch number: 8358
# Accuracy on validation dataset: 1704/15547 (10.96%)
#
# Epoch: 15, Batch number: 1455
# Accuracy on validation dataset: 1676/15547 (10.78%)
#
# Epoch: 15, Batch number: 6455
# Accuracy on validation dataset: 1718/15547 (11.05%)
#
# Epoch: 15, Batch number: 11455
# Accuracy on validation dataset: 1736/15547 (11.17%)
#
# Epoch: 16, Batch number: 4552
# Accuracy on validation dataset: 1689/15547 (10.86%)
#
# Epoch: 16, Batch number: 9552
# Accuracy on validation dataset: 1741/15547 (11.20%)
#
# Epoch: 17, Batch number: 2649
# Accuracy on validation dataset: 1721/15547 (11.07%)
#
# Epoch: 17, Batch number: 7649
# Accuracy on validation dataset: 1726/15547 (11.10%)
#
# Epoch: 18, Batch number: 746
# Accuracy on validation dataset: 1753/15547 (11.28%)
#
# Epoch: 18, Batch number: 5746
# Accuracy on validation dataset: 1740/15547 (11.19%)
#
# Epoch: 18, Batch number: 10746
# Accuracy on validation dataset: 1728/15547 (11.11%)
#
# Epoch: 19, Batch number: 3843
# Accuracy on validation dataset: 1709/15547 (10.99%)
#
# Epoch: 19, Batch number: 8843
# Accuracy on validation dataset: 1724/15547 (11.09%)
#
# lr=0.5 completed.
# Epoch: 0, Batch number: 0
# Accuracy on validation dataset: 0/15547 (0.00%)
#
# Epoch: 0, Batch number: 5000
# Accuracy on validation dataset: 366/15547 (2.35%)
#
# Epoch: 0, Batch number: 10000
# Accuracy on validation dataset: 345/15547 (2.22%)
#
# Epoch: 1, Batch number: 3097
# Accuracy on validation dataset: 457/15547 (2.94%)
#
# Epoch: 1, Batch number: 8097
# Accuracy on validation dataset: 446/15547 (2.87%)
#
# Epoch: 2, Batch number: 1194
# Accuracy on validation dataset: 494/15547 (3.18%)
#
# Epoch: 2, Batch number: 6194
# Accuracy on validation dataset: 505/15547 (3.25%)
#
# Epoch: 2, Batch number: 11194
# Accuracy on validation dataset: 462/15547 (2.97%)
#
# Epoch: 3, Batch number: 4291
# Accuracy on validation dataset: 611/15547 (3.93%)
#
# Epoch: 3, Batch number: 9291
# Accuracy on validation dataset: 694/15547 (4.46%)
#
# Epoch: 4, Batch number: 2388
# Accuracy on validation dataset: 695/15547 (4.47%)
#
# Epoch: 4, Batch number: 7388
# Accuracy on validation dataset: 731/15547 (4.70%)
#
# Epoch: 5, Batch number: 485
# Accuracy on validation dataset: 761/15547 (4.89%)
#
# Epoch: 5, Batch number: 5485
# Accuracy on validation dataset: 799/15547 (5.14%)
#
# Epoch: 5, Batch number: 10485
# Accuracy on validation dataset: 823/15547 (5.29%)
#
# Epoch: 6, Batch number: 3582
# Accuracy on validation dataset: 836/15547 (5.38%)
#
# Epoch: 6, Batch number: 8582
# Accuracy on validation dataset: 859/15547 (5.53%)
#
# Epoch: 7, Batch number: 1679
# Accuracy on validation dataset: 881/15547 (5.67%)
#
# Epoch: 7, Batch number: 6679
# Accuracy on validation dataset: 901/15547 (5.80%)
#
# Epoch: 7, Batch number: 11679
# Accuracy on validation dataset: 906/15547 (5.83%)
#
# Epoch: 8, Batch number: 4776
# Accuracy on validation dataset: 924/15547 (5.94%)
#
# Epoch: 8, Batch number: 9776
# Accuracy on validation dataset: 957/15547 (6.16%)
#
# Epoch: 9, Batch number: 2873
# Accuracy on validation dataset: 959/15547 (6.17%)
#
# Epoch: 9, Batch number: 7873
# Accuracy on validation dataset: 985/15547 (6.34%)
#
# Epoch: 10, Batch number: 970
# Accuracy on validation dataset: 1018/15547 (6.55%)
#
# Epoch: 10, Batch number: 5970
# Accuracy on validation dataset: 1027/15547 (6.61%)
#
# Epoch: 10, Batch number: 10970
# Accuracy on validation dataset: 999/15547 (6.43%)
#
# Epoch: 11, Batch number: 4067
# Accuracy on validation dataset: 1047/15547 (6.73%)
#
# Epoch: 11, Batch number: 9067
# Accuracy on validation dataset: 1071/15547 (6.89%)
#
# Epoch: 12, Batch number: 2164
# Accuracy on validation dataset: 1072/15547 (6.90%)
#
# Epoch: 12, Batch number: 7164
# Accuracy on validation dataset: 1078/15547 (6.93%)
#
# Epoch: 13, Batch number: 261
# Accuracy on validation dataset: 1111/15547 (7.15%)
#
# Epoch: 13, Batch number: 5261
# Accuracy on validation dataset: 1108/15547 (7.13%)
#
# Epoch: 13, Batch number: 10261
# Accuracy on validation dataset: 1090/15547 (7.01%)
#
# Epoch: 14, Batch number: 3358
# Accuracy on validation dataset: 1129/15547 (7.26%)
#
# Epoch: 14, Batch number: 8358
# Accuracy on validation dataset: 1133/15547 (7.29%)
#
# Epoch: 15, Batch number: 1455
# Accuracy on validation dataset: 1105/15547 (7.11%)
#
# Epoch: 15, Batch number: 6455
# Accuracy on validation dataset: 1166/15547 (7.50%)
#
# Epoch: 15, Batch number: 11455
# Accuracy on validation dataset: 1171/15547 (7.53%)
#
# Epoch: 16, Batch number: 4552
# Accuracy on validation dataset: 1177/15547 (7.57%)
#
# Epoch: 16, Batch number: 9552
# Accuracy on validation dataset: 1215/15547 (7.82%)
#
# Epoch: 17, Batch number: 2649
# Accuracy on validation dataset: 1218/15547 (7.83%)
#
# Epoch: 17, Batch number: 7649
# Accuracy on validation dataset: 1220/15547 (7.85%)
#
# Epoch: 18, Batch number: 746
# Accuracy on validation dataset: 1213/15547 (7.80%)
#
# Epoch: 18, Batch number: 5746
# Accuracy on validation dataset: 1238/15547 (7.96%)
#
# Epoch: 18, Batch number: 10746
# Accuracy on validation dataset: 1259/15547 (8.10%)
#
# Epoch: 19, Batch number: 3843
# Accuracy on validation dataset: 1247/15547 (8.02%)
#
# Epoch: 19, Batch number: 8843
# Accuracy on validation dataset: 1262/15547 (8.12%)
#
# lr=0.1 completed.
# Epoch: 0, Batch number: 0
# Accuracy on validation dataset: 0/15547 (0.00%)
#
# Epoch: 0, Batch number: 5000
# Accuracy on validation dataset: 295/15547 (1.90%)
#
# Epoch: 0, Batch number: 10000
# Accuracy on validation dataset: 297/15547 (1.91%)
#
# Epoch: 1, Batch number: 3097
# Accuracy on validation dataset: 321/15547 (2.06%)
#
# Epoch: 1, Batch number: 8097
# Accuracy on validation dataset: 430/15547 (2.77%)
# Epoch: 2, Batch number: 1194
# Accuracy on validation dataset: 362/15547 (2.33%)
#
# Epoch: 2, Batch number: 6194
# Accuracy on validation dataset: 372/15547 (2.39%)
#
# Epoch: 2, Batch number: 11194
# Accuracy on validation dataset: 362/15547 (2.33%)
#
# Epoch: 3, Batch number: 4291
# Accuracy on validation dataset: 399/15547 (2.57%)
#
# Epoch: 3, Batch number: 9291
# Accuracy on validation dataset: 457/15547 (2.94%)
#
# Epoch: 4, Batch number: 2388
# Accuracy on validation dataset: 494/15547 (3.18%)
#
# Epoch: 4, Batch number: 7388
# Accuracy on validation dataset: 496/15547 (3.19%)
#
# Epoch: 5, Batch number: 485
# Accuracy on validation dataset: 546/15547 (3.51%)
#
# Epoch: 5, Batch number: 5485
# Accuracy on validation dataset: 588/15547 (3.78%)
#
# Epoch: 5, Batch number: 10485
# Accuracy on validation dataset: 600/15547 (3.86%)
#
# Epoch: 6, Batch number: 3582
# Accuracy on validation dataset: 614/15547 (3.95%)
#
# Epoch: 6, Batch number: 8582
# Accuracy on validation dataset: 654/15547 (4.21%)
#
# Epoch: 7, Batch number: 1679
# Accuracy on validation dataset: 659/15547 (4.24%)
#
# Epoch: 7, Batch number: 6679
# Accuracy on validation dataset: 695/15547 (4.47%)
#
# Epoch: 7, Batch number: 11679
# Accuracy on validation dataset: 702/15547 (4.52%)
#
# Epoch: 8, Batch number: 4776
# Accuracy on validation dataset: 722/15547 (4.64%)
#
# Epoch: 8, Batch number: 9776
# Accuracy on validation dataset: 751/15547 (4.83%)
#
# Epoch: 9, Batch number: 2873
# Accuracy on validation dataset: 757/15547 (4.87%)
#
# Epoch: 9, Batch number: 7873
# Accuracy on validation dataset: 769/15547 (4.95%)
#
# Epoch: 10, Batch number: 970
# Accuracy on validation dataset: 783/15547 (5.04%)
#
# Epoch: 10, Batch number: 5970
# Accuracy on validation dataset: 763/15547 (4.91%)
#
# Epoch: 10, Batch number: 10970
# Accuracy on validation dataset: 806/15547 (5.18%)
#
# Epoch: 11, Batch number: 4067
# Accuracy on validation dataset: 815/15547 (5.24%)
#
# Epoch: 11, Batch number: 9067
# Accuracy on validation dataset: 827/15547 (5.32%)
#
# Epoch: 12, Batch number: 2164
# Accuracy on validation dataset: 841/15547 (5.41%)
#
# Epoch: 12, Batch number: 7164
# Accuracy on validation dataset: 865/15547 (5.56%)
#
# Epoch: 13, Batch number: 261
# Accuracy on validation dataset: 842/15547 (5.42%)
#
# Epoch: 13, Batch number: 5261
# Accuracy on validation dataset: 868/15547 (5.58%)
#
# Epoch: 13, Batch number: 10261
# Accuracy on validation dataset: 893/15547 (5.74%)
#
# Epoch: 14, Batch number: 3358
# Accuracy on validation dataset: 888/15547 (5.71%)
#
# Epoch: 14, Batch number: 8358
# Accuracy on validation dataset: 906/15547 (5.83%)
#
# Epoch: 15, Batch number: 1455
# Accuracy on validation dataset: 876/15547 (5.63%)
#
# Epoch: 15, Batch number: 6455
# Accuracy on validation dataset: 923/15547 (5.94%)
#
# Epoch: 15, Batch number: 11455
# Accuracy on validation dataset: 934/15547 (6.01%)
#
# Epoch: 16, Batch number: 4552
# Accuracy on validation dataset: 926/15547 (5.96%)
#
# Epoch: 16, Batch number: 9552
# Accuracy on validation dataset: 935/15547 (6.01%)
#
# Epoch: 17, Batch number: 2649
# Accuracy on validation dataset: 934/15547 (6.01%)
#
# Epoch: 17, Batch number: 7649
# Accuracy on validation dataset: 964/15547 (6.20%)
#
# Epoch: 18, Batch number: 746
# Accuracy on validation dataset: 970/15547 (6.24%)
#
# Epoch: 18, Batch number: 5746
# Accuracy on validation dataset: 985/15547 (6.34%)
#
# Epoch: 18, Batch number: 10746
# Accuracy on validation dataset: 1010/15547 (6.50%)
#
# Epoch: 19, Batch number: 3843
# Accuracy on validation dataset: 987/15547 (6.35%)
#
# Epoch: 19, Batch number: 8843
# Accuracy on validation dataset: 1023/15547 (6.58%)
#
# lr=0.05 completed.

# %%
fig, ax = plt.subplots()
for lr, ph in zip(learning_rate, performance_history):
    ax.plot(ph['iter'],ph['loss'],label='lr={:.2g}'.format(lr))
    
ax.legend()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %% [markdown]
# ## Finetuning

# %%
class AGNewsDataset(torch.utils.data.Dataset):
    
    def __init__(self, root='./AG_NEWS/', preprocess=lambda x: x, train=True):
        
        target = 'train.csv' if train else 'test.csv'
        df = pd.read_csv(root + target, header=None, names=['class_idx', 'title', 'description'])
        
        # Etiquetas:
        self.cls_indeces = torch.tensor(df['class_idx'].tolist(), dtype=torch.long) - 1
        
        # DataSeries con las muestras de entradas:
        data = df['title']
        self.data = preprocess(data)
    
    def __getitem__(self,idx):
        if type(idx) == torch.Tensor:
            idx = idx.item()
        return self.vectorizer.vectorize(self.data.iloc[idx]), self.cls_indeces[idx]
    
    def __len__(self):
        return len(self.cls_indeces)
    
    
def GetAGNewsDataset(root, preprocess, cutoff=25):
    
    # Datasets:
    train_dataset = AGNewsDataset(root, preprocess=preprocess, train=True)
    train_dataset.vectorizer = Vectorizer([train_dataset.data], cutoff=cutoff)
    test_dataset = AGNewsDataset(root, preprocess=preprocess, train=False)
    test_dataset.vectorizer = train_dataset.vectorizer
    
    # Dataloaders:
    train_dataloader, val_dataloader, test_dataloader = generate_data_batches(train_dataset, 
                                                                              test_dataset,    
                                                                              batch_size=64)
    return train_dataloader, val_dataloader, test_dataloader

# %%
tc_train_dataloader, tc_val_dataloader, tc_test_dataloader = GetAGNewsDataset(root='./AG_NEWS/', 
                                                                     preprocess=preprocess, 
                                                                     cutoff=25)

import torch.nn as nn

class TextClassifier(nn.Module):
    
    def __init__(self, EmbeddingLayer, n_classes):
        super(TextClassifier, self).__init__()
        self.emb = nn.Linear(EmbeddingLayer.in_features, EmbeddingLayer.out_features)
        self.out = nn.Linear(EmbeddingLayer.out_features, n_classes)
        
    def forward(self, x):
        return self.out(self.emb(x))
    
    def loss(self, scores, target):
        lf = nn.CrossEntropyLoss()
        return lf(scores, target)

# %%
# Parámetros de las muestras:
data = {
    'use_gpu': True, # Trasladar o no las muestras a la GPU
    'input_dtype': torch.float, # Tipo de dato de las muestras de entrada
    'target_dtype': torch.long, # Tipo de dato de las muestras de salida
    'train_dataloader': tc_train_dataloader, # Dataset de entrenamiento
    'val_dataloader': tc_val_dataloader # Dataset de validación
}

# Parámetros de optimización:
epochs = 20 # Cantidad de epochs
sample_loss_every = 500 # Cantidad de iteraciones para calcular la cantidad de aciertos
learning_rate = [1, 5e-1] # Tasa de aprendizaje
check_on_train = False # Queremos ver los resultados también en el train set

# Entrenamiento:
performance_history = []
n_classes = 4
BestEmbeddingModel = models[0]
classification_models = []
ClassifierModel = TextClassifier(BestEmbeddingModel.emb, n_classes)
ClassifierModel.load_state_dict({
    'emb.weight': BestEmbeddingModel.state_dict()['emb.weight'],
    'emb.bias': BestEmbeddingModel.state_dict()['emb.bias'],
    'out.weight': ClassifierModel.state_dict()['out.weight'],
    'out.bias': ClassifierModel.state_dict()['out.bias']
})
for lr in learning_rate:
    model = TextClassifier(BestEmbeddingModel.emb, n_classes)
    model.load_state_dict(ClassifierModel.state_dict())
    for param in model.emb.parameters():
        param.requires_grad = False
    performance_history.append(SGDTrainModel(model, 
                                             data, 
                                             epochs, 
                                             lr, 
                                             sample_loss_every, 
                                             check_on_train, 
                                             verbose=True))
    classification_models.append(model)
    print('lr={:.2g} completed.'.format(lr))
# Out:
# Epoch: 0, Batch number: 0
# Accuracy on validation dataset: 1420/2400 (59.17%)
#
# Epoch: 0, Batch number: 500
# Accuracy on validation dataset: 1768/2400 (73.67%)
#
# Epoch: 0, Batch number: 1000
# Accuracy on validation dataset: 1811/2400 (75.46%)
#
# Epoch: 0, Batch number: 1500
# Accuracy on validation dataset: 1800/2400 (75.00%)
#
# Epoch: 1, Batch number: 162
# Accuracy on validation dataset: 1812/2400 (75.50%)
#
# Epoch: 1, Batch number: 662
# Accuracy on validation dataset: 1819/2400 (75.79%)
#
# Epoch: 1, Batch number: 1162
# Accuracy on validation dataset: 1865/2400 (77.71%)
#
# Epoch: 1, Batch number: 1662
# Accuracy on validation dataset: 1870/2400 (77.92%)
#
# Epoch: 2, Batch number: 324
# Accuracy on validation dataset: 1853/2400 (77.21%)
#
# Epoch: 2, Batch number: 824
# Accuracy on validation dataset: 1844/2400 (76.83%)
#
# Epoch: 2, Batch number: 1324
# Accuracy on validation dataset: 1895/2400 (78.96%)
#
# Epoch: 2, Batch number: 1824
# Accuracy on validation dataset: 1911/2400 (79.62%)
#
# Epoch: 3, Batch number: 486
# Accuracy on validation dataset: 1889/2400 (78.71%)
#
# Epoch: 3, Batch number: 986
# Accuracy on validation dataset: 1854/2400 (77.25%)
#
# Epoch: 3, Batch number: 1486
# Accuracy on validation dataset: 1896/2400 (79.00%)
#
# Epoch: 4, Batch number: 148
# Accuracy on validation dataset: 1890/2400 (78.75%)
#
# Epoch: 4, Batch number: 648
# Accuracy on validation dataset: 1853/2400 (77.21%)
#
# Epoch: 4, Batch number: 1148
# Accuracy on validation dataset: 1845/2400 (76.88%)
#
# Epoch: 4, Batch number: 1648
# Accuracy on validation dataset: 1901/2400 (79.21%)
#
# Epoch: 5, Batch number: 310
# Accuracy on validation dataset: 1917/2400 (79.88%)
#
# Epoch: 5, Batch number: 810
# Accuracy on validation dataset: 1901/2400 (79.21%)
#
# Epoch: 5, Batch number: 1310
# Accuracy on validation dataset: 1878/2400 (78.25%)
#
# Epoch: 5, Batch number: 1810
# Accuracy on validation dataset: 1899/2400 (79.12%)
#
# Epoch: 6, Batch number: 472
# Accuracy on validation dataset: 1904/2400 (79.33%)
#
# Epoch: 6, Batch number: 972
# Accuracy on validation dataset: 1922/2400 (80.08%)
#
# Epoch: 6, Batch number: 1472
# Accuracy on validation dataset: 1906/2400 (79.42%)
#
# Epoch: 7, Batch number: 134
# Accuracy on validation dataset: 1912/2400 (79.67%)
#
# Epoch: 7, Batch number: 634
# Accuracy on validation dataset: 1913/2400 (79.71%)
#
# Epoch: 7, Batch number: 1134
# Accuracy on validation dataset: 1917/2400 (79.88%)
#
# Epoch: 7, Batch number: 1634
# Accuracy on validation dataset: 1900/2400 (79.17%)
#
# Epoch: 8, Batch number: 296
# Accuracy on validation dataset: 1903/2400 (79.29%)
#
# Epoch: 8, Batch number: 796
# Accuracy on validation dataset: 1926/2400 (80.25%)
#
# Epoch: 8, Batch number: 1296
# Accuracy on validation dataset: 1925/2400 (80.21%)
#
# Epoch: 8, Batch number: 1796
# Accuracy on validation dataset: 1874/2400 (78.08%)
#
# Epoch: 9, Batch number: 458
# Accuracy on validation dataset: 1933/2400 (80.54%)
#
# Epoch: 9, Batch number: 958
# Accuracy on validation dataset: 1939/2400 (80.79%)
#
# Epoch: 9, Batch number: 1458
# Accuracy on validation dataset: 1915/2400 (79.79%)
#
# Epoch: 10, Batch number: 120
# Accuracy on validation dataset: 1913/2400 (79.71%)
#
# Epoch: 10, Batch number: 620
# Accuracy on validation dataset: 1946/2400 (81.08%)
#
# Epoch: 10, Batch number: 1120
# Accuracy on validation dataset: 1925/2400 (80.21%)
#
# Epoch: 10, Batch number: 1620
# Accuracy on validation dataset: 1911/2400 (79.62%)
#
# Epoch: 11, Batch number: 282
# Accuracy on validation dataset: 1903/2400 (79.29%)
#
# Epoch: 11, Batch number: 782
# Accuracy on validation dataset: 1918/2400 (79.92%)
#
# Epoch: 11, Batch number: 1282
# Accuracy on validation dataset: 1882/2400 (78.42%)
#
# Epoch: 11, Batch number: 1782
# Accuracy on validation dataset: 1923/2400 (80.12%)
#
# Epoch: 12, Batch number: 444
# Accuracy on validation dataset: 1923/2400 (80.12%)
#
# Epoch: 12, Batch number: 944
# Accuracy on validation dataset: 1926/2400 (80.25%)
#
# Epoch: 12, Batch number: 1444
# Accuracy on validation dataset: 1919/2400 (79.96%)
#
# Epoch: 13, Batch number: 106
# Accuracy on validation dataset: 1912/2400 (79.67%)
#
# Epoch: 13, Batch number: 606
# Accuracy on validation dataset: 1944/2400 (81.00%)
#
# Epoch: 13, Batch number: 1106
# Accuracy on validation dataset: 1922/2400 (80.08%)
#
# Epoch: 13, Batch number: 1606
# Accuracy on validation dataset: 1900/2400 (79.17%)
#
# Epoch: 14, Batch number: 268
# Accuracy on validation dataset: 1932/2400 (80.50%)
#
# Epoch: 14, Batch number: 768
# Accuracy on validation dataset: 1935/2400 (80.62%)
#
# Epoch: 14, Batch number: 1268
# Accuracy on validation dataset: 1926/2400 (80.25%)
#
# Epoch: 14, Batch number: 1768
# Accuracy on validation dataset: 1915/2400 (79.79%)
#
# Epoch: 15, Batch number: 430
# Accuracy on validation dataset: 1929/2400 (80.38%)
#
# Epoch: 15, Batch number: 930
# Accuracy on validation dataset: 1890/2400 (78.75%)
#
# Epoch: 15, Batch number: 1430
# Accuracy on validation dataset: 1937/2400 (80.71%)
#
# Epoch: 16, Batch number: 92
# Accuracy on validation dataset: 1904/2400 (79.33%)
#
# Epoch: 16, Batch number: 592
# Accuracy on validation dataset: 1923/2400 (80.12%)
#
# Epoch: 16, Batch number: 1092
# Accuracy on validation dataset: 1938/2400 (80.75%)
#
# Epoch: 16, Batch number: 1592
# Accuracy on validation dataset: 1961/2400 (81.71%)
#
# Epoch: 17, Batch number: 254
# Accuracy on validation dataset: 1928/2400 (80.33%)
#
# Epoch: 17, Batch number: 754
# Accuracy on validation dataset: 1912/2400 (79.67%)
#
# Epoch: 17, Batch number: 1254
# Accuracy on validation dataset: 1938/2400 (80.75%)
#
# Epoch: 17, Batch number: 1754
# Accuracy on validation dataset: 1957/2400 (81.54%)
#
# Epoch: 18, Batch number: 416
# Accuracy on validation dataset: 1935/2400 (80.62%)
#
# Epoch: 18, Batch number: 916
# Accuracy on validation dataset: 1924/2400 (80.17%)
#
# Epoch: 18, Batch number: 1416
# Accuracy on validation dataset: 1937/2400 (80.71%)
#
# Epoch: 19, Batch number: 78
# Accuracy on validation dataset: 1948/2400 (81.17%)
#
# Epoch: 19, Batch number: 578
# Accuracy on validation dataset: 1943/2400 (80.96%)
#
# Epoch: 19, Batch number: 1078
# Accuracy on validation dataset: 1901/2400 (79.21%)
#
# Epoch: 19, Batch number: 1578
# Accuracy on validation dataset: 1902/2400 (79.25%)
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-18-67266ea19c6b> in <module>
#      38                                              check_on_train,
#      39                                              verbose=True))
# ---> 40     classification_model.append(model)
#      41     print('lr={:.2g} completed.'.format(lr))
#
# NameError: name 'classification_model' is not defined

# %%
fig, ax = plt.subplots()
for lr, ph in zip(learning_rate, performance_history):
    ax.plot(ph['iter'],ph['loss'],label='lr={:.2g}'.format(lr))
    
ax.legend()
# Out:
# <img src="data:image/png;base64,..." width="640">
