# %%
import torch
import pandas as pd
from TorchDataUtils import *
from NLPDataUtils import *

# %matplotlib notebook
import matplotlib.pyplot as plt

# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %% [markdown]
# # Entrenamiento de word vectors para clasificación

# %% [markdown]
# ## Pretraining

# %%
class WordEmbeddingAGNewsDataset(torch.utils.data.Dataset):
    
    def __init__(self, root='./AG_NEWS/', preprocess=lambda x: x, n_window=2, train=True):
        
        target = 'train.csv' if train else 'test.csv'
        df = pd.read_csv(root + target, header=None, names=['class_idx', 'title', 'description'])
        data = preprocess(df['title'])
        samples = data.apply(self._get_context, n_window=n_window)
        self.data = pd.DataFrame([[subsample[0], subsample[1]] for sample in samples for subsample in sample],
                                 columns=['word','context'])
    
    def __getitem__(self,idx):
        if type(idx) == torch.Tensor:
            idx = idx.item()
        
        context_vector = self.vectorizer.vectorize(self.data['context'].iloc[idx])
        word_index = self.vectorizer.vocabulary.token_to_index(self.data['word'].iloc[idx])
        return context_vector, word_index
    
    def _get_context(self,sentence,n_window):
        
        no_sentence = '<NS>'
        samples = []
        for i, word in enumerate(sentence):
            first_context_word_index = max(0,i-n_window)
            last_context_word_index = min(i+n_window+1, len(sentence))

            context = [no_sentence for j in range(i-n_window,first_context_word_index)] + \
                      sentence[first_context_word_index:i] + \
                      sentence[i+1:last_context_word_index] + \
                      [no_sentence for j in range(last_context_word_index,i+n_window+1)]
            
            samples.append((word,context))

        return samples
    
    
    def __len__(self):
        return len(self.data)
    
    
def GetAGNewsWordEmbeddingsDataset(root, preprocess, n_window=2, cutoff=25):
    
    # Datasets:
    train_dataset = WordEmbeddingAGNewsDataset(root, preprocess=preprocess, n_window=2, train=True)
    train_dataset.vectorizer = Vectorizer([train_dataset.data['word']], cutoff=cutoff)
    test_dataset = WordEmbeddingAGNewsDataset(root, preprocess=preprocess, n_window=2, train=False)
    test_dataset.vectorizer = train_dataset.vectorizer
    
    # Dataloaders:
    train_dataloader, val_dataloader, test_dataloader = generate_data_batches(train_dataset, 
                                                                              test_dataset,    
                                                                              batch_size=64)
    return train_dataloader, val_dataloader, test_dataloader


def preprocess(data):
    df = data.str.replace(r'\(AP\)','')
    df = df.str.replace(r'\(Reuters\)','')
    df = df.str.replace(r'\(AFP\)','')
    df = df.str.replace(r'\(SPACE\.com\)','')
    df = df.str.replace(r'\ba\b','')
    df = df.str.replace(r'\bthe\b','')
    df = df.str.replace(r'\bis\b','')
    df = df.str.replace(r'\bof\b','')
    df = df.str.replace(r'\bto\b','')
    df = df.str.replace(r'[,:;\?\!\"]','')
    df = df.str.replace(r'\s+','<SEP>')
    df = df.str.replace(r"'s<SEP>","<SEP>'s<SEP>")
    df = df.str.split('<SEP>')
    return df


we_train_dataloader, we_val_dataloader, we_test_dataloader = GetAGNewsWordEmbeddingsDataset(root='./AG_NEWS/', 
                                                                               preprocess=preprocess, 
                                                                               cutoff=25)

# %%
import torch.nn as nn

class Word2VecCBOW(nn.Module):
    
    def __init__(self, vocab_size, n_embeddings):
        super(Word2VecCBOW, self).__init__()
        self.emb = nn.Linear(vocab_size, n_embeddings)
        self.out = nn.Linear(n_embeddings, vocab_size)
        
    def forward(self, x):
        return self.out(self.emb(x))
    
    def loss(self, scores, target):
        lf = nn.CrossEntropyLoss()
        return lf(scores, target)
    

vocab_size = len(we_train_dataloader.dataset.vectorizer.vocabulary)
n_embeddings = 100
EmbeddingModel = Word2VecCBOW(vocab_size, n_embeddings)

# %%
# Parámetros de las muestras:
data = {
    'use_gpu': True, # Trasladar o no las muestras a la GPU
    'input_dtype': torch.float, # Tipo de dato de las muestras de entrada
    'target_dtype': torch.long, # Tipo de dato de las muestras de salida
    'train_dataloader': we_train_dataloader, # Dataset de entrenamiento
    'val_dataloader': we_val_dataloader # Dataset de validación
}

# Parámetros de optimización:
epochs = 10 # Cantidad de epochs
sample_loss_every = 500 # Cantidad de iteraciones para calcular la cantidad de aciertos
learning_rate = [1e-1, 1e-2] # Tasa de aprendizaje
check_on_train = False # Queremos ver los resultados también en el train set

# Entrenamiento:
performance_history = []
for lr in learning_rate:
    EmbeddingModel = Word2VecCBOW(vocab_size, n_embeddings)
    performance_history.append(SGDTrainModel(EmbeddingModel, 
                                             data, 
                                             epochs, 
                                             lr, 
                                             sample_loss_every, 
                                             check_on_train, 
                                             verbose=True))
    print('lr={:.2g} completed.'.format(lr))
# Out:
# Epoch: 0, Batch number: 0
# Accuracy on validation dataset: 0/15547 (0.00%)
#
# Epoch: 0, Batch number: 500
# Accuracy on validation dataset: 322/15547 (2.07%)
#
# Epoch: 0, Batch number: 1000
# Accuracy on validation dataset: 322/15547 (2.07%)
#
# Epoch: 0, Batch number: 1500
# Accuracy on validation dataset: 297/15547 (1.91%)
#
# Epoch: 0, Batch number: 2000
# Accuracy on validation dataset: 322/15547 (2.07%)
#
# Epoch: 0, Batch number: 2500
# Accuracy on validation dataset: 322/15547 (2.07%)
#
# Epoch: 0, Batch number: 3000
# Accuracy on validation dataset: 220/15547 (1.42%)
#
# Epoch: 0, Batch number: 3500
# Accuracy on validation dataset: 322/15547 (2.07%)
#
# Epoch: 0, Batch number: 4000
# Accuracy on validation dataset: 322/15547 (2.07%)
#
# Epoch: 0, Batch number: 4500
# Accuracy on validation dataset: 335/15547 (2.15%)
#
# Epoch: 0, Batch number: 5000
# Accuracy on validation dataset: 322/15547 (2.07%)
#
# Epoch: 0, Batch number: 5500
# Accuracy on validation dataset: 322/15547 (2.07%)
#
# Epoch: 0, Batch number: 6000
# Accuracy on validation dataset: 338/15547 (2.17%)
#
# Epoch: 0, Batch number: 6500
# Accuracy on validation dataset: 235/15547 (1.51%)
#
# Epoch: 0, Batch number: 7000
# Accuracy on validation dataset: 331/15547 (2.13%)
#
# Epoch: 0, Batch number: 7500
# Accuracy on validation dataset: 433/15547 (2.79%)
#
# Epoch: 0, Batch number: 8000
# Accuracy on validation dataset: 446/15547 (2.87%)
#
# Epoch: 0, Batch number: 8500
# Accuracy on validation dataset: 339/15547 (2.18%)
#
# Epoch: 0, Batch number: 9000
# Accuracy on validation dataset: 225/15547 (1.45%)
#
# Epoch: 0, Batch number: 9500
# Accuracy on validation dataset: 335/15547 (2.15%)
#
# Epoch: 0, Batch number: 10000
# Accuracy on validation dataset: 299/15547 (1.92%)
#
# Epoch: 0, Batch number: 10500
# Accuracy on validation dataset: 406/15547 (2.61%)
#
# Epoch: 0, Batch number: 11000
# Accuracy on validation dataset: 351/15547 (2.26%)
#
# Epoch: 0, Batch number: 11500
# Accuracy on validation dataset: 419/15547 (2.70%)
#
# Epoch: 1, Batch number: 97
# Accuracy on validation dataset: 367/15547 (2.36%)
#
# Epoch: 1, Batch number: 597
# Accuracy on validation dataset: 441/15547 (2.84%)
#
# Epoch: 1, Batch number: 1097
# Accuracy on validation dataset: 366/15547 (2.35%)
#
# Epoch: 1, Batch number: 1597
# Accuracy on validation dataset: 421/15547 (2.71%)
#
# Epoch: 1, Batch number: 2097
# Accuracy on validation dataset: 400/15547 (2.57%)
#
# Epoch: 1, Batch number: 2597
# Accuracy on validation dataset: 374/15547 (2.41%)
#
# Epoch: 1, Batch number: 3097
# Accuracy on validation dataset: 234/15547 (1.51%)
#
# Epoch: 1, Batch number: 3597
# Accuracy on validation dataset: 342/15547 (2.20%)
#
# Epoch: 1, Batch number: 4097
# Accuracy on validation dataset: 361/15547 (2.32%)
#
# Epoch: 1, Batch number: 4597
# Accuracy on validation dataset: 319/15547 (2.05%)
#
# Epoch: 1, Batch number: 5097
# Accuracy on validation dataset: 355/15547 (2.28%)
#
# Epoch: 1, Batch number: 5597
# Accuracy on validation dataset: 356/15547 (2.29%)
#
# Epoch: 1, Batch number: 6097
# Accuracy on validation dataset: 474/15547 (3.05%)
#
# Epoch: 1, Batch number: 6597
# Accuracy on validation dataset: 430/15547 (2.77%)
#
# Epoch: 1, Batch number: 7097
# Accuracy on validation dataset: 412/15547 (2.65%)
#
# Epoch: 1, Batch number: 7597
# Accuracy on validation dataset: 462/15547 (2.97%)
#
# Epoch: 1, Batch number: 8097
# Accuracy on validation dataset: 439/15547 (2.82%)
#
# Epoch: 1, Batch number: 8597
# Accuracy on validation dataset: 470/15547 (3.02%)
#
# Epoch: 1, Batch number: 9097
# Accuracy on validation dataset: 451/15547 (2.90%)
#
# Epoch: 1, Batch number: 9597
# Accuracy on validation dataset: 377/15547 (2.42%)
#
# Epoch: 1, Batch number: 10097
# Accuracy on validation dataset: 408/15547 (2.62%)
#
# Epoch: 1, Batch number: 10597
# Accuracy on validation dataset: 394/15547 (2.53%)
#
# Epoch: 1, Batch number: 11097
# Accuracy on validation dataset: 402/15547 (2.59%)
#
# Epoch: 1, Batch number: 11597
# Accuracy on validation dataset: 416/15547 (2.68%)
#
# Epoch: 2, Batch number: 194
# Accuracy on validation dataset: 488/15547 (3.14%)
#
# Epoch: 2, Batch number: 694
# Accuracy on validation dataset: 481/15547 (3.09%)
#
# Epoch: 2, Batch number: 1194
# Accuracy on validation dataset: 407/15547 (2.62%)
#
# Epoch: 2, Batch number: 1694
# Accuracy on validation dataset: 401/15547 (2.58%)
#
# Epoch: 2, Batch number: 2194
# Accuracy on validation dataset: 516/15547 (3.32%)
#
# Epoch: 2, Batch number: 2694
# Accuracy on validation dataset: 524/15547 (3.37%)
#
# Epoch: 2, Batch number: 3194
# Accuracy on validation dataset: 441/15547 (2.84%)
#
# Epoch: 2, Batch number: 3694
# Accuracy on validation dataset: 477/15547 (3.07%)
#
# Epoch: 2, Batch number: 4194
# Accuracy on validation dataset: 565/15547 (3.63%)
#
# Epoch: 2, Batch number: 4694
# Accuracy on validation dataset: 576/15547 (3.70%)
#
# Epoch: 2, Batch number: 5194
# Accuracy on validation dataset: 533/15547 (3.43%)
#
# Epoch: 2, Batch number: 5694
# Accuracy on validation dataset: 490/15547 (3.15%)
#
# Epoch: 2, Batch number: 6194
# Accuracy on validation dataset: 512/15547 (3.29%)
#
# Epoch: 2, Batch number: 6694
# Accuracy on validation dataset: 546/15547 (3.51%)
#
# Epoch: 2, Batch number: 7194
# Accuracy on validation dataset: 581/15547 (3.74%)
#
# Epoch: 2, Batch number: 7694
# Accuracy on validation dataset: 426/15547 (2.74%)
#
# Epoch: 2, Batch number: 8194
# Accuracy on validation dataset: 606/15547 (3.90%)
#
# Epoch: 2, Batch number: 8694
# Accuracy on validation dataset: 638/15547 (4.10%)
#
# Epoch: 2, Batch number: 9194
# Accuracy on validation dataset: 611/15547 (3.93%)
#
# Epoch: 2, Batch number: 9694
# Accuracy on validation dataset: 602/15547 (3.87%)
#
# Epoch: 2, Batch number: 10194
# Accuracy on validation dataset: 608/15547 (3.91%)
#
# Epoch: 2, Batch number: 10694
# Accuracy on validation dataset: 639/15547 (4.11%)
#
# Epoch: 2, Batch number: 11194
# Accuracy on validation dataset: 580/15547 (3.73%)
#
# Epoch: 2, Batch number: 11694
# Accuracy on validation dataset: 630/15547 (4.05%)
#
# Epoch: 3, Batch number: 291
# Accuracy on validation dataset: 675/15547 (4.34%)
#
# Epoch: 3, Batch number: 791
# Accuracy on validation dataset: 639/15547 (4.11%)
#
# Epoch: 3, Batch number: 1291
# Accuracy on validation dataset: 625/15547 (4.02%)
#
# Epoch: 3, Batch number: 1791
# Accuracy on validation dataset: 660/15547 (4.25%)
#
# Epoch: 3, Batch number: 2291
# Accuracy on validation dataset: 590/15547 (3.79%)
#
# Epoch: 3, Batch number: 2791
# Accuracy on validation dataset: 610/15547 (3.92%)
#
# Epoch: 3, Batch number: 3291
# Accuracy on validation dataset: 601/15547 (3.87%)
#
# Epoch: 3, Batch number: 3791
# Accuracy on validation dataset: 651/15547 (4.19%)
#
# Epoch: 3, Batch number: 4291
# Accuracy on validation dataset: 649/15547 (4.17%)
#
# Epoch: 3, Batch number: 4791
# Accuracy on validation dataset: 669/15547 (4.30%)
#
# Epoch: 3, Batch number: 5291
# Accuracy on validation dataset: 544/15547 (3.50%)
#
# Epoch: 3, Batch number: 5791
# Accuracy on validation dataset: 701/15547 (4.51%)
#
# Epoch: 3, Batch number: 6291
# Accuracy on validation dataset: 685/15547 (4.41%)
#
# Epoch: 3, Batch number: 6791
# Accuracy on validation dataset: 639/15547 (4.11%)
#
# Epoch: 3, Batch number: 7291
# Accuracy on validation dataset: 672/15547 (4.32%)
#
# Epoch: 3, Batch number: 7791
# Accuracy on validation dataset: 685/15547 (4.41%)
#
# Epoch: 3, Batch number: 8291
# Accuracy on validation dataset: 680/15547 (4.37%)
#
# Epoch: 3, Batch number: 8791
# Accuracy on validation dataset: 694/15547 (4.46%)
#
# Epoch: 3, Batch number: 9291
# Accuracy on validation dataset: 692/15547 (4.45%)
#
# Epoch: 3, Batch number: 9791
# Accuracy on validation dataset: 684/15547 (4.40%)
#
# Epoch: 3, Batch number: 10291
# Accuracy on validation dataset: 663/15547 (4.26%)
#
# Epoch: 3, Batch number: 10791
# Accuracy on validation dataset: 685/15547 (4.41%)
#
# Epoch: 3, Batch number: 11291
# Accuracy on validation dataset: 684/15547 (4.40%)
#
# Epoch: 3, Batch number: 11791
# Accuracy on validation dataset: 685/15547 (4.41%)
#
# Epoch: 4, Batch number: 388
# Accuracy on validation dataset: 709/15547 (4.56%)
#
# Epoch: 4, Batch number: 888
# Accuracy on validation dataset: 709/15547 (4.56%)
#
# Epoch: 4, Batch number: 1388
# Accuracy on validation dataset: 707/15547 (4.55%)
#
# Epoch: 4, Batch number: 1888
# Accuracy on validation dataset: 703/15547 (4.52%)
#
# Epoch: 4, Batch number: 2388
# Accuracy on validation dataset: 703/15547 (4.52%)
#
# Epoch: 4, Batch number: 2888
# Accuracy on validation dataset: 711/15547 (4.57%)
#
# Epoch: 4, Batch number: 3388
# Accuracy on validation dataset: 682/15547 (4.39%)
# Epoch: 4, Batch number: 3888
# Accuracy on validation dataset: 739/15547 (4.75%)
#
# Epoch: 4, Batch number: 4388
# Accuracy on validation dataset: 723/15547 (4.65%)
#
# Epoch: 4, Batch number: 4888
# Accuracy on validation dataset: 726/15547 (4.67%)
#
# Epoch: 4, Batch number: 5388
# Accuracy on validation dataset: 727/15547 (4.68%)
#
# Epoch: 4, Batch number: 5888
# Accuracy on validation dataset: 725/15547 (4.66%)
#
# Epoch: 4, Batch number: 6388
# Accuracy on validation dataset: 726/15547 (4.67%)
#
# Epoch: 4, Batch number: 6888
# Accuracy on validation dataset: 740/15547 (4.76%)
#
# Epoch: 4, Batch number: 7388
# Accuracy on validation dataset: 695/15547 (4.47%)
#
# Epoch: 4, Batch number: 7888
# Accuracy on validation dataset: 714/15547 (4.59%)
#
# Epoch: 4, Batch number: 8388
# Accuracy on validation dataset: 751/15547 (4.83%)
#
# Epoch: 4, Batch number: 8888
# Accuracy on validation dataset: 737/15547 (4.74%)
#
# Epoch: 4, Batch number: 9388
# Accuracy on validation dataset: 775/15547 (4.98%)
#
# Epoch: 4, Batch number: 9888
# Accuracy on validation dataset: 741/15547 (4.77%)
#
# Epoch: 4, Batch number: 10388
# Accuracy on validation dataset: 747/15547 (4.80%)
#
# Epoch: 4, Batch number: 10888
# Accuracy on validation dataset: 763/15547 (4.91%)
#
# Epoch: 4, Batch number: 11388
# Accuracy on validation dataset: 774/15547 (4.98%)
#
# Epoch: 4, Batch number: 11888
# Accuracy on validation dataset: 767/15547 (4.93%)
#
# Epoch: 5, Batch number: 485
# Accuracy on validation dataset: 796/15547 (5.12%)
#
# Epoch: 5, Batch number: 985
# Accuracy on validation dataset: 762/15547 (4.90%)
#
# Epoch: 5, Batch number: 1485
# Accuracy on validation dataset: 790/15547 (5.08%)
#
# Epoch: 5, Batch number: 1985
# Accuracy on validation dataset: 785/15547 (5.05%)
#
# Epoch: 5, Batch number: 2485
# Accuracy on validation dataset: 802/15547 (5.16%)
#
# Epoch: 5, Batch number: 2985
# Accuracy on validation dataset: 812/15547 (5.22%)
#
# Epoch: 5, Batch number: 3485
# Accuracy on validation dataset: 800/15547 (5.15%)
#
# Epoch: 5, Batch number: 3985
# Accuracy on validation dataset: 803/15547 (5.16%)
#
# Epoch: 5, Batch number: 4485
# Accuracy on validation dataset: 796/15547 (5.12%)
#
# Epoch: 5, Batch number: 4985
# Accuracy on validation dataset: 795/15547 (5.11%)
#
# Epoch: 5, Batch number: 5485
# Accuracy on validation dataset: 812/15547 (5.22%)
#
# Epoch: 5, Batch number: 5985
# Accuracy on validation dataset: 819/15547 (5.27%)
#
# Epoch: 5, Batch number: 6485
# Accuracy on validation dataset: 781/15547 (5.02%)
#
# Epoch: 5, Batch number: 6985
# Accuracy on validation dataset: 804/15547 (5.17%)
#
# Epoch: 5, Batch number: 7485
# Accuracy on validation dataset: 825/15547 (5.31%)
#
# Epoch: 5, Batch number: 7985
# Accuracy on validation dataset: 830/15547 (5.34%)
#
# Epoch: 5, Batch number: 8485
# Accuracy on validation dataset: 818/15547 (5.26%)
#
# Epoch: 5, Batch number: 8985
# Accuracy on validation dataset: 837/15547 (5.38%)
#
# Epoch: 5, Batch number: 9485
# Accuracy on validation dataset: 840/15547 (5.40%)
#
# Epoch: 5, Batch number: 9985
# Accuracy on validation dataset: 828/15547 (5.33%)
#
# Epoch: 5, Batch number: 10485
# Accuracy on validation dataset: 824/15547 (5.30%)
#
# Epoch: 5, Batch number: 10985
# Accuracy on validation dataset: 841/15547 (5.41%)
#
# Epoch: 5, Batch number: 11485
# Accuracy on validation dataset: 826/15547 (5.31%)
#
# Epoch: 6, Batch number: 82
# Accuracy on validation dataset: 825/15547 (5.31%)
#
# Epoch: 6, Batch number: 582
# Accuracy on validation dataset: 804/15547 (5.17%)
#
# Epoch: 6, Batch number: 1082
# Accuracy on validation dataset: 827/15547 (5.32%)
#
# Epoch: 6, Batch number: 1582
# Accuracy on validation dataset: 845/15547 (5.44%)
#
# Epoch: 6, Batch number: 2082
# Accuracy on validation dataset: 853/15547 (5.49%)
#
# Epoch: 6, Batch number: 2582
# Accuracy on validation dataset: 854/15547 (5.49%)
#
# Epoch: 6, Batch number: 3082
# Accuracy on validation dataset: 871/15547 (5.60%)
#
# Epoch: 6, Batch number: 3582
# Accuracy on validation dataset: 855/15547 (5.50%)
#
# Epoch: 6, Batch number: 4082
# Accuracy on validation dataset: 858/15547 (5.52%)
#
# Epoch: 6, Batch number: 4582
# Accuracy on validation dataset: 857/15547 (5.51%)
#
# Epoch: 6, Batch number: 5082
# Accuracy on validation dataset: 856/15547 (5.51%)
#
# Epoch: 6, Batch number: 5582
# Accuracy on validation dataset: 857/15547 (5.51%)
#
# Epoch: 6, Batch number: 6082
# Accuracy on validation dataset: 858/15547 (5.52%)
#
# Epoch: 6, Batch number: 6582
# Accuracy on validation dataset: 870/15547 (5.60%)
#
# Epoch: 6, Batch number: 7082
# Accuracy on validation dataset: 875/15547 (5.63%)
#
# Epoch: 6, Batch number: 7582
# Accuracy on validation dataset: 868/15547 (5.58%)
#
# Epoch: 6, Batch number: 8082
# Accuracy on validation dataset: 868/15547 (5.58%)
#
# Epoch: 6, Batch number: 8582
# Accuracy on validation dataset: 870/15547 (5.60%)
#
# Epoch: 6, Batch number: 9082
# Accuracy on validation dataset: 870/15547 (5.60%)
#
# Epoch: 6, Batch number: 9582
# Accuracy on validation dataset: 889/15547 (5.72%)
#
# Epoch: 6, Batch number: 10082
# Accuracy on validation dataset: 871/15547 (5.60%)
#
# Epoch: 6, Batch number: 10582
# Accuracy on validation dataset: 880/15547 (5.66%)
#
# Epoch: 6, Batch number: 11082
# Accuracy on validation dataset: 873/15547 (5.62%)
#
# Epoch: 6, Batch number: 11582
# Accuracy on validation dataset: 889/15547 (5.72%)
#
# Epoch: 7, Batch number: 179
# Accuracy on validation dataset: 882/15547 (5.67%)
#
# Epoch: 7, Batch number: 679
# Accuracy on validation dataset: 891/15547 (5.73%)
#
# Epoch: 7, Batch number: 1179
# Accuracy on validation dataset: 889/15547 (5.72%)
#
# Epoch: 7, Batch number: 1679
# Accuracy on validation dataset: 894/15547 (5.75%)
#
# Epoch: 7, Batch number: 2179
# Accuracy on validation dataset: 882/15547 (5.67%)
#
# Epoch: 7, Batch number: 2679
# Accuracy on validation dataset: 885/15547 (5.69%)
#
# Epoch: 7, Batch number: 3179
# Accuracy on validation dataset: 920/15547 (5.92%)
#
# Epoch: 7, Batch number: 3679
# Accuracy on validation dataset: 900/15547 (5.79%)
#
# Epoch: 7, Batch number: 4179
# Accuracy on validation dataset: 915/15547 (5.89%)
#
# Epoch: 7, Batch number: 4679
# Accuracy on validation dataset: 911/15547 (5.86%)
#
# Epoch: 7, Batch number: 5179
# Accuracy on validation dataset: 908/15547 (5.84%)
#
# Epoch: 7, Batch number: 5679
# Accuracy on validation dataset: 911/15547 (5.86%)
#
# Epoch: 7, Batch number: 6179
# Accuracy on validation dataset: 927/15547 (5.96%)
#
# Epoch: 7, Batch number: 6679
# Accuracy on validation dataset: 930/15547 (5.98%)
#
# Epoch: 7, Batch number: 7179
# Accuracy on validation dataset: 914/15547 (5.88%)
#
# Epoch: 7, Batch number: 7679
# Accuracy on validation dataset: 922/15547 (5.93%)
#
# Epoch: 7, Batch number: 8179
# Accuracy on validation dataset: 915/15547 (5.89%)
#
# Epoch: 7, Batch number: 8679
# Accuracy on validation dataset: 912/15547 (5.87%)
#
# Epoch: 7, Batch number: 9179
# Accuracy on validation dataset: 916/15547 (5.89%)
#
# Epoch: 7, Batch number: 9679
# Accuracy on validation dataset: 925/15547 (5.95%)
#
# Epoch: 7, Batch number: 10179
# Accuracy on validation dataset: 907/15547 (5.83%)
#
# Epoch: 7, Batch number: 10679
# Accuracy on validation dataset: 908/15547 (5.84%)
#
# Epoch: 7, Batch number: 11179
# Accuracy on validation dataset: 936/15547 (6.02%)
#
# Epoch: 7, Batch number: 11679
# Accuracy on validation dataset: 950/15547 (6.11%)
#
# Epoch: 8, Batch number: 276
# Accuracy on validation dataset: 920/15547 (5.92%)
#
# Epoch: 8, Batch number: 776
# Accuracy on validation dataset: 926/15547 (5.96%)
#
# Epoch: 8, Batch number: 1276
# Accuracy on validation dataset: 901/15547 (5.80%)
#
# Epoch: 8, Batch number: 1776
# Accuracy on validation dataset: 938/15547 (6.03%)
#
# Epoch: 8, Batch number: 2276
# Accuracy on validation dataset: 927/15547 (5.96%)
#
# Epoch: 8, Batch number: 2776
# Accuracy on validation dataset: 950/15547 (6.11%)
#
# Epoch: 8, Batch number: 3276
# Accuracy on validation dataset: 925/15547 (5.95%)
#
# Epoch: 8, Batch number: 3776
# Accuracy on validation dataset: 952/15547 (6.12%)
#
# Epoch: 8, Batch number: 4276
# Accuracy on validation dataset: 955/15547 (6.14%)
#
# Epoch: 8, Batch number: 4776
# Accuracy on validation dataset: 934/15547 (6.01%)
#
# Epoch: 8, Batch number: 5276
# Accuracy on validation dataset: 965/15547 (6.21%)
#
# Epoch: 8, Batch number: 5776
# Accuracy on validation dataset: 946/15547 (6.08%)
#
# Epoch: 8, Batch number: 6276
# Accuracy on validation dataset: 949/15547 (6.10%)
#
# Epoch: 8, Batch number: 6776
# Accuracy on validation dataset: 959/15547 (6.17%)
#
# Epoch: 8, Batch number: 7276
# Accuracy on validation dataset: 944/15547 (6.07%)
# Epoch: 8, Batch number: 7776
# Accuracy on validation dataset: 977/15547 (6.28%)
#
# Epoch: 8, Batch number: 8276
# Accuracy on validation dataset: 965/15547 (6.21%)
#
# Epoch: 8, Batch number: 8776
# Accuracy on validation dataset: 967/15547 (6.22%)
#
# Epoch: 8, Batch number: 9276
# Accuracy on validation dataset: 971/15547 (6.25%)
#
# Epoch: 8, Batch number: 9776
# Accuracy on validation dataset: 960/15547 (6.17%)
#
# Epoch: 8, Batch number: 10276
# Accuracy on validation dataset: 975/15547 (6.27%)
#
# Epoch: 8, Batch number: 10776
# Accuracy on validation dataset: 987/15547 (6.35%)
#
# Epoch: 8, Batch number: 11276
# Accuracy on validation dataset: 972/15547 (6.25%)
#
# Epoch: 8, Batch number: 11776
# Accuracy on validation dataset: 975/15547 (6.27%)
#
# Epoch: 9, Batch number: 373
# Accuracy on validation dataset: 969/15547 (6.23%)
#
# Epoch: 9, Batch number: 873
# Accuracy on validation dataset: 969/15547 (6.23%)
#
# Epoch: 9, Batch number: 1373
# Accuracy on validation dataset: 983/15547 (6.32%)
#
# Epoch: 9, Batch number: 1873
# Accuracy on validation dataset: 987/15547 (6.35%)
#
# Epoch: 9, Batch number: 2373
# Accuracy on validation dataset: 1006/15547 (6.47%)
#
# Epoch: 9, Batch number: 2873
# Accuracy on validation dataset: 984/15547 (6.33%)
#
# Epoch: 9, Batch number: 3373
# Accuracy on validation dataset: 1000/15547 (6.43%)
#
# Epoch: 9, Batch number: 3873
# Accuracy on validation dataset: 980/15547 (6.30%)
#
# Epoch: 9, Batch number: 4373
# Accuracy on validation dataset: 1001/15547 (6.44%)
#
# Epoch: 9, Batch number: 4873
# Accuracy on validation dataset: 986/15547 (6.34%)
#
# Epoch: 9, Batch number: 5373
# Accuracy on validation dataset: 1000/15547 (6.43%)
#
# Epoch: 9, Batch number: 5873
# Accuracy on validation dataset: 1002/15547 (6.44%)
#
# Epoch: 9, Batch number: 6373
# Accuracy on validation dataset: 1002/15547 (6.44%)
#
# Epoch: 9, Batch number: 6873
# Accuracy on validation dataset: 1011/15547 (6.50%)
#
# Epoch: 9, Batch number: 7373
# Accuracy on validation dataset: 1008/15547 (6.48%)
#
# Epoch: 9, Batch number: 7873
# Accuracy on validation dataset: 1000/15547 (6.43%)
#
# Epoch: 9, Batch number: 8373
# Accuracy on validation dataset: 999/15547 (6.43%)
#
# Epoch: 9, Batch number: 8873
# Accuracy on validation dataset: 962/15547 (6.19%)
#
# Epoch: 9, Batch number: 9373
# Accuracy on validation dataset: 1001/15547 (6.44%)
#
# Epoch: 9, Batch number: 9873
# Accuracy on validation dataset: 1013/15547 (6.52%)
#
# Epoch: 9, Batch number: 10373
# Accuracy on validation dataset: 1020/15547 (6.56%)
#
# Epoch: 9, Batch number: 10873
# Accuracy on validation dataset: 996/15547 (6.41%)
#
# Epoch: 9, Batch number: 11373
# Accuracy on validation dataset: 1013/15547 (6.52%)
#
# Epoch: 9, Batch number: 11873
# Accuracy on validation dataset: 1022/15547 (6.57%)
#
# lr=0.1 completed.
# Epoch: 0, Batch number: 0
# Accuracy on validation dataset: 0/15547 (0.00%)
#
# Epoch: 0, Batch number: 500
# Accuracy on validation dataset: 189/15547 (1.22%)
#
# Epoch: 0, Batch number: 1000
# Accuracy on validation dataset: 189/15547 (1.22%)
#
# Epoch: 0, Batch number: 1500
# Accuracy on validation dataset: 322/15547 (2.07%)
#
# Epoch: 0, Batch number: 2000
# Accuracy on validation dataset: 322/15547 (2.07%)
#
# Epoch: 0, Batch number: 2500
# Accuracy on validation dataset: 322/15547 (2.07%)
#
# Epoch: 0, Batch number: 3000
# Accuracy on validation dataset: 322/15547 (2.07%)
#
# Epoch: 0, Batch number: 3500
# Accuracy on validation dataset: 322/15547 (2.07%)
#
# Epoch: 0, Batch number: 4000
# Accuracy on validation dataset: 322/15547 (2.07%)
#
# Epoch: 0, Batch number: 4500
# Accuracy on validation dataset: 322/15547 (2.07%)
#
# Epoch: 0, Batch number: 5000
# Accuracy on validation dataset: 322/15547 (2.07%)
#
# Epoch: 0, Batch number: 5500
# Accuracy on validation dataset: 322/15547 (2.07%)
#
# Epoch: 0, Batch number: 6000
# Accuracy on validation dataset: 322/15547 (2.07%)
#
# Epoch: 0, Batch number: 6500
# Accuracy on validation dataset: 322/15547 (2.07%)
#
# Epoch: 0, Batch number: 7000
# Accuracy on validation dataset: 322/15547 (2.07%)
#
# Epoch: 0, Batch number: 7500
# Accuracy on validation dataset: 322/15547 (2.07%)
#
# Epoch: 0, Batch number: 8000
# Accuracy on validation dataset: 322/15547 (2.07%)
#
# Epoch: 0, Batch number: 8500
# Accuracy on validation dataset: 322/15547 (2.07%)
#
# Epoch: 0, Batch number: 9000
# Accuracy on validation dataset: 322/15547 (2.07%)
#
# Epoch: 0, Batch number: 9500
# Accuracy on validation dataset: 322/15547 (2.07%)
#
# Epoch: 0, Batch number: 10000
# Accuracy on validation dataset: 322/15547 (2.07%)
#
# Epoch: 0, Batch number: 10500
# Accuracy on validation dataset: 322/15547 (2.07%)
#
# Epoch: 0, Batch number: 11000
# Accuracy on validation dataset: 322/15547 (2.07%)
#
# Epoch: 0, Batch number: 11500
# Accuracy on validation dataset: 322/15547 (2.07%)
#
# Epoch: 1, Batch number: 97
# Accuracy on validation dataset: 322/15547 (2.07%)
#
# Epoch: 1, Batch number: 597
# Accuracy on validation dataset: 322/15547 (2.07%)
#
# Epoch: 1, Batch number: 1097
# Accuracy on validation dataset: 322/15547 (2.07%)
#
# Epoch: 1, Batch number: 1597
# Accuracy on validation dataset: 322/15547 (2.07%)
#
# Epoch: 1, Batch number: 2097
# Accuracy on validation dataset: 322/15547 (2.07%)
#
# Epoch: 1, Batch number: 2597
# Accuracy on validation dataset: 322/15547 (2.07%)
#
# Epoch: 1, Batch number: 3097
# Accuracy on validation dataset: 322/15547 (2.07%)
#
# Epoch: 1, Batch number: 3597
# Accuracy on validation dataset: 322/15547 (2.07%)
#
# Epoch: 1, Batch number: 4097
# Accuracy on validation dataset: 322/15547 (2.07%)
#
# Epoch: 1, Batch number: 4597
# Accuracy on validation dataset: 322/15547 (2.07%)
#
# Epoch: 1, Batch number: 5097
# Accuracy on validation dataset: 322/15547 (2.07%)
#
# Epoch: 1, Batch number: 5597
# Accuracy on validation dataset: 335/15547 (2.15%)
#
# Epoch: 1, Batch number: 6097
# Accuracy on validation dataset: 338/15547 (2.17%)
#
# Epoch: 1, Batch number: 6597
# Accuracy on validation dataset: 322/15547 (2.07%)
#
# Epoch: 1, Batch number: 7097
# Accuracy on validation dataset: 322/15547 (2.07%)
#
# Epoch: 1, Batch number: 7597
# Accuracy on validation dataset: 322/15547 (2.07%)
#
# Epoch: 1, Batch number: 8097
# Accuracy on validation dataset: 322/15547 (2.07%)
#
# Epoch: 1, Batch number: 8597
# Accuracy on validation dataset: 322/15547 (2.07%)
#
# Epoch: 1, Batch number: 9097
# Accuracy on validation dataset: 322/15547 (2.07%)
#
# Epoch: 1, Batch number: 9597
# Accuracy on validation dataset: 338/15547 (2.17%)
#
# Epoch: 1, Batch number: 10097
# Accuracy on validation dataset: 338/15547 (2.17%)
#
# Epoch: 1, Batch number: 10597
# Accuracy on validation dataset: 322/15547 (2.07%)
#
# Epoch: 1, Batch number: 11097
# Accuracy on validation dataset: 365/15547 (2.35%)
#
# Epoch: 1, Batch number: 11597
# Accuracy on validation dataset: 322/15547 (2.07%)
#
# Epoch: 2, Batch number: 194
# Accuracy on validation dataset: 322/15547 (2.07%)
#
# Epoch: 2, Batch number: 694
# Accuracy on validation dataset: 322/15547 (2.07%)
#
# Epoch: 2, Batch number: 1194
# Accuracy on validation dataset: 322/15547 (2.07%)
#
# Epoch: 2, Batch number: 1694
# Accuracy on validation dataset: 322/15547 (2.07%)
#
# Epoch: 2, Batch number: 2194
# Accuracy on validation dataset: 322/15547 (2.07%)
#
# Epoch: 2, Batch number: 2694
# Accuracy on validation dataset: 322/15547 (2.07%)
#
# Epoch: 2, Batch number: 3194
# Accuracy on validation dataset: 322/15547 (2.07%)
#
# Epoch: 2, Batch number: 3694
# Accuracy on validation dataset: 338/15547 (2.17%)
#
# Epoch: 2, Batch number: 4194
# Accuracy on validation dataset: 322/15547 (2.07%)
#
# Epoch: 2, Batch number: 4694
# Accuracy on validation dataset: 322/15547 (2.07%)
#
# Epoch: 2, Batch number: 5194
# Accuracy on validation dataset: 338/15547 (2.17%)
#
# Epoch: 2, Batch number: 5694
# Accuracy on validation dataset: 322/15547 (2.07%)
#
# Epoch: 2, Batch number: 6194
# Accuracy on validation dataset: 322/15547 (2.07%)
#
# Epoch: 2, Batch number: 6694
# Accuracy on validation dataset: 322/15547 (2.07%)
#
# Epoch: 2, Batch number: 7194
# Accuracy on validation dataset: 322/15547 (2.07%)
#
# Epoch: 2, Batch number: 7694
# Accuracy on validation dataset: 322/15547 (2.07%)
#
# Epoch: 2, Batch number: 8194
# Accuracy on validation dataset: 322/15547 (2.07%)
#
# Epoch: 2, Batch number: 8694
# Accuracy on validation dataset: 338/15547 (2.17%)
#
# Epoch: 2, Batch number: 9194
# Accuracy on validation dataset: 322/15547 (2.07%)
#
# Epoch: 2, Batch number: 9694
# Accuracy on validation dataset: 338/15547 (2.17%)
#
# Epoch: 2, Batch number: 10194
# Accuracy on validation dataset: 322/15547 (2.07%)
# Epoch: 2, Batch number: 10694
# Accuracy on validation dataset: 322/15547 (2.07%)
#
# Epoch: 2, Batch number: 11194
# Accuracy on validation dataset: 338/15547 (2.17%)
#
# Epoch: 2, Batch number: 11694
# Accuracy on validation dataset: 338/15547 (2.17%)
#
# Epoch: 3, Batch number: 291
# Accuracy on validation dataset: 338/15547 (2.17%)
#
# Epoch: 3, Batch number: 791
# Accuracy on validation dataset: 322/15547 (2.07%)
#
# Epoch: 3, Batch number: 1291
# Accuracy on validation dataset: 322/15547 (2.07%)
#
# Epoch: 3, Batch number: 1791
# Accuracy on validation dataset: 338/15547 (2.17%)
#
# Epoch: 3, Batch number: 2291
# Accuracy on validation dataset: 322/15547 (2.07%)
#
# Epoch: 3, Batch number: 2791
# Accuracy on validation dataset: 335/15547 (2.15%)
#
# Epoch: 3, Batch number: 3291
# Accuracy on validation dataset: 338/15547 (2.17%)
#
# Epoch: 3, Batch number: 3791
# Accuracy on validation dataset: 334/15547 (2.15%)
#
# Epoch: 3, Batch number: 4291
# Accuracy on validation dataset: 338/15547 (2.17%)
#
# Epoch: 3, Batch number: 4791
# Accuracy on validation dataset: 340/15547 (2.19%)
#
# Epoch: 3, Batch number: 5291
# Accuracy on validation dataset: 331/15547 (2.13%)
#
# Epoch: 3, Batch number: 5791
# Accuracy on validation dataset: 338/15547 (2.17%)
#
# Epoch: 3, Batch number: 6291
# Accuracy on validation dataset: 338/15547 (2.17%)
#
# Epoch: 3, Batch number: 6791
# Accuracy on validation dataset: 338/15547 (2.17%)
#
# Epoch: 3, Batch number: 7291
# Accuracy on validation dataset: 334/15547 (2.15%)
#
# Epoch: 3, Batch number: 7791
# Accuracy on validation dataset: 354/15547 (2.28%)
#
# Epoch: 3, Batch number: 8291
# Accuracy on validation dataset: 338/15547 (2.17%)
#
# Epoch: 3, Batch number: 8791
# Accuracy on validation dataset: 328/15547 (2.11%)
#
# Epoch: 3, Batch number: 9291
# Accuracy on validation dataset: 297/15547 (1.91%)
#
# Epoch: 3, Batch number: 9791
# Accuracy on validation dataset: 338/15547 (2.17%)
#
# Epoch: 3, Batch number: 10291
# Accuracy on validation dataset: 348/15547 (2.24%)
#
# Epoch: 3, Batch number: 10791
# Accuracy on validation dataset: 338/15547 (2.17%)
#
# Epoch: 3, Batch number: 11291
# Accuracy on validation dataset: 402/15547 (2.59%)
#
# Epoch: 3, Batch number: 11791
# Accuracy on validation dataset: 320/15547 (2.06%)
#
# Epoch: 4, Batch number: 388
# Accuracy on validation dataset: 338/15547 (2.17%)
#
# Epoch: 4, Batch number: 888
# Accuracy on validation dataset: 357/15547 (2.30%)
#
# Epoch: 4, Batch number: 1388
# Accuracy on validation dataset: 338/15547 (2.17%)
#
# Epoch: 4, Batch number: 1888
# Accuracy on validation dataset: 338/15547 (2.17%)
#
# Epoch: 4, Batch number: 2388
# Accuracy on validation dataset: 338/15547 (2.17%)
#
# Epoch: 4, Batch number: 2888
# Accuracy on validation dataset: 345/15547 (2.22%)
#
# Epoch: 4, Batch number: 3388
# Accuracy on validation dataset: 338/15547 (2.17%)
#
# Epoch: 4, Batch number: 3888
# Accuracy on validation dataset: 337/15547 (2.17%)
#
# Epoch: 4, Batch number: 4388
# Accuracy on validation dataset: 335/15547 (2.15%)
#
# Epoch: 4, Batch number: 4888
# Accuracy on validation dataset: 298/15547 (1.92%)
#
# Epoch: 4, Batch number: 5388
# Accuracy on validation dataset: 338/15547 (2.17%)
#
# Epoch: 4, Batch number: 5888
# Accuracy on validation dataset: 338/15547 (2.17%)
#
# Epoch: 4, Batch number: 6388
# Accuracy on validation dataset: 338/15547 (2.17%)
#
# Epoch: 4, Batch number: 6888
# Accuracy on validation dataset: 322/15547 (2.07%)
#
# Epoch: 4, Batch number: 7388
# Accuracy on validation dataset: 338/15547 (2.17%)
#
# Epoch: 4, Batch number: 7888
# Accuracy on validation dataset: 351/15547 (2.26%)
#
# Epoch: 4, Batch number: 8388
# Accuracy on validation dataset: 335/15547 (2.15%)
#
# Epoch: 4, Batch number: 8888
# Accuracy on validation dataset: 338/15547 (2.17%)
#
# Epoch: 4, Batch number: 9388
# Accuracy on validation dataset: 336/15547 (2.16%)
#
# Epoch: 4, Batch number: 9888
# Accuracy on validation dataset: 334/15547 (2.15%)
#
# Epoch: 4, Batch number: 10388
# Accuracy on validation dataset: 337/15547 (2.17%)
#
# Epoch: 4, Batch number: 10888
# Accuracy on validation dataset: 343/15547 (2.21%)
#
# Epoch: 4, Batch number: 11388
# Accuracy on validation dataset: 338/15547 (2.17%)
#
# Epoch: 4, Batch number: 11888
# Accuracy on validation dataset: 340/15547 (2.19%)
#
# Epoch: 5, Batch number: 485
# Accuracy on validation dataset: 392/15547 (2.52%)
#
# Epoch: 5, Batch number: 985
# Accuracy on validation dataset: 322/15547 (2.07%)
#
# Epoch: 5, Batch number: 1485
# Accuracy on validation dataset: 336/15547 (2.16%)
#
# Epoch: 5, Batch number: 1985
# Accuracy on validation dataset: 363/15547 (2.33%)
#
# Epoch: 5, Batch number: 2485
# Accuracy on validation dataset: 338/15547 (2.17%)
#
# Epoch: 5, Batch number: 2985
# Accuracy on validation dataset: 338/15547 (2.17%)
#
# Epoch: 5, Batch number: 3485
# Accuracy on validation dataset: 338/15547 (2.17%)
#
# Epoch: 5, Batch number: 3985
# Accuracy on validation dataset: 444/15547 (2.86%)
#
# Epoch: 5, Batch number: 4485
# Accuracy on validation dataset: 338/15547 (2.17%)
#
# Epoch: 5, Batch number: 4985
# Accuracy on validation dataset: 331/15547 (2.13%)
#
# Epoch: 5, Batch number: 5485
# Accuracy on validation dataset: 348/15547 (2.24%)
#
# Epoch: 5, Batch number: 5985
# Accuracy on validation dataset: 364/15547 (2.34%)
#
# Epoch: 5, Batch number: 6485
# Accuracy on validation dataset: 338/15547 (2.17%)
#
# Epoch: 5, Batch number: 6985
# Accuracy on validation dataset: 326/15547 (2.10%)
#
# Epoch: 5, Batch number: 7485
# Accuracy on validation dataset: 338/15547 (2.17%)
#
# Epoch: 5, Batch number: 7985
# Accuracy on validation dataset: 361/15547 (2.32%)
#
# Epoch: 5, Batch number: 8485
# Accuracy on validation dataset: 338/15547 (2.17%)
#
# Epoch: 5, Batch number: 8985
# Accuracy on validation dataset: 338/15547 (2.17%)
#
# Epoch: 5, Batch number: 9485
# Accuracy on validation dataset: 338/15547 (2.17%)
#
# Epoch: 5, Batch number: 9985
# Accuracy on validation dataset: 338/15547 (2.17%)
#
# Epoch: 5, Batch number: 10485
# Accuracy on validation dataset: 338/15547 (2.17%)
#
# Epoch: 5, Batch number: 10985
# Accuracy on validation dataset: 338/15547 (2.17%)
#
# Epoch: 5, Batch number: 11485
# Accuracy on validation dataset: 347/15547 (2.23%)
#
# Epoch: 6, Batch number: 82
# Accuracy on validation dataset: 338/15547 (2.17%)
#
# Epoch: 6, Batch number: 582
# Accuracy on validation dataset: 349/15547 (2.24%)
#
# Epoch: 6, Batch number: 1082
# Accuracy on validation dataset: 342/15547 (2.20%)
#
# Epoch: 6, Batch number: 1582
# Accuracy on validation dataset: 393/15547 (2.53%)
#
# Epoch: 6, Batch number: 2082
# Accuracy on validation dataset: 348/15547 (2.24%)
#
# Epoch: 6, Batch number: 2582
# Accuracy on validation dataset: 353/15547 (2.27%)
#
# Epoch: 6, Batch number: 3082
# Accuracy on validation dataset: 338/15547 (2.17%)
#
# Epoch: 6, Batch number: 3582
# Accuracy on validation dataset: 338/15547 (2.17%)
#
# Epoch: 6, Batch number: 4082
# Accuracy on validation dataset: 329/15547 (2.12%)
#
# Epoch: 6, Batch number: 4582
# Accuracy on validation dataset: 338/15547 (2.17%)
#
# Epoch: 6, Batch number: 5082
# Accuracy on validation dataset: 353/15547 (2.27%)
#
# Epoch: 6, Batch number: 5582
# Accuracy on validation dataset: 337/15547 (2.17%)
#
# Epoch: 6, Batch number: 6082
# Accuracy on validation dataset: 338/15547 (2.17%)
#
# Epoch: 6, Batch number: 6582
# Accuracy on validation dataset: 338/15547 (2.17%)
#
# Epoch: 6, Batch number: 7082
# Accuracy on validation dataset: 435/15547 (2.80%)
#
# Epoch: 6, Batch number: 7582
# Accuracy on validation dataset: 349/15547 (2.24%)
#
# Epoch: 6, Batch number: 8082
# Accuracy on validation dataset: 338/15547 (2.17%)
#
# Epoch: 6, Batch number: 8582
# Accuracy on validation dataset: 348/15547 (2.24%)
#
# Epoch: 6, Batch number: 9082
# Accuracy on validation dataset: 426/15547 (2.74%)
#
# Epoch: 6, Batch number: 9582
# Accuracy on validation dataset: 346/15547 (2.23%)
#
# Epoch: 6, Batch number: 10082
# Accuracy on validation dataset: 338/15547 (2.17%)
#
# Epoch: 6, Batch number: 10582
# Accuracy on validation dataset: 451/15547 (2.90%)
#
# Epoch: 6, Batch number: 11082
# Accuracy on validation dataset: 348/15547 (2.24%)
#
# Epoch: 6, Batch number: 11582
# Accuracy on validation dataset: 338/15547 (2.17%)
#
# Epoch: 7, Batch number: 179
# Accuracy on validation dataset: 438/15547 (2.82%)
#
# Epoch: 7, Batch number: 679
# Accuracy on validation dataset: 342/15547 (2.20%)
#
# Epoch: 7, Batch number: 1179
# Accuracy on validation dataset: 348/15547 (2.24%)
#
# Epoch: 7, Batch number: 1679
# Accuracy on validation dataset: 342/15547 (2.20%)
#
# Epoch: 7, Batch number: 2179
# Accuracy on validation dataset: 349/15547 (2.24%)
# Epoch: 7, Batch number: 2679
# Accuracy on validation dataset: 374/15547 (2.41%)
#
# Epoch: 7, Batch number: 3179
# Accuracy on validation dataset: 356/15547 (2.29%)
#
# Epoch: 7, Batch number: 3679
# Accuracy on validation dataset: 337/15547 (2.17%)
#
# Epoch: 7, Batch number: 4179
# Accuracy on validation dataset: 338/15547 (2.17%)
#
# Epoch: 7, Batch number: 4679
# Accuracy on validation dataset: 337/15547 (2.17%)
#
# Epoch: 7, Batch number: 5179
# Accuracy on validation dataset: 340/15547 (2.19%)
#
# Epoch: 7, Batch number: 5679
# Accuracy on validation dataset: 340/15547 (2.19%)
#
# Epoch: 7, Batch number: 6179
# Accuracy on validation dataset: 338/15547 (2.17%)
#
# Epoch: 7, Batch number: 6679
# Accuracy on validation dataset: 337/15547 (2.17%)
#
# Epoch: 7, Batch number: 7179
# Accuracy on validation dataset: 340/15547 (2.19%)
#
# Epoch: 7, Batch number: 7679
# Accuracy on validation dataset: 337/15547 (2.17%)
#
# Epoch: 7, Batch number: 8179
# Accuracy on validation dataset: 351/15547 (2.26%)
#
# Epoch: 7, Batch number: 8679
# Accuracy on validation dataset: 338/15547 (2.17%)
#
# Epoch: 7, Batch number: 9179
# Accuracy on validation dataset: 343/15547 (2.21%)
#
# Epoch: 7, Batch number: 9679
# Accuracy on validation dataset: 362/15547 (2.33%)
#
# Epoch: 7, Batch number: 10179
# Accuracy on validation dataset: 340/15547 (2.19%)
#
# Epoch: 7, Batch number: 10679
# Accuracy on validation dataset: 337/15547 (2.17%)
#
# Epoch: 7, Batch number: 11179
# Accuracy on validation dataset: 384/15547 (2.47%)
#
# Epoch: 7, Batch number: 11679
# Accuracy on validation dataset: 360/15547 (2.32%)
#
# Epoch: 8, Batch number: 276
# Accuracy on validation dataset: 353/15547 (2.27%)
#
# Epoch: 8, Batch number: 776
# Accuracy on validation dataset: 355/15547 (2.28%)
#
# Epoch: 8, Batch number: 1276
# Accuracy on validation dataset: 341/15547 (2.19%)
#
# Epoch: 8, Batch number: 1776
# Accuracy on validation dataset: 351/15547 (2.26%)
#
# Epoch: 8, Batch number: 2276
# Accuracy on validation dataset: 407/15547 (2.62%)
#
# Epoch: 8, Batch number: 2776
# Accuracy on validation dataset: 353/15547 (2.27%)
#
# Epoch: 8, Batch number: 3276
# Accuracy on validation dataset: 354/15547 (2.28%)
#
# Epoch: 8, Batch number: 3776
# Accuracy on validation dataset: 355/15547 (2.28%)
#
# Epoch: 8, Batch number: 4276
# Accuracy on validation dataset: 437/15547 (2.81%)
#
# Epoch: 8, Batch number: 4776
# Accuracy on validation dataset: 345/15547 (2.22%)
#
# Epoch: 8, Batch number: 5276
# Accuracy on validation dataset: 341/15547 (2.19%)
#
# Epoch: 8, Batch number: 5776
# Accuracy on validation dataset: 340/15547 (2.19%)
#
# Epoch: 8, Batch number: 6276
# Accuracy on validation dataset: 358/15547 (2.30%)
#
# Epoch: 8, Batch number: 6776
# Accuracy on validation dataset: 440/15547 (2.83%)
#
# Epoch: 8, Batch number: 7276
# Accuracy on validation dataset: 356/15547 (2.29%)
#
# Epoch: 8, Batch number: 7776
# Accuracy on validation dataset: 351/15547 (2.26%)
#
# Epoch: 8, Batch number: 8276
# Accuracy on validation dataset: 358/15547 (2.30%)
#
# Epoch: 8, Batch number: 8776
# Accuracy on validation dataset: 402/15547 (2.59%)
#
# Epoch: 8, Batch number: 9276
# Accuracy on validation dataset: 363/15547 (2.33%)
#
# Epoch: 8, Batch number: 9776
# Accuracy on validation dataset: 358/15547 (2.30%)
#
# Epoch: 8, Batch number: 10276
# Accuracy on validation dataset: 371/15547 (2.39%)
#
# Epoch: 8, Batch number: 10776
# Accuracy on validation dataset: 446/15547 (2.87%)
#
# Epoch: 8, Batch number: 11276
# Accuracy on validation dataset: 444/15547 (2.86%)
#
# Epoch: 8, Batch number: 11776
# Accuracy on validation dataset: 358/15547 (2.30%)
#
# Epoch: 9, Batch number: 373
# Accuracy on validation dataset: 355/15547 (2.28%)
#
# Epoch: 9, Batch number: 873
# Accuracy on validation dataset: 349/15547 (2.24%)
#
# Epoch: 9, Batch number: 1373
# Accuracy on validation dataset: 412/15547 (2.65%)
#
# Epoch: 9, Batch number: 1873
# Accuracy on validation dataset: 358/15547 (2.30%)
#
# Epoch: 9, Batch number: 2373
# Accuracy on validation dataset: 358/15547 (2.30%)
#
# Epoch: 9, Batch number: 2873
# Accuracy on validation dataset: 452/15547 (2.91%)
#
# Epoch: 9, Batch number: 3373
# Accuracy on validation dataset: 359/15547 (2.31%)
#
# Epoch: 9, Batch number: 3873
# Accuracy on validation dataset: 348/15547 (2.24%)
#
# Epoch: 9, Batch number: 4373
# Accuracy on validation dataset: 360/15547 (2.32%)
#
# Epoch: 9, Batch number: 4873
# Accuracy on validation dataset: 451/15547 (2.90%)
#
# Epoch: 9, Batch number: 5373
# Accuracy on validation dataset: 362/15547 (2.33%)
#
# Epoch: 9, Batch number: 5873
# Accuracy on validation dataset: 419/15547 (2.70%)
#
# Epoch: 9, Batch number: 6373
# Accuracy on validation dataset: 439/15547 (2.82%)
#
# Epoch: 9, Batch number: 6873
# Accuracy on validation dataset: 415/15547 (2.67%)
#
# Epoch: 9, Batch number: 7373
# Accuracy on validation dataset: 435/15547 (2.80%)
#
# Epoch: 9, Batch number: 7873
# Accuracy on validation dataset: 371/15547 (2.39%)
#
# Epoch: 9, Batch number: 8373
# Accuracy on validation dataset: 342/15547 (2.20%)
#
# Epoch: 9, Batch number: 8873
# Accuracy on validation dataset: 364/15547 (2.34%)
#
# Epoch: 9, Batch number: 9373
# Accuracy on validation dataset: 363/15547 (2.33%)
#
# Epoch: 9, Batch number: 9873
# Accuracy on validation dataset: 386/15547 (2.48%)
#
# Epoch: 9, Batch number: 10373
# Accuracy on validation dataset: 366/15547 (2.35%)
#
# Epoch: 9, Batch number: 10873
# Accuracy on validation dataset: 356/15547 (2.29%)
#
# Epoch: 9, Batch number: 11373
# Accuracy on validation dataset: 366/15547 (2.35%)
#
# Epoch: 9, Batch number: 11873
# Accuracy on validation dataset: 379/15547 (2.44%)
#
# lr=0.01 completed.

# %%
fig, ax = plt.subplots()
for lr, ph in zip(learning_rate, performance_history):
    ax.plot(ph['iter'],ph['loss'],label='lr={:.2g}'.format(lr))
    
ax.legend()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
EmbeddingModel.state_dict()['emb.weight']
# Out:
# tensor([[-3.6818e-03,  8.3574e-03, -3.3496e-05,  ...,  1.0827e-03,
#           1.1752e-03,  3.7088e-03],
#         [ 5.9935e-03,  1.2400e-02, -5.0499e-03,  ..., -1.0103e-03,
#          -2.6502e-04,  3.8109e-03],
#         [-5.6724e-03,  6.3797e-03, -1.4528e-03,  ...,  3.6511e-04,
#           2.0212e-03, -2.0120e-03],
#         ...,
#         [ 3.8196e-02,  4.2808e-03,  3.5793e-03,  ..., -8.6712e-04,
#           2.7670e-03,  4.6814e-04],
#         [-2.9420e-02,  1.2441e-02, -4.6934e-03,  ...,  2.8302e-03,
#          -1.5351e-05, -3.0450e-03],
#         [-1.6083e-02, -1.5726e-03,  2.0950e-03,  ...,  2.6498e-03,
#           1.6592e-03,  1.1319e-03]], device='cuda:0')

# %% [markdown]
# ## Finetuning

# %%
class AGNewsDataset(torch.utils.data.Dataset):
    
    def __init__(self, root='./AG_NEWS/', preprocess=lambda x: x, train=True):
        
        target = 'train.csv' if train else 'test.csv'
        df = pd.read_csv(root + target, header=None, names=['class_idx', 'title', 'description'])
        
        # Etiquetas:
        self.cls_indeces = torch.tensor(df['class_idx'].tolist(), dtype=torch.long) - 1
        
        # DataSeries con las muestras de entradas:
        data = df['title']
        self.data = preprocess(data)
    
    def __getitem__(self,idx):
        if type(idx) == torch.Tensor:
            idx = idx.item()
        return self.vectorizer.vectorize(self.data.iloc[idx]), self.cls_indeces[idx]
    
    def __len__(self):
        return len(self.cls_indeces)
    
    
def GetAGNewsDataset(root, preprocess, cutoff=25):
    
    # Datasets:
    train_dataset = AGNewsDataset(root, preprocess=preprocess, train=True)
    train_dataset.vectorizer = Vectorizer([train_dataset.data], cutoff=cutoff)
    test_dataset = AGNewsDataset(root, preprocess=preprocess, train=False)
    test_dataset.vectorizer = train_dataset.vectorizer
    
    # Dataloaders:
    train_dataloader, val_dataloader, test_dataloader = generate_data_batches(train_dataset, 
                                                                              test_dataset,    
                                                                              batch_size=64)
    return train_dataloader, val_dataloader, test_dataloader

# %%
tc_train_dataloader, tc_val_dataloader, tc_test_dataloader = GetAGNewsDataset(root='./AG_NEWS/', 
                                                                     preprocess=preprocess, 
                                                                     cutoff=25)

import torch.nn as nn

class TextClassifier(nn.Module):
    
    def __init__(self, EmbeddingLayer, n_classes):
        super(TextClassifier, self).__init__()
        self.emb = EmbeddingLayer
        self.out = nn.Linear(self.emb.out_features, n_classes)
        
    def forward(self, x):
        return self.out(self.emb(x))
    
    def loss(self, scores, target):
        lf = nn.CrossEntropyLoss()
        return lf(scores, target)
    

n_classes = 4
ClassifierModel = TextClassifier(EmbeddingModel.emb, n_classes)

# %%
# Parámetros de las muestras:
data = {
    'use_gpu': True, # Trasladar o no las muestras a la GPU
    'input_dtype': torch.float, # Tipo de dato de las muestras de entrada
    'target_dtype': torch.long, # Tipo de dato de las muestras de salida
    'train_dataloader': tc_train_dataloader, # Dataset de entrenamiento
    'val_dataloader': tc_val_dataloader # Dataset de validación
}

# Parámetros de optimización:
epochs = 10 # Cantidad de epochs
sample_loss_every = 500 # Cantidad de iteraciones para calcular la cantidad de aciertos
learning_rate = [1e-1, 1e-2] # Tasa de aprendizaje
check_on_train = False # Queremos ver los resultados también en el train set

# Entrenamiento:
performance_history = []
for lr in learning_rate:
    ClassifierModel = TextClassifier(EmbeddingModel.emb, n_classes)
    performance_history.append(SGDTrainModel(EmbeddingModel, 
                                             data, 
                                             epochs, 
                                             lr, 
                                             sample_loss_every, 
                                             check_on_train, 
                                             verbose=True))
    print('lr={:.2g} completed.'.format(lr))
# Out:
# Epoch: 0, Batch number: 0
# Accuracy on validation dataset: 1276/2400 (53.17%)
#
# Epoch: 0, Batch number: 500
# Accuracy on validation dataset: 1269/2400 (52.88%)
#
# Epoch: 0, Batch number: 1000
# Accuracy on validation dataset: 1275/2400 (53.12%)
#
# Epoch: 0, Batch number: 1500
# Accuracy on validation dataset: 1293/2400 (53.88%)
#
# Epoch: 1, Batch number: 162
# Accuracy on validation dataset: 1285/2400 (53.54%)
#
# Epoch: 1, Batch number: 662
# Accuracy on validation dataset: 1323/2400 (55.12%)
#
# Epoch: 1, Batch number: 1162
# Accuracy on validation dataset: 1268/2400 (52.83%)
#
# Epoch: 1, Batch number: 1662
# Accuracy on validation dataset: 1286/2400 (53.58%)
#
# Epoch: 2, Batch number: 324
# Accuracy on validation dataset: 1314/2400 (54.75%)
#
# Epoch: 2, Batch number: 824
# Accuracy on validation dataset: 1308/2400 (54.50%)
#
# Epoch: 2, Batch number: 1324
# Accuracy on validation dataset: 1281/2400 (53.38%)
#
# Epoch: 2, Batch number: 1824
# Accuracy on validation dataset: 1252/2400 (52.17%)
#
# Epoch: 3, Batch number: 486
# Accuracy on validation dataset: 1289/2400 (53.71%)
#
# Epoch: 3, Batch number: 986
# Accuracy on validation dataset: 1294/2400 (53.92%)
#
# Epoch: 3, Batch number: 1486
# Accuracy on validation dataset: 1295/2400 (53.96%)
#
# Epoch: 4, Batch number: 148
# Accuracy on validation dataset: 1269/2400 (52.88%)
#
# Epoch: 4, Batch number: 648
# Accuracy on validation dataset: 1269/2400 (52.88%)
#
# Epoch: 4, Batch number: 1148
# Accuracy on validation dataset: 1283/2400 (53.46%)
#
# Epoch: 4, Batch number: 1648
# Accuracy on validation dataset: 1303/2400 (54.29%)
#
# Epoch: 5, Batch number: 310
# Accuracy on validation dataset: 1310/2400 (54.58%)
#
# Epoch: 5, Batch number: 810
# Accuracy on validation dataset: 1295/2400 (53.96%)
#
# Epoch: 5, Batch number: 1310
# Accuracy on validation dataset: 1282/2400 (53.42%)
#
# Epoch: 5, Batch number: 1810
# Accuracy on validation dataset: 1296/2400 (54.00%)
#
# Epoch: 6, Batch number: 472
# Accuracy on validation dataset: 1284/2400 (53.50%)
#
# Exiting training...
# Final accuracy registered on validation dataset: 1284/2400 (53.50%)
