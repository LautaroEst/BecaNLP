# %%
import torch
from NLPUtils import *

import numpy as np
# %matplotlib notebook
import matplotlib.pyplot as plt

# %load_ext autoreload
# %autoreload 2

# %%
sentences = []
with open("datasetSentences.txt", "r") as f:
    first = True
    for line in f:
        if first:
            first = False
            continue

        splitted = line.strip().split()[1:]
        # Deal with some peculiar encoding issues with this file
        sentences += [[w.lower() for w in splitted]]

split = [[] for i in range(3)]
with open("datasetSplit.txt", "r") as f:
    first = True
    for line in f:
        if first:
            first = False
            continue

        splitted = line.strip().split(",")
        split[int(splitted[1]) - 1] += [int(splitted[0]) - 1]
        
# Tomamos como corpus el set de entrenamiento:
corpus = [sentences[i] for i in split[0]]

# %%
""" Función para entrenar Word Embeddings
"""
def SGDTrainWordVectors(data,                   # Corpus de entrenamiento (debe ser una lista de listas de strings).
                        lm='CBOW',              # Modelo de lenguaje a utilizar.
                        window_size=2,          # Tamaño de la ventana.
                        batch_size=64,          # Tamaño del batch.
                        embedding_dim=100,      # Dimensión de los word embeddings.
                        use_gpu=True,           # Flags para usar las GPUs.
                        epochs=1,               # Cantidad de epochs.
                        learning_rate=1e-2,     # Tasa de aprendizaje.
                        sample_loss_every=100): # Cada cuántas iteraciones calcular la loss.
    
    # Chequeo que se haya pasado bien el corpus:
    data_is_ok = True
    if isinstance(data,list):
        for doc in data:
            if isinstance(doc,list) or not data_is_ok:
                for token in doc:
                    if not isinstance(token,str):
                        data_is_ok = False
                        break
            else:
                data_is_ok = False
                break
    else:
        data_is_ok = False
                        
    if data_is_ok:
        corpus = data
    else:
        raise TypeError('data debe ser una lista de listas de tokens o un texto plano (string)')
        return
    
    # Obtengo los batches de muestras:
    dataset = Word2VecSamples(corpus, window_size=window_size)
    samples_idx = torch.randperm(len(dataset))
    my_sampler = lambda indices: sampler.SubsetRandomSampler(indices)
    dataloader = DataLoader(dataset, batch_size=batch_size, sampler=my_sampler(samples_idx))
    
    vocab_size = len(dataset.vocabulary)    
    
    # Defino el modelo:
    if lm == 'CBOW':
        model = CBOWModel(vocab_size, embedding_dim)
    elif lm == 'SkipGram':
        model = SkipGramModel(vocab_size, embedding_dim)
    else:
        raise TypeError('El modelo de entrenamiento no es válido.')
    
    
    print('Starting training...')
    loss_history = {'iter': [], 'loss': []}
    device = torch.device('cuda:1') if torch.cuda.is_available() and use_gpu else torch.device('cpu')
    model = model.to(device=device)
    optimizer = optim.SGD(model.parameters(), lr=learning_rate)
    batch_len = len(dataloader)
    
    try:
        for e in range(epochs):
            for t, (x,y) in enumerate(dataloader):
                model.train()
                x = x.to(device=device, dtype=torch.long)
                y = y.to(device=device, dtype=torch.long)

                if lm == 'CBOW':
                    scores = model(y)
                    loss = model.loss(scores,x)
                elif lm == 'SkipGram':
                    scores = model(x)
                    loss = model.loss(scores,y)

                optimizer.zero_grad()
                loss.backward()
                optimizer.step()

                if (e * batch_len + t) % sample_loss_every == 0:
                    print('Epoch: {}, Batch number: {}, Loss: {}'.format(e+1, t,loss.item()))
                    loss_history['iter'].append(e * batch_len + t)
                    loss_history['loss'].append(loss.item())
                    
                    
        return model.emb, dataset.vocabulary, loss_history
                    
    except KeyboardInterrupt:
        
        print('Exiting training...')
        return model.emb, dataset.vocabulary, loss_history


# Modelo de lenguaje:
method = 'SkipGram'
window_size = [1,2,3,4]
embedding_dim = 100

# Parámetros de iteración:
batch_size = 64
epochs = 50
learning_rate = 1e-1
sample_loss_every = 1000
use_gpu = True

history = []
embeddings = []
for ws in window_size:
    embedding_layer, vocab, loss_history = SGDTrainWordVectors(corpus,lm=method,window_size=ws,batch_size=batch_size,embedding_dim=embedding_dim,use_gpu=use_gpu,epochs=epochs,learning_rate=learning_rate,sample_loss_every=sample_loss_every)
    history.append(loss_history)
    embeddings.append(embedding_layer)

fig, ax = plt.subplots()
for i, ws in enumerate(window_size):
    ax.plot(history[i]['iter'],history[i]['loss'],label='Window Size = {}'.format(ws))

ax.legend()
# Out:
# Starting training...
# Epoch: 1, Batch number: 0, Loss: 9.918039321899414
# Epoch: 1, Batch number: 1000, Loss: 8.455574989318848
# Epoch: 1, Batch number: 2000, Loss: 7.912580966949463
# Epoch: 2, Batch number: 444, Loss: 7.825655937194824
# Epoch: 2, Batch number: 1444, Loss: 7.752556800842285
# Epoch: 2, Batch number: 2444, Loss: 7.307127475738525
# Epoch: 3, Batch number: 888, Loss: 6.961059093475342
# Epoch: 3, Batch number: 1888, Loss: 7.6171464920043945
# Epoch: 4, Batch number: 332, Loss: 7.429873943328857
# Epoch: 4, Batch number: 1332, Loss: 7.37601900100708
# Epoch: 4, Batch number: 2332, Loss: 7.041444301605225
# Epoch: 5, Batch number: 776, Loss: 7.479556083679199
# Epoch: 5, Batch number: 1776, Loss: 6.841553688049316
# Epoch: 6, Batch number: 220, Loss: 6.36747932434082
# Epoch: 6, Batch number: 1220, Loss: 6.878442764282227
# Epoch: 6, Batch number: 2220, Loss: 7.124186992645264
# Epoch: 7, Batch number: 664, Loss: 6.769253730773926
# Epoch: 7, Batch number: 1664, Loss: 7.0002055168151855
# Epoch: 8, Batch number: 108, Loss: 6.577085494995117
# Epoch: 8, Batch number: 1108, Loss: 6.856180667877197
# Epoch: 8, Batch number: 2108, Loss: 6.518235206604004
# Epoch: 9, Batch number: 552, Loss: 6.687285900115967
# Epoch: 9, Batch number: 1552, Loss: 6.4119696617126465
# Epoch: 9, Batch number: 2552, Loss: 6.446567058563232
# Epoch: 10, Batch number: 996, Loss: 6.782721996307373
# Epoch: 10, Batch number: 1996, Loss: 6.185611248016357
# Epoch: 11, Batch number: 440, Loss: 6.696413516998291
# Epoch: 11, Batch number: 1440, Loss: 6.403108596801758
# Epoch: 11, Batch number: 2440, Loss: 6.771993160247803
# Epoch: 12, Batch number: 884, Loss: 6.553794860839844
# Epoch: 12, Batch number: 1884, Loss: 6.562185764312744
# Epoch: 13, Batch number: 328, Loss: 6.313545227050781
# Epoch: 13, Batch number: 1328, Loss: 6.631306171417236
# Epoch: 13, Batch number: 2328, Loss: 6.322340488433838
# Epoch: 14, Batch number: 772, Loss: 6.215307235717773
# Epoch: 14, Batch number: 1772, Loss: 6.384908676147461
# Epoch: 15, Batch number: 216, Loss: 6.191675186157227
# Epoch: 15, Batch number: 1216, Loss: 6.671392917633057
# Epoch: 15, Batch number: 2216, Loss: 6.381475448608398
# Epoch: 16, Batch number: 660, Loss: 6.537471294403076
# Epoch: 16, Batch number: 1660, Loss: 6.735663414001465
# Epoch: 17, Batch number: 104, Loss: 6.359570026397705
# Epoch: 17, Batch number: 1104, Loss: 6.322230815887451
# Epoch: 17, Batch number: 2104, Loss: 6.1850199699401855
# Epoch: 18, Batch number: 548, Loss: 6.206125736236572
# Epoch: 18, Batch number: 1548, Loss: 5.770168304443359
# Epoch: 18, Batch number: 2548, Loss: 6.431643486022949
# Epoch: 19, Batch number: 992, Loss: 6.398612976074219
# Epoch: 19, Batch number: 1992, Loss: 5.988898754119873
# Epoch: 20, Batch number: 436, Loss: 6.244639873504639
# Epoch: 20, Batch number: 1436, Loss: 6.173701763153076
# Epoch: 20, Batch number: 2436, Loss: 6.315881729125977
# Epoch: 21, Batch number: 880, Loss: 6.727958679199219
# Epoch: 21, Batch number: 1880, Loss: 6.402233123779297
# Epoch: 22, Batch number: 324, Loss: 5.992872714996338
# Epoch: 22, Batch number: 1324, Loss: 6.105312824249268
# Epoch: 22, Batch number: 2324, Loss: 6.600011825561523
# Epoch: 23, Batch number: 768, Loss: 6.3524169921875
# Epoch: 23, Batch number: 1768, Loss: 6.182876110076904
# Epoch: 24, Batch number: 212, Loss: 6.049583435058594
# Epoch: 24, Batch number: 1212, Loss: 6.103781700134277
# Epoch: 24, Batch number: 2212, Loss: 5.8633832931518555
# Epoch: 25, Batch number: 656, Loss: 6.300947666168213
# Epoch: 25, Batch number: 1656, Loss: 6.517792224884033
# Epoch: 26, Batch number: 100, Loss: 6.178220748901367
# Epoch: 26, Batch number: 1100, Loss: 5.895172595977783
# Epoch: 26, Batch number: 2100, Loss: 6.122950553894043
# Epoch: 27, Batch number: 544, Loss: 6.18056583404541
# Epoch: 27, Batch number: 1544, Loss: 6.204071521759033
# Epoch: 27, Batch number: 2544, Loss: 6.442529678344727
# Epoch: 28, Batch number: 988, Loss: 6.048206806182861
# Epoch: 28, Batch number: 1988, Loss: 6.172483921051025
# Epoch: 29, Batch number: 432, Loss: 6.260298252105713
# Epoch: 29, Batch number: 1432, Loss: 6.119647026062012
# Epoch: 29, Batch number: 2432, Loss: 6.633688926696777
# Epoch: 30, Batch number: 876, Loss: 6.102160930633545
# Epoch: 30, Batch number: 1876, Loss: 5.495173454284668
# Epoch: 31, Batch number: 320, Loss: 6.253482341766357
# Epoch: 31, Batch number: 1320, Loss: 5.900730609893799
# Epoch: 31, Batch number: 2320, Loss: 5.946344375610352
# Epoch: 32, Batch number: 764, Loss: 5.772607803344727
# Epoch: 32, Batch number: 1764, Loss: 6.251584529876709
# Epoch: 33, Batch number: 208, Loss: 5.587738990783691
# Epoch: 33, Batch number: 1208, Loss: 5.671800136566162
# Epoch: 33, Batch number: 2208, Loss: 5.57749605178833
# Epoch: 34, Batch number: 652, Loss: 5.970991134643555
# Epoch: 34, Batch number: 1652, Loss: 5.694724082946777
# Epoch: 35, Batch number: 96, Loss: 5.656172752380371
# Epoch: 35, Batch number: 1096, Loss: 6.124266147613525
# Epoch: 35, Batch number: 2096, Loss: 6.01293420791626
# Epoch: 36, Batch number: 540, Loss: 5.720272541046143
# Epoch: 36, Batch number: 1540, Loss: 5.6378889083862305
# Epoch: 36, Batch number: 2540, Loss: 5.992100715637207
# Epoch: 37, Batch number: 984, Loss: 6.0456061363220215
# Epoch: 37, Batch number: 1984, Loss: 6.109378814697266
# Epoch: 38, Batch number: 428, Loss: 5.534039497375488
# Epoch: 38, Batch number: 1428, Loss: 5.833736896514893
# Epoch: 38, Batch number: 2428, Loss: 6.105112075805664
# Epoch: 39, Batch number: 872, Loss: 5.907573223114014
# Epoch: 39, Batch number: 1872, Loss: 5.821816921234131
# Epoch: 40, Batch number: 316, Loss: 5.580209732055664
# Epoch: 40, Batch number: 1316, Loss: 6.023899555206299
# Epoch: 40, Batch number: 2316, Loss: 5.822972297668457
# Epoch: 41, Batch number: 760, Loss: 5.512907981872559
# Epoch: 41, Batch number: 1760, Loss: 5.842502117156982
# Epoch: 42, Batch number: 204, Loss: 5.602062702178955
# Epoch: 42, Batch number: 1204, Loss: 5.750683784484863
# Epoch: 42, Batch number: 2204, Loss: 5.716310977935791
# Epoch: 43, Batch number: 648, Loss: 6.027327537536621
# Epoch: 43, Batch number: 1648, Loss: 5.504403591156006
# Epoch: 44, Batch number: 92, Loss: 5.949035167694092
# Epoch: 44, Batch number: 1092, Loss: 5.800198554992676
# Epoch: 44, Batch number: 2092, Loss: 5.794924736022949
# Epoch: 45, Batch number: 536, Loss: 5.618182182312012
# Epoch: 45, Batch number: 1536, Loss: 5.933675289154053
# Epoch: 45, Batch number: 2536, Loss: 5.911121845245361
# Epoch: 46, Batch number: 980, Loss: 5.166558742523193
# Epoch: 46, Batch number: 1980, Loss: 6.210392475128174
# Epoch: 47, Batch number: 424, Loss: 6.02047872543335
# Epoch: 47, Batch number: 1424, Loss: 5.863901138305664
# Epoch: 47, Batch number: 2424, Loss: 5.936966896057129
# Epoch: 48, Batch number: 868, Loss: 5.798035144805908
# Epoch: 48, Batch number: 1868, Loss: 6.297817707061768
# Epoch: 49, Batch number: 312, Loss: 5.956424236297607
# Epoch: 49, Batch number: 1312, Loss: 5.789870738983154
# Epoch: 49, Batch number: 2312, Loss: 6.037787914276123
# Epoch: 50, Batch number: 756, Loss: 5.715366840362549
# Epoch: 50, Batch number: 1756, Loss: 6.029365062713623
# Starting training...
# Epoch: 1, Batch number: 0, Loss: 9.894052505493164
# Epoch: 1, Batch number: 1000, Loss: 8.635455131530762
# Epoch: 1, Batch number: 2000, Loss: 8.151047706604004
# Epoch: 2, Batch number: 444, Loss: 8.027836799621582
# Epoch: 2, Batch number: 1444, Loss: 7.47735071182251
# Epoch: 2, Batch number: 2444, Loss: 7.498254776000977
# Epoch: 3, Batch number: 888, Loss: 7.406188011169434
# Epoch: 3, Batch number: 1888, Loss: 7.2729411125183105
# Epoch: 4, Batch number: 332, Loss: 7.681795597076416
# Epoch: 4, Batch number: 1332, Loss: 7.363789081573486
# Epoch: 4, Batch number: 2332, Loss: 7.199565887451172
# Epoch: 5, Batch number: 776, Loss: 7.075248718261719
# Epoch: 5, Batch number: 1776, Loss: 7.324740886688232
# Epoch: 6, Batch number: 220, Loss: 7.182989120483398
# Epoch: 6, Batch number: 1220, Loss: 7.503014087677002
# Epoch: 6, Batch number: 2220, Loss: 6.884500503540039
# Epoch: 7, Batch number: 664, Loss: 7.044977188110352
# Epoch: 7, Batch number: 1664, Loss: 6.965289115905762
# Epoch: 8, Batch number: 108, Loss: 7.201642036437988
# Epoch: 8, Batch number: 1108, Loss: 6.924764156341553
# Epoch: 8, Batch number: 2108, Loss: 6.9837141036987305
# Epoch: 9, Batch number: 552, Loss: 6.905241966247559
# Epoch: 9, Batch number: 1552, Loss: 7.001717567443848
# Epoch: 9, Batch number: 2552, Loss: 6.869040012359619
# Epoch: 10, Batch number: 996, Loss: 6.806644439697266
# Epoch: 10, Batch number: 1996, Loss: 7.030974388122559
# Epoch: 11, Batch number: 440, Loss: 7.030904293060303
# Epoch: 11, Batch number: 1440, Loss: 6.822992324829102
# Epoch: 11, Batch number: 2440, Loss: 7.089425086975098
# Epoch: 12, Batch number: 884, Loss: 6.76313591003418
# Epoch: 12, Batch number: 1884, Loss: 6.732667922973633
# Epoch: 13, Batch number: 328, Loss: 6.7406535148620605
# Epoch: 13, Batch number: 1328, Loss: 6.536139965057373
# Epoch: 13, Batch number: 2328, Loss: 6.961251258850098
# Epoch: 14, Batch number: 772, Loss: 6.746321201324463
# Epoch: 14, Batch number: 1772, Loss: 6.720941543579102
# Epoch: 15, Batch number: 216, Loss: 6.617141246795654
# Epoch: 15, Batch number: 1216, Loss: 6.534308433532715
# Epoch: 15, Batch number: 2216, Loss: 7.016434669494629
# Epoch: 16, Batch number: 660, Loss: 6.828343868255615
# Epoch: 16, Batch number: 1660, Loss: 6.650965690612793
# Epoch: 17, Batch number: 104, Loss: 6.6549201011657715
# Epoch: 17, Batch number: 1104, Loss: 6.647006511688232
# Epoch: 17, Batch number: 2104, Loss: 6.775563716888428
# Epoch: 18, Batch number: 548, Loss: 6.947256565093994
# Epoch: 18, Batch number: 1548, Loss: 6.685998439788818
# Epoch: 18, Batch number: 2548, Loss: 7.029656410217285
# Epoch: 19, Batch number: 992, Loss: 6.716147422790527
# Epoch: 19, Batch number: 1992, Loss: 6.633978366851807
# Epoch: 20, Batch number: 436, Loss: 6.477904319763184
# Epoch: 20, Batch number: 1436, Loss: 6.399059772491455
# Epoch: 20, Batch number: 2436, Loss: 6.766506671905518
# Epoch: 21, Batch number: 880, Loss: 6.4681525230407715
# Epoch: 21, Batch number: 1880, Loss: 6.785149097442627
# Epoch: 22, Batch number: 324, Loss: 6.682614326477051
# Epoch: 22, Batch number: 1324, Loss: 6.5105767250061035
# Epoch: 22, Batch number: 2324, Loss: 6.372927665710449
# Epoch: 23, Batch number: 768, Loss: 6.316885471343994
# Epoch: 23, Batch number: 1768, Loss: 6.544840335845947
# Epoch: 24, Batch number: 212, Loss: 6.92527961730957
# Epoch: 24, Batch number: 1212, Loss: 6.845646381378174
# Epoch: 24, Batch number: 2212, Loss: 6.689203262329102
# Epoch: 25, Batch number: 656, Loss: 6.560486793518066
# Epoch: 25, Batch number: 1656, Loss: 6.618572235107422
# Epoch: 26, Batch number: 100, Loss: 6.424008369445801
# Epoch: 26, Batch number: 1100, Loss: 6.316852569580078
# Epoch: 26, Batch number: 2100, Loss: 6.4643168449401855
# Epoch: 27, Batch number: 544, Loss: 6.287835121154785
# Epoch: 27, Batch number: 1544, Loss: 6.294749736785889
# Epoch: 27, Batch number: 2544, Loss: 6.585540294647217
# Epoch: 28, Batch number: 988, Loss: 6.315464973449707
# Epoch: 28, Batch number: 1988, Loss: 6.452876567840576
# Epoch: 29, Batch number: 432, Loss: 6.430129051208496
# Epoch: 29, Batch number: 1432, Loss: 6.59414005279541
# Epoch: 29, Batch number: 2432, Loss: 6.5496368408203125
# Epoch: 30, Batch number: 876, Loss: 6.576581001281738
# Epoch: 30, Batch number: 1876, Loss: 6.307302474975586
# Epoch: 31, Batch number: 320, Loss: 6.293409824371338
# Epoch: 31, Batch number: 1320, Loss: 6.6246466636657715
# Epoch: 31, Batch number: 2320, Loss: 6.488521575927734
# Epoch: 32, Batch number: 764, Loss: 6.343749523162842
# Epoch: 32, Batch number: 1764, Loss: 6.591968059539795
# Epoch: 33, Batch number: 208, Loss: 6.382047176361084
# Epoch: 33, Batch number: 1208, Loss: 6.675390720367432
# Epoch: 33, Batch number: 2208, Loss: 6.623138427734375
# Epoch: 34, Batch number: 652, Loss: 6.771417140960693
# Epoch: 34, Batch number: 1652, Loss: 6.2282891273498535
# Epoch: 35, Batch number: 96, Loss: 6.460779666900635
# Epoch: 35, Batch number: 1096, Loss: 6.270869731903076
# Epoch: 35, Batch number: 2096, Loss: 6.511467456817627
# Epoch: 36, Batch number: 540, Loss: 6.502832889556885
# Epoch: 36, Batch number: 1540, Loss: 6.392672061920166
# Epoch: 36, Batch number: 2540, Loss: 6.610866069793701
# Epoch: 37, Batch number: 984, Loss: 6.397342205047607
# Epoch: 37, Batch number: 1984, Loss: 6.480522632598877
# Epoch: 38, Batch number: 428, Loss: 6.688543319702148
# Epoch: 38, Batch number: 1428, Loss: 6.574647426605225
# Epoch: 38, Batch number: 2428, Loss: 6.42636775970459
# Epoch: 39, Batch number: 872, Loss: 6.415085792541504
# Epoch: 39, Batch number: 1872, Loss: 6.606666564941406
# Epoch: 40, Batch number: 316, Loss: 6.677824020385742
# Epoch: 40, Batch number: 1316, Loss: 6.443024635314941
# Epoch: 40, Batch number: 2316, Loss: 6.4628400802612305
# Epoch: 41, Batch number: 760, Loss: 6.310828685760498
# Epoch: 41, Batch number: 1760, Loss: 6.3178324699401855
# Epoch: 42, Batch number: 204, Loss: 6.145020484924316
# Epoch: 42, Batch number: 1204, Loss: 6.324333190917969
# Epoch: 42, Batch number: 2204, Loss: 6.325078964233398
# Epoch: 43, Batch number: 648, Loss: 6.407922267913818
# Epoch: 43, Batch number: 1648, Loss: 6.225672721862793
# Epoch: 44, Batch number: 92, Loss: 6.249143600463867
# Epoch: 44, Batch number: 1092, Loss: 6.440629005432129
# Epoch: 44, Batch number: 2092, Loss: 6.098136901855469
# Epoch: 45, Batch number: 536, Loss: 6.021692276000977
# Epoch: 45, Batch number: 1536, Loss: 6.327101707458496
# Epoch: 45, Batch number: 2536, Loss: 6.392336845397949
# Epoch: 46, Batch number: 980, Loss: 6.403013706207275
# Epoch: 46, Batch number: 1980, Loss: 6.193800449371338
# Epoch: 47, Batch number: 424, Loss: 6.425748825073242
# Epoch: 47, Batch number: 1424, Loss: 6.272421836853027
# Epoch: 47, Batch number: 2424, Loss: 6.361723899841309
# Epoch: 48, Batch number: 868, Loss: 6.435426712036133
# Epoch: 48, Batch number: 1868, Loss: 6.6437859535217285
# Epoch: 49, Batch number: 312, Loss: 6.422999382019043
# Epoch: 49, Batch number: 1312, Loss: 6.246431350708008
# Epoch: 49, Batch number: 2312, Loss: 6.162132263183594
# Epoch: 50, Batch number: 756, Loss: 6.537935733795166
# Epoch: 50, Batch number: 1756, Loss: 6.263974189758301
# Starting training...
# Epoch: 1, Batch number: 0, Loss: 9.89195442199707
# Epoch: 1, Batch number: 1000, Loss: 8.480090141296387
# Epoch: 1, Batch number: 2000, Loss: 8.098817825317383
# Epoch: 2, Batch number: 444, Loss: 7.61837911605835
# Epoch: 2, Batch number: 1444, Loss: 7.509815692901611
# Epoch: 2, Batch number: 2444, Loss: 7.635775089263916
# Epoch: 3, Batch number: 888, Loss: 7.451420307159424
# Epoch: 3, Batch number: 1888, Loss: 7.393708229064941
# Epoch: 4, Batch number: 332, Loss: 7.297534942626953
# Epoch: 4, Batch number: 1332, Loss: 7.067312240600586
# Epoch: 4, Batch number: 2332, Loss: 7.208391189575195
# Epoch: 5, Batch number: 776, Loss: 7.250072479248047
# Epoch: 5, Batch number: 1776, Loss: 7.242354393005371
# Epoch: 6, Batch number: 220, Loss: 7.006407260894775
# Epoch: 6, Batch number: 1220, Loss: 7.415619850158691
# Epoch: 6, Batch number: 2220, Loss: 7.058595180511475
# Epoch: 7, Batch number: 664, Loss: 7.254502773284912
# Epoch: 7, Batch number: 1664, Loss: 7.070835113525391
# Epoch: 8, Batch number: 108, Loss: 7.213694095611572
# Epoch: 8, Batch number: 1108, Loss: 7.033139705657959
# Epoch: 8, Batch number: 2108, Loss: 7.250641822814941
# Epoch: 9, Batch number: 552, Loss: 7.015573978424072
# Epoch: 9, Batch number: 1552, Loss: 6.8086137771606445
# Epoch: 9, Batch number: 2552, Loss: 7.07606840133667
# Epoch: 10, Batch number: 996, Loss: 6.812135696411133
# Epoch: 10, Batch number: 1996, Loss: 7.020785808563232
# Epoch: 11, Batch number: 440, Loss: 6.930983543395996
# Epoch: 11, Batch number: 1440, Loss: 6.880501747131348
# Epoch: 11, Batch number: 2440, Loss: 6.813780307769775
# Epoch: 12, Batch number: 884, Loss: 6.858974933624268
# Epoch: 12, Batch number: 1884, Loss: 6.691996097564697
# Epoch: 13, Batch number: 328, Loss: 7.091263771057129
# Epoch: 13, Batch number: 1328, Loss: 7.076562881469727
# Epoch: 13, Batch number: 2328, Loss: 6.773477554321289
# Epoch: 14, Batch number: 772, Loss: 7.044069766998291
# Epoch: 14, Batch number: 1772, Loss: 7.133737087249756
# Epoch: 15, Batch number: 216, Loss: 6.820066452026367
# Epoch: 15, Batch number: 1216, Loss: 7.026703834533691
# Epoch: 15, Batch number: 2216, Loss: 6.948476314544678
# Epoch: 16, Batch number: 660, Loss: 6.846828937530518
# Epoch: 16, Batch number: 1660, Loss: 6.733996868133545
# Epoch: 17, Batch number: 104, Loss: 6.767367839813232
# Epoch: 17, Batch number: 1104, Loss: 6.634716987609863
# Epoch: 17, Batch number: 2104, Loss: 6.972650051116943
# Epoch: 18, Batch number: 548, Loss: 6.863503932952881
# Epoch: 18, Batch number: 1548, Loss: 6.853785991668701
# Epoch: 18, Batch number: 2548, Loss: 6.88289213180542
# Epoch: 19, Batch number: 992, Loss: 6.851823806762695
# Epoch: 19, Batch number: 1992, Loss: 6.934492588043213
# Epoch: 20, Batch number: 436, Loss: 6.657252311706543
# Epoch: 20, Batch number: 1436, Loss: 6.683864593505859
# Epoch: 20, Batch number: 2436, Loss: 6.6248602867126465
# Epoch: 21, Batch number: 880, Loss: 6.6704277992248535
# Epoch: 21, Batch number: 1880, Loss: 6.597770690917969
# Epoch: 22, Batch number: 324, Loss: 6.573245048522949
# Epoch: 22, Batch number: 1324, Loss: 6.55191707611084
# Epoch: 22, Batch number: 2324, Loss: 6.938693046569824
# Epoch: 23, Batch number: 768, Loss: 6.784461975097656
# Epoch: 23, Batch number: 1768, Loss: 6.885495662689209
# Epoch: 24, Batch number: 212, Loss: 6.743733882904053
# Epoch: 24, Batch number: 1212, Loss: 6.560019016265869
# Epoch: 24, Batch number: 2212, Loss: 6.801799297332764
# Epoch: 25, Batch number: 656, Loss: 6.882972240447998
# Epoch: 25, Batch number: 1656, Loss: 6.7736005783081055
# Epoch: 26, Batch number: 100, Loss: 6.892435073852539
# Epoch: 26, Batch number: 1100, Loss: 6.541945934295654
# Epoch: 26, Batch number: 2100, Loss: 6.553313255310059
# Epoch: 27, Batch number: 544, Loss: 6.896708011627197
# Epoch: 27, Batch number: 1544, Loss: 6.723328113555908
# Epoch: 27, Batch number: 2544, Loss: 6.6647725105285645
# Epoch: 28, Batch number: 988, Loss: 6.695907115936279
# Epoch: 28, Batch number: 1988, Loss: 6.937218189239502
# Epoch: 29, Batch number: 432, Loss: 6.764309883117676
# Epoch: 29, Batch number: 1432, Loss: 6.752662181854248
# Epoch: 29, Batch number: 2432, Loss: 6.6834187507629395
# Epoch: 30, Batch number: 876, Loss: 6.639743328094482
# Epoch: 30, Batch number: 1876, Loss: 6.736122131347656
# Epoch: 31, Batch number: 320, Loss: 6.828763484954834
# Epoch: 31, Batch number: 1320, Loss: 6.823698997497559
# Epoch: 31, Batch number: 2320, Loss: 6.5628886222839355
# Epoch: 32, Batch number: 764, Loss: 6.695830821990967
# Epoch: 32, Batch number: 1764, Loss: 6.869687557220459
# Epoch: 33, Batch number: 208, Loss: 6.476374626159668
# Epoch: 33, Batch number: 1208, Loss: 6.629056453704834
# Epoch: 33, Batch number: 2208, Loss: 6.633965492248535
# Epoch: 34, Batch number: 652, Loss: 6.835065841674805
# Epoch: 34, Batch number: 1652, Loss: 6.610989093780518
# Epoch: 35, Batch number: 96, Loss: 6.67498254776001
# Epoch: 35, Batch number: 1096, Loss: 6.59415864944458
# Epoch: 35, Batch number: 2096, Loss: 6.630023002624512
# Epoch: 36, Batch number: 540, Loss: 6.704955101013184
# Epoch: 36, Batch number: 1540, Loss: 6.7944560050964355
# Epoch: 36, Batch number: 2540, Loss: 6.6432414054870605
# Epoch: 37, Batch number: 984, Loss: 6.424854755401611
# Epoch: 37, Batch number: 1984, Loss: 6.475167274475098
# Epoch: 38, Batch number: 428, Loss: 6.6313982009887695
# Epoch: 38, Batch number: 1428, Loss: 6.878377437591553
# Epoch: 38, Batch number: 2428, Loss: 6.588172435760498
# Epoch: 39, Batch number: 872, Loss: 6.544415473937988
# Epoch: 39, Batch number: 1872, Loss: 6.397984027862549
# Epoch: 40, Batch number: 316, Loss: 6.471255779266357
# Epoch: 40, Batch number: 1316, Loss: 6.674407005310059
# Epoch: 40, Batch number: 2316, Loss: 6.546053886413574
# Epoch: 41, Batch number: 760, Loss: 6.748073577880859
# Epoch: 41, Batch number: 1760, Loss: 6.537949562072754
# Epoch: 42, Batch number: 204, Loss: 6.639204978942871
# Epoch: 42, Batch number: 1204, Loss: 6.393814563751221
# Epoch: 42, Batch number: 2204, Loss: 6.299344062805176
# Epoch: 43, Batch number: 648, Loss: 6.709277153015137
# Epoch: 43, Batch number: 1648, Loss: 6.68609619140625
# Epoch: 44, Batch number: 92, Loss: 6.54974365234375
# Epoch: 44, Batch number: 1092, Loss: 6.622950077056885
# Epoch: 44, Batch number: 2092, Loss: 6.645878791809082
# Epoch: 45, Batch number: 536, Loss: 6.575778961181641
# Epoch: 45, Batch number: 1536, Loss: 6.679691314697266
# Epoch: 45, Batch number: 2536, Loss: 6.584676742553711
# Epoch: 46, Batch number: 980, Loss: 6.706063270568848
# Epoch: 46, Batch number: 1980, Loss: 6.529407024383545
# Epoch: 47, Batch number: 424, Loss: 6.58629846572876
# Epoch: 47, Batch number: 1424, Loss: 6.509028911590576
# Epoch: 47, Batch number: 2424, Loss: 6.558712482452393
# Epoch: 48, Batch number: 868, Loss: 6.687321662902832
# Epoch: 48, Batch number: 1868, Loss: 6.452859878540039
# Epoch: 49, Batch number: 312, Loss: 6.582908630371094
# Epoch: 49, Batch number: 1312, Loss: 6.528716564178467
# Epoch: 49, Batch number: 2312, Loss: 6.471438884735107
# Epoch: 50, Batch number: 756, Loss: 6.421692848205566
# Epoch: 50, Batch number: 1756, Loss: 6.616352081298828
# Starting training...
# Epoch: 1, Batch number: 0, Loss: 9.91828727722168
# Epoch: 1, Batch number: 1000, Loss: 8.648966789245605
# Epoch: 1, Batch number: 2000, Loss: 7.927973747253418
# Epoch: 2, Batch number: 444, Loss: 8.176095962524414
# Epoch: 2, Batch number: 1444, Loss: 7.6637492179870605
# Epoch: 2, Batch number: 2444, Loss: 7.496361255645752
# Epoch: 3, Batch number: 888, Loss: 7.4816789627075195
# Epoch: 3, Batch number: 1888, Loss: 7.539000511169434
# Epoch: 4, Batch number: 332, Loss: 7.33089017868042
# Epoch: 4, Batch number: 1332, Loss: 7.347195625305176
# Epoch: 4, Batch number: 2332, Loss: 7.349143028259277
# Epoch: 5, Batch number: 776, Loss: 7.236072063446045
# Epoch: 5, Batch number: 1776, Loss: 7.210276126861572
# Epoch: 6, Batch number: 220, Loss: 7.218477725982666
# Epoch: 6, Batch number: 1220, Loss: 7.112900733947754
# Epoch: 6, Batch number: 2220, Loss: 7.333961486816406
# Epoch: 7, Batch number: 664, Loss: 7.0088887214660645
# Epoch: 7, Batch number: 1664, Loss: 7.032408714294434
# Epoch: 8, Batch number: 108, Loss: 7.033314228057861
# Epoch: 8, Batch number: 1108, Loss: 7.0318379402160645
# Epoch: 8, Batch number: 2108, Loss: 7.170456886291504
# Epoch: 9, Batch number: 552, Loss: 7.247288703918457
# Epoch: 9, Batch number: 1552, Loss: 7.248508930206299
# Epoch: 9, Batch number: 2552, Loss: 6.901927471160889
# Epoch: 10, Batch number: 996, Loss: 7.0821075439453125
# Epoch: 10, Batch number: 1996, Loss: 6.96331262588501
# Epoch: 11, Batch number: 440, Loss: 6.898621559143066
# Epoch: 11, Batch number: 1440, Loss: 7.198468208312988
# Epoch: 11, Batch number: 2440, Loss: 7.0634074211120605
# Epoch: 12, Batch number: 884, Loss: 6.849406719207764
# Epoch: 12, Batch number: 1884, Loss: 6.791590213775635
# Epoch: 13, Batch number: 328, Loss: 6.909992694854736
# Epoch: 13, Batch number: 1328, Loss: 6.850777626037598
# Epoch: 13, Batch number: 2328, Loss: 6.912596702575684
# Epoch: 14, Batch number: 772, Loss: 6.784051418304443
# Epoch: 14, Batch number: 1772, Loss: 7.04377555847168
# Epoch: 15, Batch number: 216, Loss: 6.945237636566162
# Epoch: 15, Batch number: 1216, Loss: 6.822262287139893
# Epoch: 15, Batch number: 2216, Loss: 6.77803897857666
# Epoch: 16, Batch number: 660, Loss: 6.970203399658203
# Epoch: 16, Batch number: 1660, Loss: 6.890862464904785
# Epoch: 17, Batch number: 104, Loss: 6.783870220184326
# Epoch: 17, Batch number: 1104, Loss: 7.006421089172363
# Epoch: 17, Batch number: 2104, Loss: 6.842923641204834
# Epoch: 18, Batch number: 548, Loss: 6.81814432144165
# Epoch: 18, Batch number: 1548, Loss: 6.8771233558654785
# Epoch: 18, Batch number: 2548, Loss: 6.768650531768799
# Epoch: 19, Batch number: 992, Loss: 6.772865295410156
# Epoch: 19, Batch number: 1992, Loss: 6.929245948791504
# Epoch: 20, Batch number: 436, Loss: 6.974912166595459
# Epoch: 20, Batch number: 1436, Loss: 6.871798038482666
# Epoch: 20, Batch number: 2436, Loss: 6.842581272125244
# Epoch: 21, Batch number: 880, Loss: 6.954813480377197
# Epoch: 21, Batch number: 1880, Loss: 6.645626544952393
# Epoch: 22, Batch number: 324, Loss: 6.774092674255371
# Epoch: 22, Batch number: 1324, Loss: 7.003458023071289
# Epoch: 22, Batch number: 2324, Loss: 6.967552661895752
# Epoch: 23, Batch number: 768, Loss: 6.720767498016357
# Epoch: 23, Batch number: 1768, Loss: 6.803645610809326
# Epoch: 24, Batch number: 212, Loss: 6.904965400695801
# Epoch: 24, Batch number: 1212, Loss: 6.942790985107422
# Epoch: 24, Batch number: 2212, Loss: 6.890034198760986
# Epoch: 25, Batch number: 656, Loss: 6.7624101638793945
# Epoch: 25, Batch number: 1656, Loss: 6.70222282409668
# Epoch: 26, Batch number: 100, Loss: 6.926122188568115
# Epoch: 26, Batch number: 1100, Loss: 6.833795070648193
# Epoch: 26, Batch number: 2100, Loss: 6.940738677978516
# Epoch: 27, Batch number: 544, Loss: 6.608242511749268
# Epoch: 27, Batch number: 1544, Loss: 6.7106547355651855
# Epoch: 27, Batch number: 2544, Loss: 6.763978958129883
# Epoch: 28, Batch number: 988, Loss: 6.865246295928955
# Epoch: 28, Batch number: 1988, Loss: 7.004471302032471
# Epoch: 29, Batch number: 432, Loss: 6.8444647789001465
# Epoch: 29, Batch number: 1432, Loss: 6.908734321594238
# Epoch: 29, Batch number: 2432, Loss: 6.797450542449951
# Epoch: 30, Batch number: 876, Loss: 6.749401092529297
# Epoch: 30, Batch number: 1876, Loss: 6.689740180969238
# Epoch: 31, Batch number: 320, Loss: 6.781877040863037
# Epoch: 31, Batch number: 1320, Loss: 6.719272136688232
# Epoch: 31, Batch number: 2320, Loss: 6.724177360534668
# Epoch: 32, Batch number: 764, Loss: 6.89730167388916
# Epoch: 32, Batch number: 1764, Loss: 6.704092979431152
# Epoch: 33, Batch number: 208, Loss: 6.658263206481934
# Epoch: 33, Batch number: 1208, Loss: 6.543793678283691
# Epoch: 33, Batch number: 2208, Loss: 6.7426886558532715
# Epoch: 34, Batch number: 652, Loss: 6.694216251373291
# Epoch: 34, Batch number: 1652, Loss: 6.656282424926758
# Epoch: 35, Batch number: 96, Loss: 6.880101203918457
# Epoch: 35, Batch number: 1096, Loss: 6.599983215332031
# Epoch: 35, Batch number: 2096, Loss: 6.756228923797607
# Epoch: 36, Batch number: 540, Loss: 6.729395389556885
# Epoch: 36, Batch number: 1540, Loss: 6.570048809051514
# Epoch: 36, Batch number: 2540, Loss: 6.684957027435303
# Epoch: 37, Batch number: 984, Loss: 6.6184773445129395
# Epoch: 37, Batch number: 1984, Loss: 6.693978309631348
# Epoch: 38, Batch number: 428, Loss: 6.739771366119385
# Epoch: 38, Batch number: 1428, Loss: 6.79922342300415
# Epoch: 38, Batch number: 2428, Loss: 6.628448009490967
# Epoch: 39, Batch number: 872, Loss: 6.505880832672119
# Epoch: 39, Batch number: 1872, Loss: 6.7243971824646
# Epoch: 40, Batch number: 316, Loss: 6.510602951049805
# Epoch: 40, Batch number: 1316, Loss: 6.76068115234375
# Epoch: 40, Batch number: 2316, Loss: 6.473448276519775
# Epoch: 41, Batch number: 760, Loss: 6.599725246429443
# Epoch: 41, Batch number: 1760, Loss: 6.679260730743408
# Epoch: 42, Batch number: 204, Loss: 6.60816764831543
# Epoch: 42, Batch number: 1204, Loss: 6.634944915771484
# Epoch: 42, Batch number: 2204, Loss: 6.6553473472595215
# Epoch: 43, Batch number: 648, Loss: 6.749394416809082
# Epoch: 43, Batch number: 1648, Loss: 6.641272068023682
# Epoch: 44, Batch number: 92, Loss: 6.53786039352417
# Epoch: 44, Batch number: 1092, Loss: 6.540093421936035
# Epoch: 44, Batch number: 2092, Loss: 6.667251110076904
# Epoch: 45, Batch number: 536, Loss: 6.658835411071777
# Epoch: 45, Batch number: 1536, Loss: 6.805165767669678
# Epoch: 45, Batch number: 2536, Loss: 6.644843578338623
# Epoch: 46, Batch number: 980, Loss: 6.757479667663574
# Epoch: 46, Batch number: 1980, Loss: 6.751120090484619
# Epoch: 47, Batch number: 424, Loss: 6.534824371337891
# Epoch: 47, Batch number: 1424, Loss: 6.734666347503662
# Epoch: 47, Batch number: 2424, Loss: 6.585935115814209
# Epoch: 48, Batch number: 868, Loss: 6.553460597991943
# Epoch: 48, Batch number: 1868, Loss: 6.629637241363525
# Epoch: 49, Batch number: 312, Loss: 6.9219255447387695
# Epoch: 49, Batch number: 1312, Loss: 6.709352970123291
# Epoch: 49, Batch number: 2312, Loss: 6.604674816131592
# Epoch: 50, Batch number: 756, Loss: 6.5069050788879395
# Epoch: 50, Batch number: 1756, Loss: 6.647970676422119
# <img src="data:image/png;base64,..." width="640">

# %%
# Se visualizan las n palabras más frecuentes:
# n = 100
# freqs = np.array([vocab.get_freq(idx) for idx in range(len(vocab))])
# freqs_indeces = (len(vocab) - np.argsort(freqs) - 1).tolist()[:n]
# visualizeWords = [vocab.index_to_token(idx) for idx in freqs_indeces]

visualizeWords = ["great", "cool", "brilliant", "wonderful", "well", "amazing",
                  "worth", "sweet", "enjoyable", "boring", "bad", "dumb",
                  "annoying", "female", "male", "queen", "king", "man", "woman", "rain", "snow",
                  "hail", "coffee", "tea"]

visualizeIdx = [vocab.token_to_index(word) for word in visualizeWords]

for emb in embeddings:
    visualizeVecs = np.zeros((len(visualizeIdx), embedding_dim),dtype=np.float)
    for i, word in enumerate(visualizeWords):
        idx = vocab.token_to_index(word)
        visualizeVecs[i,:] = next(emb.parameters())[idx,:].cpu().detach().numpy()
    temp = (visualizeVecs - np.mean(visualizeVecs, axis=0))
    covariance = 1.0 / len(visualizeIdx) * temp.T.dot(temp)
    U,S,V = np.linalg.svd(covariance)
    coord = temp.dot(U[:,0:2])

    fig, ax = plt.subplots()
    for i in range(len(visualizeWords)):
        ax.text(coord[i,0], coord[i,1], visualizeWords[i],
            bbox=dict(facecolor='green', alpha=0.1))

    ax.set_xlim((np.min(coord[:,0]), np.max(coord[:,0])))
    ax.set_ylim((np.min(coord[:,1]), np.max(coord[:,1])))
# Out:
# <img src="data:image/png;base64,..." width="640">
# <img src="data:image/png;base64,..." width="640">
# <img src="data:image/png;base64,..." width="640">
# <img src="data:image/png;base64,..." width="640">
